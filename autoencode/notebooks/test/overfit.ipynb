# %%
import autoencodeSVJ.utils as utils
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import glob
import os
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
data,jet_tables = utils.get_training_data_jets("../../data/dijet_tight/*data.h5")
data.head()
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0.0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#      jetEta    jetPhi        jetPt        jetM  jetChargedFraction    jetPTD  \
# 0  0.391208  3.126895   880.629578   46.972202            0.941176  0.238104
# 1  0.226281  1.619783   839.069214   27.909035            0.631579  0.254852
# 2  1.215448  0.042642  1736.550293  164.827713            0.608696  0.418112
# 3 -0.121109 -1.891376   453.773132   62.488964            0.771429  0.162267
# 4  1.025759  3.117460   882.341492  160.383484            0.600000  0.215028
#
#    jetAxis2
# 0  0.041430
# 1  0.016366
# 2  0.006629
# 3  0.079624
# 4  0.021459

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
train, test = data.train_test_split(0.9998)
data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train', 'test']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'jet 0', 'jet 1']

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
ntype="MinMaxScaler"
norm_data = data.norm(norm_type=ntype)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, rng=(0,1), figsize=(8,8), fontsize=10)

ntype="StandardScaler"
norm_data = data.norm(norm_type=ntype)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, rng=(-3,3), figsize=(8,8), fontsize=10)

norm_type="RobustScaler"
q_min = 30
quantile_range=(q_min,100-q_min)
norm_args = {
    "norm_type": norm_type,
    "quantile_range": quantile_range
}
norm_data = data.norm(**norm_args)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, rng=(-3,3))

# rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # norm_data = data.norm(norm_type=0, rng=rng)
# norm_data = custom_norm(data)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
train_norm, test_norm = data.norm(train, **norm_args), data.norm(test, **norm_args)
# print train_norm.shape, test_norm.shape
# train_norm, test_norm = (
#     utils.data_table(custom_norm(train), name="norm train", headers=train.headers),
#     utils.data_table(custom_norm(test), name="norm test", headers=test.headers),
# )
test_norm.df = test_norm.df.iloc[0:100]
test_norm.data = test_norm.data[0:100]

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
# ae_skeleton.add(100)
ae_skeleton.add(30)
ae_skeleton.add(30)
ae_skeleton.add(4, 'relu')

# ae_skeleton.add(300)
# ae_skeleton.add(30)
ae_skeleton.add(40)
# ae_skeleton.add(100)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
name = "test1"
instance = trainer.trainer(os.path.join("../data/training_runs/7jf/", name))
# Out:
# h5_elt 'metric_names' :: creating group 'data' in file 'test1.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'test1.h5'
# h5_elt 'training' :: creating group 'params' in file 'test1.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'test1.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'test1.h5'

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 30)                240
# _________________________________________________________________
# layer_3 (Dense)              (None, 30)                930
# _________________________________________________________________
# layer_4 (Dense)              (None, 4)                 124
# =================================================================
# Total params: 1,294
# Trainable params: 1,294
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_4 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# layer_5 (Dense)              (None, 40)                200
# _________________________________________________________________
# layer_6 (Dense)              (None, 7)                 287
# =================================================================
# Total params: 487
# Trainable params: 487
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 4)                 1294
# _________________________________________________________________
# decoder (Model)              (None, 7)                 487
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss='mse',
    epochs=100,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=True,
    batch_size=1,
    use_callbacks=True,
    learning_rate=0.001
)
# Out:
# train_shell :: using model passed as function argument
# Train on 2 samples, validate on 100 samples
# Epoch 14/113
# 2/2 [==============================] - 1s 341ms/step - loss: 0.4241 - r_square: 0.1827 - mean_absolute_error: 0.5363 - mean_squared_error: 0.4241 - val_loss: 1.4114 - val_r_square: -0.0413 - val_mean_absolute_error: 0.8087 - val_mean_squared_error: 1.4114
# Epoch 15/113
# 2/2 [==============================] - 0s 45ms/step - loss: 0.4136 - r_square: 0.2029 - mean_absolute_error: 0.5269 - mean_squared_error: 0.4136 - val_loss: 1.4113 - val_r_square: -0.0412 - val_mean_absolute_error: 0.8083 - val_mean_squared_error: 1.4113
# Epoch 16/113
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4024 - r_square: 0.2245 - mean_absolute_error: 0.5163 - mean_squared_error: 0.4024 - val_loss: 1.4141 - val_r_square: -0.0433 - val_mean_absolute_error: 0.8089 - val_mean_squared_error: 1.4141
# Epoch 17/113
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3907 - r_square: 0.2470 - mean_absolute_error: 0.5041 - mean_squared_error: 0.3907 - val_loss: 1.4168 - val_r_square: -0.0453 - val_mean_absolute_error: 0.8096 - val_mean_squared_error: 1.4168
# Epoch 18/113
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3793 - r_square: 0.2690 - mean_absolute_error: 0.4916 - mean_squared_error: 0.3793 - val_loss: 1.4191 - val_r_square: -0.0470 - val_mean_absolute_error: 0.8104 - val_mean_squared_error: 1.4191
# Epoch 19/113
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3678 - r_square: 0.2912 - mean_absolute_error: 0.4784 - mean_squared_error: 0.3678 - val_loss: 1.4214 - val_r_square: -0.0487 - val_mean_absolute_error: 0.8113 - val_mean_squared_error: 1.4214
# Epoch 20/113
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3564 - r_square: 0.3131 - mean_absolute_error: 0.4645 - mean_squared_error: 0.3564 - val_loss: 1.4240 - val_r_square: -0.0506 - val_mean_absolute_error: 0.8124 - val_mean_squared_error: 1.4240
# Epoch 21/113
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3455 - r_square: 0.3341 - mean_absolute_error: 0.4502 - mean_squared_error: 0.3455 - val_loss: 1.4252 - val_r_square: -0.0514 - val_mean_absolute_error: 0.8132 - val_mean_squared_error: 1.4252
# Epoch 22/113
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3374 - r_square: 0.3498 - mean_absolute_error: 0.4390 - mean_squared_error: 0.3374 - val_loss: 1.4252 - val_r_square: -0.0515 - val_mean_absolute_error: 0.8133 - val_mean_squared_error: 1.4252
# Epoch 23/113
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3363 - r_square: 0.3519 - mean_absolute_error: 0.4377 - mean_squared_error: 0.3363 - val_loss: 1.4253 - val_r_square: -0.0516 - val_mean_absolute_error: 0.8133 - val_mean_squared_error: 1.4253
# Epoch 24/113
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3353 - r_square: 0.3539 - mean_absolute_error: 0.4366 - mean_squared_error: 0.3353 - val_loss: 1.4254 - val_r_square: -0.0516 - val_mean_absolute_error: 0.8134 - val_mean_squared_error: 1.4254
# Epoch 25/113
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3342 - r_square: 0.3560 - mean_absolute_error: 0.4354 - mean_squared_error: 0.3342 - val_loss: 1.4254 - val_r_square: -0.0516 - val_mean_absolute_error: 0.8135 - val_mean_squared_error: 1.4254
# EPOCH N: 113 100
# train_shell ::
# train_shell :: trained 12 epochs!
# train_shell ::
# finished epoch N 25
# prev [13, 12]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*mean_s*", yscale="linear")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="linear")
instance.plot_metrics(fnmatch_criteria="*r_s*", yscale="linear")

# %% [markdown]
# checking results:

# %%
data_recon_norm = utils.data_table(autoencoder.predict(data.norm(**norm_args).df.values), headers=train_norm.headers)
data_recon = data.inorm(data_recon_norm, **norm_args)
data_recon.name = "all jet data (pred)"

train_reconstructed_norm = utils.data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
test_reconstructed_norm = utils.data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)

train_reconstructed = data.inorm(train_reconstructed_norm, **norm_args)
test_reconstructed = data.inorm(test_reconstructed_norm, **norm_args)


train_reconstructed.name = "train reconstructed"
test_reconstructed.name = "test reconstructed"

# train.plot([train_reconstructed],
#     normed=0, bins=50, alpha=1.0, figloc="upper right",
#     figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
# )
# test.plot([test_reconstructed], 
#       normed=0, bins=50, alpha=1.0, figloc="upper right",
#     figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
# )
data.plot(
#     [train_reconstructed, test_reconstructed],
    data_recon,
    normed=1, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
)

# data.norm(**norm_args).plot(
#     data_recon_norm,
#     normed=0, bins=50, alpha=1.0, figloc="upper right",
#     figsize=(25,15), fontsize=22
# )
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'all jet data (pred)']

# %%
encoder, decoder = autoencoder.layers[1:]
all_reps = utils.data_table(encoder.predict(data.norm(**norm_args).data), headers=["rep {}".format(i + 1) for i in range(4)], name="all_reps")
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), headers=["rep {}".format(i + 1) for i in range(4)], name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), headers=["rep {}".format(i + 1) for i in range(4)], name="test_reps")
)

# %%
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=0, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']

# %%
import keras
errors = utils.data_table(np.asarray(map(
        lambda x: keras.backend.eval(getattr(keras.losses, x)(data.norm(**norm_args).data, data_recon_norm.data)),
        ["mse", "mae"]
    )).T,                      
    headers=["mse", "mae"],
    name="errors"
)
outlier_fraction = 0.02
index = np.argsort(errors.mse)
out_index = index[-int(outlier_fraction*len(errors)):]
reg_index = index[:-int(outlier_fraction*len(errors))]
# print out_index.size + reg_index.size,len(errors)
# print out_index.size, reg_index.size
out,reg = (
    utils.data_table(data.data[out_index], headers=data.headers, name="outliers (top {})".format(outlier_fraction)), 
    utils.data_table(data.data[reg_index], headers=data.headers, name="normal")
)
out_reps, reg_reps = (
    utils.data_table(all_reps.data[out_index], headers=all_reps.headers, name="outlier reps"), 
    utils.data_table(all_reps.data[reg_index], headers=all_reps.headers, name="normal reps")
)
out_reps.plot(reg_reps, normed=1, bins=50, figsize=(20,4))
# reg.plot(out, normed=1, bins=50, figsize=(20,10))
# Out:
# data_table :: plotting distrubution(s) for table(s) ['outlier reps', 'normal reps']
