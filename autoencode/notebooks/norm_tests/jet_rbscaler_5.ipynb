# %%
import autoencodeSVJ.utils as utils
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import glob
import os
import numpy as np

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
data,jet_tables = utils.get_training_data_jets("../../../data/dijet_tight/*data.h5")
data.head()
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0.0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#      jetEta    jetPhi        jetPt        jetM  jetChargedFraction    jetPTD  \
# 0  0.391208  3.126895   880.629578   46.972202            0.941176  0.238104
# 1  0.226281  1.619783   839.069214   27.909035            0.631579  0.254852
# 2  1.215448  0.042642  1736.550293  164.827713            0.608696  0.418112
# 3 -0.121109 -1.891376   453.773132   62.488964            0.771429  0.162267
# 4  1.025759  3.117460   882.341492  160.383484            0.600000  0.215028
#
#    jetAxis2
# 0  0.041430
# 1  0.016366
# 2  0.006629
# 3  0.079624
# 4  0.021459

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
train, test = data.train_test_split(0.3)
data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train', 'test']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'jet 0', 'jet 1']

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
# norm_args = {
#     "norm_type": "MinMaxScaler",
# }
# norm_data = data.norm(**norm_args)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, rng=(0,1), figsize=(8,8), fontsize=10)

# norm_args = {
#     "norm_type": "StandardScaler"
# }
# norm_data = data.norm(**norm_args)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, rng=(-3,3), figsize=(8,8), fontsize=10)

q_min=25
norm_args = {
    "norm_type": "RobustScaler",
    "quantile_range": (q_min,100-q_min)
}
norm_data = data.norm(**norm_args)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, rng=(-3,3))

# # rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# # custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # # norm_data = data.norm(norm_type=0, rng=rng)
# # norm_data = custom_norm(data)
# # features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# # features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
train_norm, test_norm = data.norm(train, **norm_args), data.norm(test, **norm_args)
# print train_norm.shape, test_norm.shape
# train_norm, test_norm = (
#     utils.data_table(custom_norm(train), name="norm train", headers=train.headers),
#     utils.data_table(custom_norm(test), name="norm test", headers=test.headers),
# )

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(30)
ae_skeleton.add(5, 'relu')
ae_skeleton.add(30)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
name = "deep_5_rb_scaler_test"
instance = trainer.trainer(os.path.join("../data/training_runs/7jf/", name))
# Out:
# h5_elt 'metric_names' :: creating group 'data' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'training' :: creating group 'params' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'deep_5_rb_scaler_test.h5'

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 30)                240
# _________________________________________________________________
# layer_3 (Dense)              (None, 5)                 155
# =================================================================
# Total params: 395
# Trainable params: 395
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_3 (InputLayer)         (None, 5)                 0
# _________________________________________________________________
# layer_4 (Dense)              (None, 30)                180
# _________________________________________________________________
# layer_5 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 5)                 395
# _________________________________________________________________
# decoder (Model)              (None, 7)                 397
# =================================================================
# Total params: 792
# Trainable params: 792
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss="mse",
    epochs=40,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=False,
    batch_size=128,
    use_callbacks=False,
    learning_rate=0.001
)
# Out:
# train_shell :: TRAINING EPOCH 0/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 1/1
# 61/61 [==============================] - 2s 26ms/step - loss: 0.6225 - r_square: 0.1121 - mean_absolute_error: 0.5804 - mean_squared_error: 0.6225 - val_loss: 0.5015 - val_r_square: 0.3149 - val_mean_absolute_error: 0.5402 - val_mean_squared_error: 0.5015
# train_shell :: TRAINING EPOCH 1/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 2/2
# 61/61 [==============================] - 1s 15ms/step - loss: 0.3565 - r_square: 0.4915 - mean_absolute_error: 0.4592 - mean_squared_error: 0.3565 - val_loss: 0.2764 - val_r_square: 0.6225 - val_mean_absolute_error: 0.3959 - val_mean_squared_error: 0.2764
# train_shell :: TRAINING EPOCH 2/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 3/3
# 61/61 [==============================] - 1s 15ms/step - loss: 0.2147 - r_square: 0.6938 - mean_absolute_error: 0.3476 - mean_squared_error: 0.2147 - val_loss: 0.1676 - val_r_square: 0.7711 - val_mean_absolute_error: 0.3075 - val_mean_squared_error: 0.1676
# train_shell :: TRAINING EPOCH 3/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 4/4
# 61/61 [==============================] - 1s 15ms/step - loss: 0.1272 - r_square: 0.8186 - mean_absolute_error: 0.2701 - mean_squared_error: 0.1272 - val_loss: 0.1041 - val_r_square: 0.8578 - val_mean_absolute_error: 0.2441 - val_mean_squared_error: 0.1041
# train_shell :: TRAINING EPOCH 4/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 5/5
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0907 - r_square: 0.8707 - mean_absolute_error: 0.2257 - mean_squared_error: 0.0907 - val_loss: 0.0824 - val_r_square: 0.8874 - val_mean_absolute_error: 0.2125 - val_mean_squared_error: 0.0824
# train_shell :: TRAINING EPOCH 5/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 6/6
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0750 - r_square: 0.8930 - mean_absolute_error: 0.2031 - mean_squared_error: 0.0750 - val_loss: 0.0694 - val_r_square: 0.9052 - val_mean_absolute_error: 0.1948 - val_mean_squared_error: 0.0694
# train_shell :: TRAINING EPOCH 6/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 7/7
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0635 - r_square: 0.9094 - mean_absolute_error: 0.1867 - mean_squared_error: 0.0635 - val_loss: 0.0590 - val_r_square: 0.9194 - val_mean_absolute_error: 0.1797 - val_mean_squared_error: 0.0590
# train_shell :: TRAINING EPOCH 7/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 8/8
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0546 - r_square: 0.9222 - mean_absolute_error: 0.1721 - mean_squared_error: 0.0546 - val_loss: 0.0509 - val_r_square: 0.9305 - val_mean_absolute_error: 0.1661 - val_mean_squared_error: 0.0509
# train_shell :: TRAINING EPOCH 8/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 9/9
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0476 - r_square: 0.9321 - mean_absolute_error: 0.1596 - mean_squared_error: 0.0476 - val_loss: 0.0449 - val_r_square: 0.9387 - val_mean_absolute_error: 0.1545 - val_mean_squared_error: 0.0449
# train_shell :: TRAINING EPOCH 9/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 10/10
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0425 - r_square: 0.9394 - mean_absolute_error: 0.1491 - mean_squared_error: 0.0425 - val_loss: 0.0405 - val_r_square: 0.9446 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0405
# train_shell :: TRAINING EPOCH 10/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 11/11
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0390 - r_square: 0.9444 - mean_absolute_error: 0.1410 - mean_squared_error: 0.0390 - val_loss: 0.0376 - val_r_square: 0.9486 - val_mean_absolute_error: 0.1378 - val_mean_squared_error: 0.0376
# train_shell :: TRAINING EPOCH 11/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 12/12
# 61/61 [==============================] - 1s 18ms/step - loss: 0.0366 - r_square: 0.9478 - mean_absolute_error: 0.1348 - mean_squared_error: 0.0366 - val_loss: 0.0356 - val_r_square: 0.9514 - val_mean_absolute_error: 0.1325 - val_mean_squared_error: 0.0356
# train_shell :: TRAINING EPOCH 12/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 13/13
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0349 - r_square: 0.9502 - mean_absolute_error: 0.1300 - mean_squared_error: 0.0349 - val_loss: 0.0341 - val_r_square: 0.9534 - val_mean_absolute_error: 0.1283 - val_mean_squared_error: 0.0341
# train_shell :: TRAINING EPOCH 13/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 14/14
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0336 - r_square: 0.9520 - mean_absolute_error: 0.1263 - mean_squared_error: 0.0336 - val_loss: 0.0329 - val_r_square: 0.9550 - val_mean_absolute_error: 0.1249 - val_mean_squared_error: 0.0329
# train_shell :: TRAINING EPOCH 14/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 15/15
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0326 - r_square: 0.9535 - mean_absolute_error: 0.1231 - mean_squared_error: 0.0326 - val_loss: 0.0320 - val_r_square: 0.9563 - val_mean_absolute_error: 0.1219 - val_mean_squared_error: 0.0320
# train_shell :: TRAINING EPOCH 15/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 16/16
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0318 - r_square: 0.9547 - mean_absolute_error: 0.1203 - mean_squared_error: 0.0318 - val_loss: 0.0312 - val_r_square: 0.9574 - val_mean_absolute_error: 0.1194 - val_mean_squared_error: 0.0312
# train_shell :: TRAINING EPOCH 16/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 17/17
# 61/61 [==============================] - 1s 13ms/step - loss: 0.0311 - r_square: 0.9556 - mean_absolute_error: 0.1180 - mean_squared_error: 0.0311 - val_loss: 0.0306 - val_r_square: 0.9582 - val_mean_absolute_error: 0.1172 - val_mean_squared_error: 0.0306
# train_shell :: TRAINING EPOCH 17/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 18/18
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0305 - r_square: 0.9564 - mean_absolute_error: 0.1160 - mean_squared_error: 0.0305 - val_loss: 0.0301 - val_r_square: 0.9589 - val_mean_absolute_error: 0.1154 - val_mean_squared_error: 0.0301
# train_shell :: TRAINING EPOCH 18/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 19/19
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0300 - r_square: 0.9572 - mean_absolute_error: 0.1142 - mean_squared_error: 0.0300 - val_loss: 0.0296 - val_r_square: 0.9595 - val_mean_absolute_error: 0.1138 - val_mean_squared_error: 0.0296
# train_shell :: TRAINING EPOCH 19/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 20/20
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0296 - r_square: 0.9578 - mean_absolute_error: 0.1126 - mean_squared_error: 0.0296 - val_loss: 0.0292 - val_r_square: 0.9601 - val_mean_absolute_error: 0.1122 - val_mean_squared_error: 0.0292
# train_shell :: TRAINING EPOCH 20/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 21/21
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0292 - r_square: 0.9583 - mean_absolute_error: 0.1112 - mean_squared_error: 0.0292 - val_loss: 0.0289 - val_r_square: 0.9606 - val_mean_absolute_error: 0.1108 - val_mean_squared_error: 0.0289
# train_shell :: TRAINING EPOCH 21/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 22/22
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0289 - r_square: 0.9588 - mean_absolute_error: 0.1098 - mean_squared_error: 0.0289 - val_loss: 0.0285 - val_r_square: 0.9610 - val_mean_absolute_error: 0.1095 - val_mean_squared_error: 0.0285
# train_shell :: TRAINING EPOCH 22/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 23/23
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0285 - r_square: 0.9593 - mean_absolute_error: 0.1086 - mean_squared_error: 0.0285 - val_loss: 0.0283 - val_r_square: 0.9614 - val_mean_absolute_error: 0.1084 - val_mean_squared_error: 0.0283
# train_shell :: TRAINING EPOCH 23/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 24/24
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0282 - r_square: 0.9597 - mean_absolute_error: 0.1075 - mean_squared_error: 0.0282 - val_loss: 0.0279 - val_r_square: 0.9618 - val_mean_absolute_error: 0.1071 - val_mean_squared_error: 0.0279
# train_shell :: TRAINING EPOCH 24/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 25/25
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0280 - r_square: 0.9601 - mean_absolute_error: 0.1063 - mean_squared_error: 0.0280 - val_loss: 0.0277 - val_r_square: 0.9622 - val_mean_absolute_error: 0.1060 - val_mean_squared_error: 0.0277
# train_shell :: TRAINING EPOCH 25/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 26/26
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0277 - r_square: 0.9604 - mean_absolute_error: 0.1053 - mean_squared_error: 0.0277 - val_loss: 0.0275 - val_r_square: 0.9625 - val_mean_absolute_error: 0.1050 - val_mean_squared_error: 0.0275
# train_shell :: TRAINING EPOCH 26/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 27/27
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0275 - r_square: 0.9608 - mean_absolute_error: 0.1044 - mean_squared_error: 0.0275 - val_loss: 0.0272 - val_r_square: 0.9628 - val_mean_absolute_error: 0.1040 - val_mean_squared_error: 0.0272
# train_shell :: TRAINING EPOCH 27/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 28/28
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0273 - r_square: 0.9611 - mean_absolute_error: 0.1035 - mean_squared_error: 0.0273 - val_loss: 0.0270 - val_r_square: 0.9631 - val_mean_absolute_error: 0.1032 - val_mean_squared_error: 0.0270
# train_shell :: TRAINING EPOCH 28/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 29/29
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0271 - r_square: 0.9613 - mean_absolute_error: 0.1027 - mean_squared_error: 0.0271 - val_loss: 0.0269 - val_r_square: 0.9633 - val_mean_absolute_error: 0.1024 - val_mean_squared_error: 0.0269
# train_shell :: TRAINING EPOCH 29/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 30/30
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0269 - r_square: 0.9616 - mean_absolute_error: 0.1019 - mean_squared_error: 0.0269 - val_loss: 0.0267 - val_r_square: 0.9635 - val_mean_absolute_error: 0.1017 - val_mean_squared_error: 0.0267
# train_shell :: TRAINING EPOCH 30/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 31/31
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0268 - r_square: 0.9618 - mean_absolute_error: 0.1011 - mean_squared_error: 0.0268 - val_loss: 0.0265 - val_r_square: 0.9637 - val_mean_absolute_error: 0.1010 - val_mean_squared_error: 0.0265
# train_shell :: TRAINING EPOCH 31/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 32/32
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0266 - r_square: 0.9620 - mean_absolute_error: 0.1005 - mean_squared_error: 0.0266 - val_loss: 0.0264 - val_r_square: 0.9639 - val_mean_absolute_error: 0.1004 - val_mean_squared_error: 0.0264
# train_shell :: TRAINING EPOCH 32/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 33/33
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0265 - r_square: 0.9622 - mean_absolute_error: 0.0998 - mean_squared_error: 0.0265 - val_loss: 0.0263 - val_r_square: 0.9641 - val_mean_absolute_error: 0.0997 - val_mean_squared_error: 0.0263
# train_shell :: TRAINING EPOCH 33/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 34/34
# 61/61 [==============================] - 1s 17ms/step - loss: 0.0264 - r_square: 0.9624 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0264 - val_loss: 0.0261 - val_r_square: 0.9643 - val_mean_absolute_error: 0.0990 - val_mean_squared_error: 0.0261
# train_shell :: TRAINING EPOCH 34/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 35/35
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0262 - r_square: 0.9626 - mean_absolute_error: 0.0986 - mean_squared_error: 0.0262 - val_loss: 0.0260 - val_r_square: 0.9645 - val_mean_absolute_error: 0.0985 - val_mean_squared_error: 0.0260
# train_shell :: TRAINING EPOCH 35/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 36/36
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0261 - r_square: 0.9628 - mean_absolute_error: 0.0981 - mean_squared_error: 0.0261 - val_loss: 0.0259 - val_r_square: 0.9646 - val_mean_absolute_error: 0.0980 - val_mean_squared_error: 0.0259
# train_shell :: TRAINING EPOCH 36/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 37/37
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0260 - r_square: 0.9629 - mean_absolute_error: 0.0976 - mean_squared_error: 0.0260 - val_loss: 0.0258 - val_r_square: 0.9648 - val_mean_absolute_error: 0.0975 - val_mean_squared_error: 0.0258
# train_shell :: TRAINING EPOCH 37/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 38/38
# 61/61 [==============================] - 1s 16ms/step - loss: 0.0259 - r_square: 0.9631 - mean_absolute_error: 0.0971 - mean_squared_error: 0.0259 - val_loss: 0.0257 - val_r_square: 0.9649 - val_mean_absolute_error: 0.0971 - val_mean_squared_error: 0.0257
# train_shell :: TRAINING EPOCH 38/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 39/39
# 61/61 [==============================] - 1s 15ms/step - loss: 0.0258 - r_square: 0.9632 - mean_absolute_error: 0.0966 - mean_squared_error: 0.0258 - val_loss: 0.0256 - val_r_square: 0.9650 - val_mean_absolute_error: 0.0966 - val_mean_squared_error: 0.0256
# train_shell :: TRAINING EPOCH 39/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 40/40
# 61/61 [==============================] - 1s 14ms/step - loss: 0.0257 - r_square: 0.9634 - mean_absolute_error: 0.0961 - mean_squared_error: 0.0257 - val_loss: 0.0255 - val_r_square: 0.9652 - val_mean_absolute_error: 0.0962 - val_mean_squared_error: 0.0255
# EPOCH N: 40 40
# train_shell ::
# train_shell :: trained 40 epochs!
# train_shell ::
# h5_elt 'val_r_square' :: creating group 'metric_names' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'val_r_square' :: creating dataset 'metric_names/val_r_square' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'loss' :: creating dataset 'metric_names/loss' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'mean_absolute_error' :: creating dataset 'metric_names/mean_absolute_error' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'val_mean_squared_error' :: creating dataset 'metric_names/val_mean_squared_error' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'val_mean_absolute_error' :: creating dataset 'metric_names/val_mean_absolute_error' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'r_square' :: creating dataset 'metric_names/r_square' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'mean_squared_error' :: creating dataset 'metric_names/mean_squared_error' in file 'deep_5_rb_scaler_test.h5'
# h5_elt 'val_loss' :: creating dataset 'metric_names/val_loss' in file 'deep_5_rb_scaler_test.h5'
# finished epoch N 40
# prev [40]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*loss*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*r_square*", yscale="log")

# %% [markdown]
# checking results:

# %%
data_recon_norm = utils.data_table(autoencoder.predict(data.norm(**norm_args).df.values), headers=train_norm.headers)
data_recon = data.inorm(data_recon_norm, **norm_args)
data_recon.name = "all jet data (pred)"

# train_reconstructed_norm = data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
# test_reconstructed_norm = data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)

# train_reconstructed = data.inorm(train_reconstructed_norm)
# # test_reconstructed = data.inorm(test_reconstructed_norm)


# train_reconstructed.name = "train reconstructed"
# test_reconstructed.name = "test reconstructed"

# train.plot([train_reconstructed], bins = 30, alpha=1.0)
# test.plot([test_reconstructed], bins=30, alpha=1.0)
data.plot(
#     [train_reconstructed, test_reconstructed],
    data_recon,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
)

data.norm(**norm_args).plot(
    data_recon_norm,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'all jet data (pred)']
# data_table :: plotting distrubution(s) for table(s) ["'all jet data' normed to 'all jet data'", 'untitled 67']

# %%
encoder, decoder = autoencoder.layers[1:]
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), headers=["val {}".format(i + 1) for i in range(5)], name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), headers=["val {}".format(i + 1) for i in range(5)], name="test_reps")
)

# %%
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=1, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']

# %%
train_norm.data.shape
# Out:
# (7865, 7)
