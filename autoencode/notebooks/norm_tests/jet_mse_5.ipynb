# %%
import autoencodeSVJ.utils as utils
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import glob
import os
import numpy as np

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
data,jet_tables = utils.get_training_data_jets("../../../data/dijet_tight/*data.h5")
data.head()
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0.0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#      jetEta    jetPhi        jetPt        jetM  jetChargedFraction    jetPTD  \
# 0  0.391208  3.126895   880.629578   46.972202            0.941176  0.238104
# 1  0.226281  1.619783   839.069214   27.909035            0.631579  0.254852
# 2  1.215448  0.042642  1736.550293  164.827713            0.608696  0.418112
# 3 -0.121109 -1.891376   453.773132   62.488964            0.771429  0.162267
# 4  1.025759  3.117460   882.341492  160.383484            0.600000  0.215028
#
#    jetAxis2
# 0  0.041430
# 1  0.016366
# 2  0.006629
# 3  0.079624
# 4  0.021459

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
train, test = data.train_test_split(0.3)
data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train', 'test']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'jet 0', 'jet 1']

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
norm_args = {
    "norm_type": "MinMaxScaler",
}
norm_data = data.norm(**norm_args)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, rng=(0,1), figsize=(8,8), fontsize=10)

# norm_args = {
#     "norm_type": "StandardScaler"
# }
# norm_data = data.norm(**norm_args)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, rng=(-3,3), figsize=(8,8), fontsize=10)

# q_min=25
# norm_args = {
#     "norm_type": "RobustScaler",
#     "quantile_range": (q_min,100-q_min)
# }
# norm_data = data.norm(**norm_args)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, rng=(-3,3))

# # rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# # custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # # norm_data = data.norm(norm_type=0, rng=rng)
# # norm_data = custom_norm(data)
# # features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# # features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
train_norm, test_norm = data.norm(train, **norm_args), data.norm(test, **norm_args)
# print train_norm.shape, test_norm.shape
# train_norm, test_norm = (
#     utils.data_table(custom_norm(train), name="norm train", headers=train.headers),
#     utils.data_table(custom_norm(test), name="norm test", headers=test.headers),
# )

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(30)
ae_skeleton.add(5, 'relu')
ae_skeleton.add(30)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
name = "deep_5_mse_test"
instance = trainer.trainer(os.path.join("../../data/training_runs/7jf/", name))
# Out:
# h5_elt 'metric_names' :: loading dataset 'data/metric_names' from file 'deep_5_mse_test.h5'
# h5_elt 'training' :: loading dataset 'params/training' from file 'deep_5_mse_test.h5'
# h5_elt 'config' :: loading dataset 'params/config' from file 'deep_5_mse_test.h5'

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 30)                240
# _________________________________________________________________
# layer_3 (Dense)              (None, 5)                 155
# =================================================================
# Total params: 395
# Trainable params: 395
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_3 (InputLayer)         (None, 5)                 0
# _________________________________________________________________
# layer_4 (Dense)              (None, 30)                180
# _________________________________________________________________
# layer_5 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 5)                 395
# _________________________________________________________________
# decoder (Model)              (None, 7)                 397
# =================================================================
# Total params: 792
# Trainable params: 792
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss="mse",
    epochs=40,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=False,
    batch_size=264,
    use_callbacks=False,
    learning_rate=0.005
)
# Out:
# train_shell :: TRAINING EPOCH 0/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 1/1
# 29/29 [==============================] - 3s 109ms/step - loss: 0.0584 - r_square: 0.0557 - mean_absolute_error: 0.1754 - mean_squared_error: 0.0584 - val_loss: 0.0216 - val_r_square: 0.6509 - val_mean_absolute_error: 0.1145 - val_mean_squared_error: 0.0216
# train_shell :: TRAINING EPOCH 1/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 2/2
# 29/29 [==============================] - 0s 16ms/step - loss: 0.0153 - r_square: 0.7522 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0153 - val_loss: 0.0116 - val_r_square: 0.8123 - val_mean_absolute_error: 0.0802 - val_mean_squared_error: 0.0116
# train_shell :: TRAINING EPOCH 2/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 3/3
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0096 - r_square: 0.8455 - mean_absolute_error: 0.0725 - mean_squared_error: 0.0096 - val_loss: 0.0073 - val_r_square: 0.8820 - val_mean_absolute_error: 0.0628 - val_mean_squared_error: 0.0073
# train_shell :: TRAINING EPOCH 3/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 4/4
# 29/29 [==============================] - 0s 14ms/step - loss: 0.0058 - r_square: 0.9066 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0058 - val_loss: 0.0043 - val_r_square: 0.9301 - val_mean_absolute_error: 0.0468 - val_mean_squared_error: 0.0043
# train_shell :: TRAINING EPOCH 4/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 5/5
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0033 - r_square: 0.9464 - mean_absolute_error: 0.0409 - mean_squared_error: 0.0033 - val_loss: 0.0023 - val_r_square: 0.9635 - val_mean_absolute_error: 0.0332 - val_mean_squared_error: 0.0023
# train_shell :: TRAINING EPOCH 5/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 6/6
# 29/29 [==============================] - 0s 15ms/step - loss: 0.0017 - r_square: 0.9720 - mean_absolute_error: 0.0286 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_r_square: 0.9773 - val_mean_absolute_error: 0.0254 - val_mean_squared_error: 0.0014
# train_shell :: TRAINING EPOCH 6/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 7/7
# 29/29 [==============================] - 0s 17ms/step - loss: 0.0012 - r_square: 0.9806 - mean_absolute_error: 0.0230 - mean_squared_error: 0.0012 - val_loss: 0.0011 - val_r_square: 0.9827 - val_mean_absolute_error: 0.0213 - val_mean_squared_error: 0.0011
# train_shell :: TRAINING EPOCH 7/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 8/8
# 29/29 [==============================] - 0s 17ms/step - loss: 9.6636e-04 - r_square: 0.9844 - mean_absolute_error: 0.0199 - mean_squared_error: 9.6636e-04 - val_loss: 9.0705e-04 - val_r_square: 0.9853 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 9.0705e-04
# train_shell :: TRAINING EPOCH 8/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 9/9
# 29/29 [==============================] - 1s 17ms/step - loss: 8.3152e-04 - r_square: 0.9866 - mean_absolute_error: 0.0181 - mean_squared_error: 8.3152e-04 - val_loss: 8.1019e-04 - val_r_square: 0.9869 - val_mean_absolute_error: 0.0177 - val_mean_squared_error: 8.1019e-04
# train_shell :: TRAINING EPOCH 9/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 10/10
# 29/29 [==============================] - 0s 17ms/step - loss: 7.4971e-04 - r_square: 0.9879 - mean_absolute_error: 0.0169 - mean_squared_error: 7.4971e-04 - val_loss: 7.4551e-04 - val_r_square: 0.9879 - val_mean_absolute_error: 0.0167 - val_mean_squared_error: 7.4551e-04
# train_shell :: TRAINING EPOCH 10/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 11/11
# 29/29 [==============================] - 0s 16ms/step - loss: 6.9828e-04 - r_square: 0.9887 - mean_absolute_error: 0.0161 - mean_squared_error: 6.9828e-04 - val_loss: 7.0130e-04 - val_r_square: 0.9887 - val_mean_absolute_error: 0.0159 - val_mean_squared_error: 7.0130e-04
# train_shell :: TRAINING EPOCH 11/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 12/12
# 29/29 [==============================] - 0s 16ms/step - loss: 6.6366e-04 - r_square: 0.9893 - mean_absolute_error: 0.0154 - mean_squared_error: 6.6366e-04 - val_loss: 6.7244e-04 - val_r_square: 0.9891 - val_mean_absolute_error: 0.0154 - val_mean_squared_error: 6.7244e-04
# train_shell :: TRAINING EPOCH 12/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 13/13
# 29/29 [==============================] - 1s 18ms/step - loss: 6.4166e-04 - r_square: 0.9896 - mean_absolute_error: 0.0150 - mean_squared_error: 6.4166e-04 - val_loss: 6.5469e-04 - val_r_square: 0.9894 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 6.5469e-04
# train_shell :: TRAINING EPOCH 13/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 14/14
# 29/29 [==============================] - 0s 17ms/step - loss: 6.2805e-04 - r_square: 0.9899 - mean_absolute_error: 0.0148 - mean_squared_error: 6.2805e-04 - val_loss: 6.4505e-04 - val_r_square: 0.9896 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 6.4505e-04
# train_shell :: TRAINING EPOCH 14/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 15/15
# 29/29 [==============================] - 0s 17ms/step - loss: 6.2362e-04 - r_square: 0.9899 - mean_absolute_error: 0.0151 - mean_squared_error: 6.2362e-04 - val_loss: 6.3924e-04 - val_r_square: 0.9897 - val_mean_absolute_error: 0.0149 - val_mean_squared_error: 6.3924e-04
# train_shell :: TRAINING EPOCH 15/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 16/16
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1509e-04 - r_square: 0.9901 - mean_absolute_error: 0.0147 - mean_squared_error: 6.1509e-04 - val_loss: 6.3741e-04 - val_r_square: 0.9897 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 6.3741e-04
# train_shell :: TRAINING EPOCH 16/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 17/17
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1592e-04 - r_square: 0.9900 - mean_absolute_error: 0.0151 - mean_squared_error: 6.1592e-04 - val_loss: 6.3429e-04 - val_r_square: 0.9897 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 6.3429e-04
# train_shell :: TRAINING EPOCH 17/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 18/18
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1323e-04 - r_square: 0.9901 - mean_absolute_error: 0.0150 - mean_squared_error: 6.1323e-04 - val_loss: 6.3920e-04 - val_r_square: 0.9897 - val_mean_absolute_error: 0.0157 - val_mean_squared_error: 6.3920e-04
# train_shell :: TRAINING EPOCH 18/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 19/19
# 29/29 [==============================] - 0s 16ms/step - loss: 6.0809e-04 - r_square: 0.9902 - mean_absolute_error: 0.0147 - mean_squared_error: 6.0809e-04 - val_loss: 6.2868e-04 - val_r_square: 0.9898 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 6.2868e-04
# train_shell :: TRAINING EPOCH 19/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 20/20
# 29/29 [==============================] - 0s 17ms/step - loss: 6.1191e-04 - r_square: 0.9901 - mean_absolute_error: 0.0152 - mean_squared_error: 6.1191e-04 - val_loss: 6.3464e-04 - val_r_square: 0.9897 - val_mean_absolute_error: 0.0155 - val_mean_squared_error: 6.3464e-04
# train_shell :: TRAINING EPOCH 20/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 21/21
# 29/29 [==============================] - 1s 17ms/step - loss: 6.0459e-04 - r_square: 0.9902 - mean_absolute_error: 0.0146 - mean_squared_error: 6.0459e-04 - val_loss: 6.3098e-04 - val_r_square: 0.9898 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 6.3098e-04
# train_shell :: TRAINING EPOCH 21/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 22/22
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1216e-04 - r_square: 0.9901 - mean_absolute_error: 0.0153 - mean_squared_error: 6.1216e-04 - val_loss: 6.3007e-04 - val_r_square: 0.9898 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 6.3007e-04
# train_shell :: TRAINING EPOCH 22/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 23/23
# 29/29 [==============================] - 1s 18ms/step - loss: 6.0259e-04 - r_square: 0.9903 - mean_absolute_error: 0.0145 - mean_squared_error: 6.0259e-04 - val_loss: 6.2832e-04 - val_r_square: 0.9898 - val_mean_absolute_error: 0.0150 - val_mean_squared_error: 6.2832e-04
# train_shell :: TRAINING EPOCH 23/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 24/24
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1451e-04 - r_square: 0.9901 - mean_absolute_error: 0.0155 - mean_squared_error: 6.1451e-04 - val_loss: 6.3155e-04 - val_r_square: 0.9898 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 6.3155e-04
# train_shell :: TRAINING EPOCH 24/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 25/25
# 29/29 [==============================] - 1s 17ms/step - loss: 6.0085e-04 - r_square: 0.9903 - mean_absolute_error: 0.0144 - mean_squared_error: 6.0085e-04 - val_loss: 6.2413e-04 - val_r_square: 0.9899 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 6.2413e-04
# train_shell :: TRAINING EPOCH 25/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 26/26
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1935e-04 - r_square: 0.9900 - mean_absolute_error: 0.0154 - mean_squared_error: 6.1935e-04 - val_loss: 6.3043e-04 - val_r_square: 0.9898 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 6.3043e-04
# train_shell :: TRAINING EPOCH 26/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 27/27
# 29/29 [==============================] - 0s 16ms/step - loss: 6.0817e-04 - r_square: 0.9902 - mean_absolute_error: 0.0151 - mean_squared_error: 6.0817e-04 - val_loss: 6.2497e-04 - val_r_square: 0.9899 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 6.2497e-04
# train_shell :: TRAINING EPOCH 27/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 28/28
# 29/29 [==============================] - 1s 18ms/step - loss: 5.9836e-04 - r_square: 0.9903 - mean_absolute_error: 0.0142 - mean_squared_error: 5.9836e-04 - val_loss: 6.2314e-04 - val_r_square: 0.9899 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 6.2314e-04
# train_shell :: TRAINING EPOCH 28/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 29/29
# 29/29 [==============================] - 0s 15ms/step - loss: 5.9721e-04 - r_square: 0.9904 - mean_absolute_error: 0.0140 - mean_squared_error: 5.9721e-04 - val_loss: 6.2270e-04 - val_r_square: 0.9899 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 6.2270e-04
# train_shell :: TRAINING EPOCH 29/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 30/30
# 29/29 [==============================] - 0s 14ms/step - loss: 6.1120e-04 - r_square: 0.9901 - mean_absolute_error: 0.0149 - mean_squared_error: 6.1120e-04 - val_loss: 7.9726e-04 - val_r_square: 0.9871 - val_mean_absolute_error: 0.0210 - val_mean_squared_error: 7.9726e-04
# train_shell :: TRAINING EPOCH 30/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 31/31
# 29/29 [==============================] - 0s 16ms/step - loss: 6.2515e-04 - r_square: 0.9899 - mean_absolute_error: 0.0160 - mean_squared_error: 6.2515e-04 - val_loss: 6.2260e-04 - val_r_square: 0.9899 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 6.2260e-04
# train_shell :: TRAINING EPOCH 31/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 32/32
# 29/29 [==============================] - 0s 14ms/step - loss: 5.9448e-04 - r_square: 0.9904 - mean_absolute_error: 0.0142 - mean_squared_error: 5.9448e-04 - val_loss: 6.2118e-04 - val_r_square: 0.9900 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 6.2118e-04
# train_shell :: TRAINING EPOCH 32/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 33/33
# 29/29 [==============================] - 0s 14ms/step - loss: 5.9230e-04 - r_square: 0.9904 - mean_absolute_error: 0.0139 - mean_squared_error: 5.9230e-04 - val_loss: 6.2062e-04 - val_r_square: 0.9900 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 6.2062e-04
# train_shell :: TRAINING EPOCH 33/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 34/34
# 29/29 [==============================] - 0s 16ms/step - loss: 5.9123e-04 - r_square: 0.9904 - mean_absolute_error: 0.0139 - mean_squared_error: 5.9123e-04 - val_loss: 6.2043e-04 - val_r_square: 0.9900 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 6.2043e-04
# train_shell :: TRAINING EPOCH 34/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 35/35
# 29/29 [==============================] - 0s 16ms/step - loss: 5.9763e-04 - r_square: 0.9903 - mean_absolute_error: 0.0143 - mean_squared_error: 5.9763e-04 - val_loss: 6.2313e-04 - val_r_square: 0.9899 - val_mean_absolute_error: 0.0146 - val_mean_squared_error: 6.2313e-04
# train_shell :: TRAINING EPOCH 35/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 36/36
# 29/29 [==============================] - 0s 16ms/step - loss: 6.1178e-04 - r_square: 0.9901 - mean_absolute_error: 0.0155 - mean_squared_error: 6.1178e-04 - val_loss: 6.4262e-04 - val_r_square: 0.9896 - val_mean_absolute_error: 0.0161 - val_mean_squared_error: 6.4262e-04
# train_shell :: TRAINING EPOCH 36/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 37/37
# 29/29 [==============================] - 0s 15ms/step - loss: 5.9466e-04 - r_square: 0.9904 - mean_absolute_error: 0.0146 - mean_squared_error: 5.9466e-04 - val_loss: 6.2126e-04 - val_r_square: 0.9900 - val_mean_absolute_error: 0.0142 - val_mean_squared_error: 6.2126e-04
# train_shell :: TRAINING EPOCH 37/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 38/38
# 29/29 [==============================] - 0s 16ms/step - loss: 5.8848e-04 - r_square: 0.9905 - mean_absolute_error: 0.0139 - mean_squared_error: 5.8848e-04 - val_loss: 6.2037e-04 - val_r_square: 0.9900 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 6.2037e-04
# train_shell :: TRAINING EPOCH 38/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 39/39
# 29/29 [==============================] - 0s 16ms/step - loss: 5.9955e-04 - r_square: 0.9903 - mean_absolute_error: 0.0147 - mean_squared_error: 5.9955e-04 - val_loss: 6.8211e-04 - val_r_square: 0.9890 - val_mean_absolute_error: 0.0178 - val_mean_squared_error: 6.8211e-04
# train_shell :: TRAINING EPOCH 39/40
# Train on 7865 samples, validate on 3371 samples
# Epoch 40/40
# 29/29 [==============================] - 0s 17ms/step - loss: 6.1276e-04 - r_square: 0.9901 - mean_absolute_error: 0.0156 - mean_squared_error: 6.1276e-04 - val_loss: 6.2017e-04 - val_r_square: 0.9900 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 6.2017e-04
# EPOCH N: 40 40
# train_shell ::
# train_shell :: trained 40 epochs!
# train_shell ::
# h5_elt 'val_r_square' :: creating group 'metric_names' in file 'deep_5_mse_test.h5'
# h5_elt 'val_r_square' :: creating dataset 'metric_names/val_r_square' in file 'deep_5_mse_test.h5'
# h5_elt 'loss' :: creating dataset 'metric_names/loss' in file 'deep_5_mse_test.h5'
# h5_elt 'mean_absolute_error' :: creating dataset 'metric_names/mean_absolute_error' in file 'deep_5_mse_test.h5'
# h5_elt 'val_mean_squared_error' :: creating dataset 'metric_names/val_mean_squared_error' in file 'deep_5_mse_test.h5'
# h5_elt 'val_mean_absolute_error' :: creating dataset 'metric_names/val_mean_absolute_error' in file 'deep_5_mse_test.h5'
# h5_elt 'r_square' :: creating dataset 'metric_names/r_square' in file 'deep_5_mse_test.h5'
# h5_elt 'mean_squared_error' :: creating dataset 'metric_names/mean_squared_error' in file 'deep_5_mse_test.h5'
# h5_elt 'val_loss' :: creating dataset 'metric_names/val_loss' in file 'deep_5_mse_test.h5'
# finished epoch N 40
# prev [40]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*squared*", yscale="linear")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="linear")
instance.plot_metrics(fnmatch_criteria="*r_square*", yscale="linear")

# %% [markdown]
# checking results:

# %%
data_recon_norm = utils.data_table(autoencoder.predict(data.norm(**norm_args).df.values), headers=train_norm.headers)
data_recon = data.inorm(data_recon_norm, **norm_args)
data_recon.name = "all jet data (pred)"

# train_reconstructed_norm = data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
# test_reconstructed_norm = data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)

# train_reconstructed = data.inorm(train_reconstructed_norm)
# # test_reconstructed = data.inorm(test_reconstructed_norm)


# train_reconstructed.name = "train reconstructed"
# test_reconstructed.name = "test reconstructed"

# train.plot([train_reconstructed], bins = 30, alpha=1.0)
# test.plot([test_reconstructed], bins=30, alpha=1.0)
data.plot(
#     [train_reconstructed, test_reconstructed],
    data_recon,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
)

data.norm(**norm_args).plot(
    data_recon_norm,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'all jet data (pred)']
# data_table :: plotting distrubution(s) for table(s) ["'all jet data' normed to 'all jet data'", 'untitled 164']

# %%
encoder, decoder = autoencoder.layers[1:]
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), headers=["val {}".format(i + 1) for i in range(5)], name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), headers=["val {}".format(i + 1) for i in range(5)], name="test_reps")
)

# %%
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=1, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']

# %%
train_norm.data.shape
# Out:
# (7865, 7)
