# %%
import autoencodeSVJ.utils as utils
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import glob
import os
import numpy as np

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
data,jet_tables = utils.get_training_data_jets("../../data/dijet_tight/*data.h5")
data.head()
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0.0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#      jetEta    jetPhi        jetPt        jetM  jetChargedFraction    jetPTD  \
# 0  0.391208  3.126895   880.629578   46.972202            0.941176  0.238104
# 1  0.226281  1.619783   839.069214   27.909035            0.631579  0.254852
# 2  1.215448  0.042642  1736.550293  164.827713            0.608696  0.418112
# 3 -0.121109 -1.891376   453.773132   62.488964            0.771429  0.162267
# 4  1.025759  3.117460   882.341492  160.383484            0.600000  0.215028
#
#    jetAxis2
# 0  0.041430
# 1  0.016366
# 2  0.006629
# 3  0.079624
# 4  0.021459

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
train, test = data.train_test_split(0.3)
data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train', 'test']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'jet 0', 'jet 1']

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
# norm_args = {
#     "norm_type": "MinMaxScaler",
# }
# norm_data = data.norm(**norm_args)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, rng=(0,1), figsize=(8,8), fontsize=10)

norm_args = {
    "norm_type": "StandardScaler"
}
norm_data = data.norm(**norm_args)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, rng=(-3,3), figsize=(8,8), fontsize=10)

# norm_args = {
#     "norm_type": "RobustScaler",
#     "quantile_range": (q_min,100-q_min)
# }
# norm_data = data.norm(**norm_args)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, rng=(-6,6))

# # rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# # custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # # norm_data = data.norm(norm_type=0, rng=rng)
# # norm_data = custom_norm(data)
# # features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# # features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
train_norm, test_norm = data.norm(train, **norm_args), data.norm(test, **norm_args)
# print train_norm.shape, test_norm.shape
# train_norm, test_norm = (
#     utils.data_table(custom_norm(train), name="norm train", headers=train.headers),
#     utils.data_table(custom_norm(test), name="norm test", headers=test.headers),
# )

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(30)
ae_skeleton.add(5, 'relu')
ae_skeleton.add(30)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
name = "deep_5_standard_scaler_test3"
instance = trainer.trainer(os.path.join("../data/training_runs/7jf/", name))
# Out:
# h5_elt 'metric_names' :: loading dataset 'data/metric_names' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'training' :: loading dataset 'params/training' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'config' :: loading dataset 'params/config' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'val_r_square' :: loading dataset 'metric_names/val_r_square' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'loss' :: loading dataset 'metric_names/loss' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'mean_absolute_error' :: loading dataset 'metric_names/mean_absolute_error' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'val_mean_squared_error' :: loading dataset 'metric_names/val_mean_squared_error' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'val_mean_absolute_error' :: loading dataset 'metric_names/val_mean_absolute_error' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'r_square' :: loading dataset 'metric_names/r_square' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'mean_squared_error' :: loading dataset 'metric_names/mean_squared_error' from file 'deep_5_standard_scaler_test3.h5'
# h5_elt 'val_loss' :: loading dataset 'metric_names/val_loss' from file 'deep_5_standard_scaler_test3.h5'

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 30)                240
# _________________________________________________________________
# layer_3 (Dense)              (None, 5)                 155
# =================================================================
# Total params: 395
# Trainable params: 395
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_3 (InputLayer)         (None, 5)                 0
# _________________________________________________________________
# layer_4 (Dense)              (None, 30)                180
# _________________________________________________________________
# layer_5 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 5)                 395
# _________________________________________________________________
# decoder (Model)              (None, 7)                 397
# =================================================================
# Total params: 792
# Trainable params: 792
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss="mse",
    epochs=20,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=False,
    batch_size=32,
    use_callbacks=False,
    learning_rate=0.001
)
# Out:
# train_shell :: ERROR: IGNORING PASSED PARAMETER 'model'
# train_shell :: using saved model
# train_shell :: TRAINING EPOCH 40/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 41/41
# 245/245 [==============================] - 4s 17ms/step - loss: 0.0328 - r_square: 0.9673 - mean_absolute_error: 0.0996 - mean_squared_error: 0.0328 - val_loss: 0.0330 - val_r_square: 0.9666 - val_mean_absolute_error: 0.0986 - val_mean_squared_error: 0.0330
# train_shell :: TRAINING EPOCH 41/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 42/42
# 245/245 [==============================] - 4s 16ms/step - loss: 0.0325 - r_square: 0.9677 - mean_absolute_error: 0.0978 - mean_squared_error: 0.0325 - val_loss: 0.0330 - val_r_square: 0.9666 - val_mean_absolute_error: 0.0984 - val_mean_squared_error: 0.0330
# train_shell :: TRAINING EPOCH 42/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 43/43
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0324 - r_square: 0.9677 - mean_absolute_error: 0.0975 - mean_squared_error: 0.0324 - val_loss: 0.0329 - val_r_square: 0.9667 - val_mean_absolute_error: 0.0981 - val_mean_squared_error: 0.0329
# train_shell :: TRAINING EPOCH 43/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 44/44
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0323 - r_square: 0.9678 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0323 - val_loss: 0.0329 - val_r_square: 0.9668 - val_mean_absolute_error: 0.0980 - val_mean_squared_error: 0.0329
# train_shell :: TRAINING EPOCH 44/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 45/45
# 245/245 [==============================] - 4s 16ms/step - loss: 0.0322 - r_square: 0.9679 - mean_absolute_error: 0.0969 - mean_squared_error: 0.0322 - val_loss: 0.0328 - val_r_square: 0.9669 - val_mean_absolute_error: 0.0978 - val_mean_squared_error: 0.0328
# train_shell :: TRAINING EPOCH 45/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 46/46
# 245/245 [==============================] - 4s 16ms/step - loss: 0.0322 - r_square: 0.9680 - mean_absolute_error: 0.0966 - mean_squared_error: 0.0322 - val_loss: 0.0327 - val_r_square: 0.9669 - val_mean_absolute_error: 0.0974 - val_mean_squared_error: 0.0327
# train_shell :: TRAINING EPOCH 46/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 47/47
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0321 - r_square: 0.9681 - mean_absolute_error: 0.0962 - mean_squared_error: 0.0321 - val_loss: 0.0327 - val_r_square: 0.9670 - val_mean_absolute_error: 0.0971 - val_mean_squared_error: 0.0327
# train_shell :: TRAINING EPOCH 47/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 48/48
# 245/245 [==============================] - 4s 17ms/step - loss: 0.0320 - r_square: 0.9682 - mean_absolute_error: 0.0959 - mean_squared_error: 0.0320 - val_loss: 0.0326 - val_r_square: 0.9670 - val_mean_absolute_error: 0.0972 - val_mean_squared_error: 0.0326
# train_shell :: TRAINING EPOCH 48/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 49/49
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0319 - r_square: 0.9682 - mean_absolute_error: 0.0956 - mean_squared_error: 0.0319 - val_loss: 0.0325 - val_r_square: 0.9671 - val_mean_absolute_error: 0.0965 - val_mean_squared_error: 0.0325
# train_shell :: TRAINING EPOCH 49/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 50/50
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0318 - r_square: 0.9683 - mean_absolute_error: 0.0953 - mean_squared_error: 0.0318 - val_loss: 0.0325 - val_r_square: 0.9672 - val_mean_absolute_error: 0.0962 - val_mean_squared_error: 0.0325
# train_shell :: TRAINING EPOCH 50/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 51/51
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0318 - r_square: 0.9684 - mean_absolute_error: 0.0951 - mean_squared_error: 0.0318 - val_loss: 0.0324 - val_r_square: 0.9672 - val_mean_absolute_error: 0.0960 - val_mean_squared_error: 0.0324
# train_shell :: TRAINING EPOCH 51/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 52/52
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0317 - r_square: 0.9684 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0317 - val_loss: 0.0324 - val_r_square: 0.9673 - val_mean_absolute_error: 0.0957 - val_mean_squared_error: 0.0324
# train_shell :: TRAINING EPOCH 52/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 53/53
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0316 - r_square: 0.9685 - mean_absolute_error: 0.0948 - mean_squared_error: 0.0316 - val_loss: 0.0323 - val_r_square: 0.9673 - val_mean_absolute_error: 0.0956 - val_mean_squared_error: 0.0323
# train_shell :: TRAINING EPOCH 53/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 54/54
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0316 - r_square: 0.9686 - mean_absolute_error: 0.0947 - mean_squared_error: 0.0316 - val_loss: 0.0323 - val_r_square: 0.9674 - val_mean_absolute_error: 0.0955 - val_mean_squared_error: 0.0323
# train_shell :: TRAINING EPOCH 54/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 55/55
# 245/245 [==============================] - 3s 13ms/step - loss: 0.0315 - r_square: 0.9686 - mean_absolute_error: 0.0944 - mean_squared_error: 0.0315 - val_loss: 0.0323 - val_r_square: 0.9674 - val_mean_absolute_error: 0.0958 - val_mean_squared_error: 0.0323
# train_shell :: TRAINING EPOCH 55/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 56/56
# 245/245 [==============================] - 3s 13ms/step - loss: 0.0315 - r_square: 0.9687 - mean_absolute_error: 0.0943 - mean_squared_error: 0.0315 - val_loss: 0.0322 - val_r_square: 0.9675 - val_mean_absolute_error: 0.0952 - val_mean_squared_error: 0.0322
# train_shell :: TRAINING EPOCH 56/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 57/57
# 245/245 [==============================] - 3s 13ms/step - loss: 0.0314 - r_square: 0.9687 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0314 - val_loss: 0.0321 - val_r_square: 0.9675 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.0321
# train_shell :: TRAINING EPOCH 57/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 58/58
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0314 - r_square: 0.9688 - mean_absolute_error: 0.0939 - mean_squared_error: 0.0314 - val_loss: 0.0321 - val_r_square: 0.9675 - val_mean_absolute_error: 0.0950 - val_mean_squared_error: 0.0321
# train_shell :: TRAINING EPOCH 58/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 59/59
# 245/245 [==============================] - 3s 14ms/step - loss: 0.0313 - r_square: 0.9688 - mean_absolute_error: 0.0938 - mean_squared_error: 0.0313 - val_loss: 0.0321 - val_r_square: 0.9676 - val_mean_absolute_error: 0.0950 - val_mean_squared_error: 0.0321
# train_shell :: TRAINING EPOCH 59/60
# Train on 7865 samples, validate on 3371 samples
# Epoch 60/60
# 245/245 [==============================] - 4s 15ms/step - loss: 0.0313 - r_square: 0.9689 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0313 - val_loss: 0.0320 - val_r_square: 0.9676 - val_mean_absolute_error: 0.0949 - val_mean_squared_error: 0.0320
# EPOCH N: 60 20
# train_shell ::
# train_shell :: trained 20 epochs!
# train_shell ::
# finished epoch N 60
# prev [40, 20]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*loss*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*r_square*", yscale="log")

# %% [markdown]
# checking results:

# %%
data_recon_norm = utils.data_table(autoencoder.predict(data.norm(**norm_args).df.values), headers=train_norm.headers)
data_recon = data.inorm(data_recon_norm, **norm_args)
data_recon.name = "all jet data (pred)"

# train_reconstructed_norm = data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
# test_reconstructed_norm = data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)

# train_reconstructed = data.inorm(train_reconstructed_norm)
# # test_reconstructed = data.inorm(test_reconstructed_norm)


# train_reconstructed.name = "train reconstructed"
# test_reconstructed.name = "test reconstructed"

# train.plot([train_reconstructed], bins = 30, alpha=1.0)
# test.plot([test_reconstructed], bins=30, alpha=1.0)
data.plot(
#     [train_reconstructed, test_reconstructed],
    data_recon,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
)

data.norm(**norm_args).plot(
    data_recon_norm,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'all jet data (pred)']
# data_table :: plotting distrubution(s) for table(s) ["'all jet data' normed to 'all jet data'", 'untitled 93']

# %%
encoder, decoder = autoencoder.layers[1:]
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), headers=["val {}".format(i + 1) for i in range(5)], name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), headers=["val {}".format(i + 1) for i in range(5)], name="test_reps")
)

# %%
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=1, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']

# %%
train_norm.data.shape
# Out:
# (7865, 7)
