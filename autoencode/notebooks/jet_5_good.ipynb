# %%
import autoencodeSVJ.utils as utils
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import glob
import os
import numpy as np

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
data,jet_tables = utils.get_training_data_jets("../../data/dijet_tight/*data.h5")
data.head()
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0.0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/dijet_tight/9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#      jetEta    jetPhi        jetPt        jetM  jetChargedFraction    jetPTD  \
# 0  0.391208  3.126895   880.629578   46.972202            0.941176  0.238104
# 1  0.226281  1.619783   839.069214   27.909035            0.631579  0.254852
# 2  1.215448  0.042642  1736.550293  164.827713            0.608696  0.418112
# 3 -0.121109 -1.891376   453.773132   62.488964            0.771429  0.162267
# 4  1.025759  3.117460   882.341492  160.383484            0.600000  0.215028
#
#    jetAxis2
# 0  0.041430
# 1  0.016366
# 2  0.006629
# 3  0.079624
# 4  0.021459

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
train, test = data.train_test_split(0.3)
data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train', 'test']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'jet 0', 'jet 1']

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
ntype="MinMaxScaler"
norm_data = data.norm(norm_type=ntype)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, rng=(0,1), figsize=(8,8), fontsize=10)

ntype="StandardScaler"
norm_data = data.norm(norm_type=ntype)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, rng=(-3,3), figsize=(8,8), fontsize=10)

norm_type="RobustScaler"
q_min = 40
quantile_range=(q_min,100-q_min)
norm_args = {
    "norm_type": norm_type,
    "quantile_range": quantile_range
}
norm_data = data.norm(**norm_args)
features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, rng=(-6,6))

# rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # norm_data = data.norm(norm_type=0, rng=rng)
# norm_data = custom_norm(data)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetM', 'jetChargedFraction', 'jetPTD', 'jetAxis2']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
train_norm, test_norm = data.norm(train, **norm_args), data.norm(test, **norm_args)
# print train_norm.shape, test_norm.shape
# train_norm, test_norm = (
#     utils.data_table(custom_norm(train), name="norm train", headers=train.headers),
#     utils.data_table(custom_norm(test), name="norm test", headers=test.headers),
# )

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(30)
ae_skeleton.add(5, 'relu')
ae_skeleton.add(30)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
name = "deep_5_good_test"
instance = trainer.trainer(os.path.join("../data/training_runs/7jf/", name))
# Out:
# h5_elt 'metric_names' :: creating group 'data' in file 'deep_5_good_test.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'deep_5_good_test.h5'
# h5_elt 'training' :: creating group 'params' in file 'deep_5_good_test.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'deep_5_good_test.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'deep_5_good_test.h5'

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 30)                240
# _________________________________________________________________
# layer_3 (Dense)              (None, 5)                 155
# =================================================================
# Total params: 395
# Trainable params: 395
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_3 (InputLayer)         (None, 5)                 0
# _________________________________________________________________
# layer_4 (Dense)              (None, 30)                180
# _________________________________________________________________
# layer_5 (Dense)              (None, 7)                 217
# =================================================================
# Total params: 397
# Trainable params: 397
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 5)                 395
# _________________________________________________________________
# decoder (Model)              (None, 7)                 397
# =================================================================
# Total params: 792
# Trainable params: 792
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss="mse",
    epochs=40,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=False,
    batch_size=128,
    use_callbacks=False,
    learning_rate=0.001
)
# Out:
# train_shell :: ERROR: IGNORING PASSED PARAMETER 'model'
# train_shell :: using saved model
# train_shell :: TRAINING EPOCH 40/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 41/41
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2358 - r_square: 0.9852 - mean_absolute_error: 0.3192 - mean_squared_error: 0.2358 - val_loss: 0.2253 - val_r_square: 0.9862 - val_mean_absolute_error: 0.3099 - val_mean_squared_error: 0.2253
# train_shell :: TRAINING EPOCH 41/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 42/42
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2290 - r_square: 0.9857 - mean_absolute_error: 0.3081 - mean_squared_error: 0.2290 - val_loss: 0.2240 - val_r_square: 0.9863 - val_mean_absolute_error: 0.3080 - val_mean_squared_error: 0.2240
# train_shell :: TRAINING EPOCH 42/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 43/43
# 61/61 [==============================] - 1s 14ms/step - loss: 0.2274 - r_square: 0.9858 - mean_absolute_error: 0.3060 - mean_squared_error: 0.2274 - val_loss: 0.2223 - val_r_square: 0.9864 - val_mean_absolute_error: 0.3057 - val_mean_squared_error: 0.2223
# train_shell :: TRAINING EPOCH 43/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 44/44
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2258 - r_square: 0.9859 - mean_absolute_error: 0.3037 - mean_squared_error: 0.2258 - val_loss: 0.2205 - val_r_square: 0.9865 - val_mean_absolute_error: 0.3032 - val_mean_squared_error: 0.2205
# train_shell :: TRAINING EPOCH 44/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 45/45
# 61/61 [==============================] - 1s 12ms/step - loss: 0.2241 - r_square: 0.9860 - mean_absolute_error: 0.3014 - mean_squared_error: 0.2241 - val_loss: 0.2187 - val_r_square: 0.9866 - val_mean_absolute_error: 0.3008 - val_mean_squared_error: 0.2187
# train_shell :: TRAINING EPOCH 45/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 46/46
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2224 - r_square: 0.9861 - mean_absolute_error: 0.2993 - mean_squared_error: 0.2224 - val_loss: 0.2168 - val_r_square: 0.9867 - val_mean_absolute_error: 0.2983 - val_mean_squared_error: 0.2168
# train_shell :: TRAINING EPOCH 46/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 47/47
# 61/61 [==============================] - 1s 12ms/step - loss: 0.2209 - r_square: 0.9862 - mean_absolute_error: 0.2970 - mean_squared_error: 0.2209 - val_loss: 0.2151 - val_r_square: 0.9868 - val_mean_absolute_error: 0.2957 - val_mean_squared_error: 0.2151
# train_shell :: TRAINING EPOCH 47/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 48/48
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2192 - r_square: 0.9863 - mean_absolute_error: 0.2947 - mean_squared_error: 0.2192 - val_loss: 0.2134 - val_r_square: 0.9869 - val_mean_absolute_error: 0.2932 - val_mean_squared_error: 0.2134
# train_shell :: TRAINING EPOCH 48/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 49/49
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2176 - r_square: 0.9864 - mean_absolute_error: 0.2925 - mean_squared_error: 0.2176 - val_loss: 0.2118 - val_r_square: 0.9870 - val_mean_absolute_error: 0.2909 - val_mean_squared_error: 0.2118
# train_shell :: TRAINING EPOCH 49/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 50/50
# 61/61 [==============================] - 1s 15ms/step - loss: 0.2160 - r_square: 0.9865 - mean_absolute_error: 0.2903 - mean_squared_error: 0.2160 - val_loss: 0.2101 - val_r_square: 0.9871 - val_mean_absolute_error: 0.2885 - val_mean_squared_error: 0.2101
# train_shell :: TRAINING EPOCH 50/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 51/51
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2146 - r_square: 0.9866 - mean_absolute_error: 0.2883 - mean_squared_error: 0.2146 - val_loss: 0.2088 - val_r_square: 0.9872 - val_mean_absolute_error: 0.2866 - val_mean_squared_error: 0.2088
# train_shell :: TRAINING EPOCH 51/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 52/52
# 61/61 [==============================] - 1s 13ms/step - loss: 0.2133 - r_square: 0.9866 - mean_absolute_error: 0.2865 - mean_squared_error: 0.2133 - val_loss: 0.2075 - val_r_square: 0.9873 - val_mean_absolute_error: 0.2850 - val_mean_squared_error: 0.2075
# train_shell :: TRAINING EPOCH 52/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 53/53
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2123 - r_square: 0.9867 - mean_absolute_error: 0.2849 - mean_squared_error: 0.2123 - val_loss: 0.2064 - val_r_square: 0.9874 - val_mean_absolute_error: 0.2830 - val_mean_squared_error: 0.2064
# train_shell :: TRAINING EPOCH 53/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 54/54
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2112 - r_square: 0.9868 - mean_absolute_error: 0.2834 - mean_squared_error: 0.2112 - val_loss: 0.2054 - val_r_square: 0.9874 - val_mean_absolute_error: 0.2817 - val_mean_squared_error: 0.2054
# train_shell :: TRAINING EPOCH 54/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 55/55
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2102 - r_square: 0.9868 - mean_absolute_error: 0.2821 - mean_squared_error: 0.2102 - val_loss: 0.2045 - val_r_square: 0.9875 - val_mean_absolute_error: 0.2802 - val_mean_squared_error: 0.2045
# train_shell :: TRAINING EPOCH 55/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 56/56
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2092 - r_square: 0.9869 - mean_absolute_error: 0.2808 - mean_squared_error: 0.2092 - val_loss: 0.2037 - val_r_square: 0.9875 - val_mean_absolute_error: 0.2791 - val_mean_squared_error: 0.2037
# train_shell :: TRAINING EPOCH 56/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 57/57
# 61/61 [==============================] - 1s 12ms/step - loss: 0.2083 - r_square: 0.9870 - mean_absolute_error: 0.2796 - mean_squared_error: 0.2083 - val_loss: 0.2029 - val_r_square: 0.9876 - val_mean_absolute_error: 0.2778 - val_mean_squared_error: 0.2029
# train_shell :: TRAINING EPOCH 57/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 58/58
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2074 - r_square: 0.9870 - mean_absolute_error: 0.2785 - mean_squared_error: 0.2074 - val_loss: 0.2022 - val_r_square: 0.9876 - val_mean_absolute_error: 0.2772 - val_mean_squared_error: 0.2022
# train_shell :: TRAINING EPOCH 58/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 59/59
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2065 - r_square: 0.9871 - mean_absolute_error: 0.2773 - mean_squared_error: 0.2065 - val_loss: 0.2015 - val_r_square: 0.9877 - val_mean_absolute_error: 0.2763 - val_mean_squared_error: 0.2015
# train_shell :: TRAINING EPOCH 59/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 60/60
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2057 - r_square: 0.9871 - mean_absolute_error: 0.2763 - mean_squared_error: 0.2057 - val_loss: 0.2007 - val_r_square: 0.9877 - val_mean_absolute_error: 0.2748 - val_mean_squared_error: 0.2007
# train_shell :: TRAINING EPOCH 60/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 61/61
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2050 - r_square: 0.9872 - mean_absolute_error: 0.2749 - mean_squared_error: 0.2050 - val_loss: 0.2000 - val_r_square: 0.9877 - val_mean_absolute_error: 0.2735 - val_mean_squared_error: 0.2000
# train_shell :: TRAINING EPOCH 61/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 62/62
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2042 - r_square: 0.9872 - mean_absolute_error: 0.2739 - mean_squared_error: 0.2042 - val_loss: 0.1994 - val_r_square: 0.9878 - val_mean_absolute_error: 0.2722 - val_mean_squared_error: 0.1994
# train_shell :: TRAINING EPOCH 62/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 63/63
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2035 - r_square: 0.9873 - mean_absolute_error: 0.2728 - mean_squared_error: 0.2035 - val_loss: 0.1988 - val_r_square: 0.9878 - val_mean_absolute_error: 0.2716 - val_mean_squared_error: 0.1988
# train_shell :: TRAINING EPOCH 63/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 64/64
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2029 - r_square: 0.9873 - mean_absolute_error: 0.2718 - mean_squared_error: 0.2029 - val_loss: 0.1982 - val_r_square: 0.9879 - val_mean_absolute_error: 0.2707 - val_mean_squared_error: 0.1982
# train_shell :: TRAINING EPOCH 64/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 65/65
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2023 - r_square: 0.9873 - mean_absolute_error: 0.2709 - mean_squared_error: 0.2023 - val_loss: 0.1977 - val_r_square: 0.9879 - val_mean_absolute_error: 0.2697 - val_mean_squared_error: 0.1977
# train_shell :: TRAINING EPOCH 65/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 66/66
# 61/61 [==============================] - 1s 11ms/step - loss: 0.2017 - r_square: 0.9874 - mean_absolute_error: 0.2699 - mean_squared_error: 0.2017 - val_loss: 0.1972 - val_r_square: 0.9879 - val_mean_absolute_error: 0.2685 - val_mean_squared_error: 0.1972
# train_shell :: TRAINING EPOCH 66/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 67/67
# 61/61 [==============================] - 1s 10ms/step - loss: 0.2011 - r_square: 0.9874 - mean_absolute_error: 0.2690 - mean_squared_error: 0.2011 - val_loss: 0.1967 - val_r_square: 0.9879 - val_mean_absolute_error: 0.2675 - val_mean_squared_error: 0.1967
# train_shell :: TRAINING EPOCH 67/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 68/68
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2005 - r_square: 0.9874 - mean_absolute_error: 0.2682 - mean_squared_error: 0.2005 - val_loss: 0.1963 - val_r_square: 0.9880 - val_mean_absolute_error: 0.2671 - val_mean_squared_error: 0.1963
# train_shell :: TRAINING EPOCH 68/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 69/69
# 61/61 [==============================] - 1s 9ms/step - loss: 0.2000 - r_square: 0.9875 - mean_absolute_error: 0.2672 - mean_squared_error: 0.2000 - val_loss: 0.1959 - val_r_square: 0.9880 - val_mean_absolute_error: 0.2660 - val_mean_squared_error: 0.1959
# train_shell :: TRAINING EPOCH 69/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 70/70
# 61/61 [==============================] - 1s 9ms/step - loss: 0.1996 - r_square: 0.9875 - mean_absolute_error: 0.2668 - mean_squared_error: 0.1996 - val_loss: 0.1956 - val_r_square: 0.9880 - val_mean_absolute_error: 0.2655 - val_mean_squared_error: 0.1956
# train_shell :: TRAINING EPOCH 70/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 71/71
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1992 - r_square: 0.9875 - mean_absolute_error: 0.2659 - mean_squared_error: 0.1992 - val_loss: 0.1953 - val_r_square: 0.9880 - val_mean_absolute_error: 0.2653 - val_mean_squared_error: 0.1953
# train_shell :: TRAINING EPOCH 71/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 72/72
# 61/61 [==============================] - 1s 9ms/step - loss: 0.1987 - r_square: 0.9876 - mean_absolute_error: 0.2652 - mean_squared_error: 0.1987 - val_loss: 0.1954 - val_r_square: 0.9880 - val_mean_absolute_error: 0.2670 - val_mean_squared_error: 0.1954
# train_shell :: TRAINING EPOCH 72/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 73/73
# 61/61 [==============================] - 1s 8ms/step - loss: 0.1984 - r_square: 0.9876 - mean_absolute_error: 0.2649 - mean_squared_error: 0.1984 - val_loss: 0.1946 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2639 - val_mean_squared_error: 0.1946
# train_shell :: TRAINING EPOCH 73/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 74/74
# 61/61 [==============================] - 1s 9ms/step - loss: 0.1981 - r_square: 0.9876 - mean_absolute_error: 0.2641 - mean_squared_error: 0.1981 - val_loss: 0.1945 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2636 - val_mean_squared_error: 0.1945
# train_shell :: TRAINING EPOCH 74/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 75/75
# 61/61 [==============================] - 1s 8ms/step - loss: 0.1978 - r_square: 0.9876 - mean_absolute_error: 0.2638 - mean_squared_error: 0.1978 - val_loss: 0.1941 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2630 - val_mean_squared_error: 0.1941
# train_shell :: TRAINING EPOCH 75/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 76/76
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1974 - r_square: 0.9876 - mean_absolute_error: 0.2629 - mean_squared_error: 0.1974 - val_loss: 0.1939 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2626 - val_mean_squared_error: 0.1939
# train_shell :: TRAINING EPOCH 76/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 77/77
# 61/61 [==============================] - 1s 10ms/step - loss: 0.1972 - r_square: 0.9877 - mean_absolute_error: 0.2625 - mean_squared_error: 0.1972 - val_loss: 0.1940 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2631 - val_mean_squared_error: 0.1940
# train_shell :: TRAINING EPOCH 77/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 78/78
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1969 - r_square: 0.9877 - mean_absolute_error: 0.2619 - mean_squared_error: 0.1969 - val_loss: 0.1944 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2631 - val_mean_squared_error: 0.1944
# train_shell :: TRAINING EPOCH 78/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 79/79
# 61/61 [==============================] - 1s 11ms/step - loss: 0.1966 - r_square: 0.9877 - mean_absolute_error: 0.2616 - mean_squared_error: 0.1966 - val_loss: 0.1936 - val_r_square: 0.9881 - val_mean_absolute_error: 0.2629 - val_mean_squared_error: 0.1936
# train_shell :: TRAINING EPOCH 79/80
# Train on 7865 samples, validate on 3371 samples
# Epoch 80/80
# 61/61 [==============================] - 1s 9ms/step - loss: 0.1963 - r_square: 0.9877 - mean_absolute_error: 0.2610 - mean_squared_error: 0.1963 - val_loss: 0.1933 - val_r_square: 0.9882 - val_mean_absolute_error: 0.2614 - val_mean_squared_error: 0.1933
# EPOCH N: 80 40
# train_shell ::
# train_shell :: trained 40 epochs!
# train_shell ::
# finished epoch N 80
# prev [40, 40]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*loss*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*r_square*", yscale="log")

# %% [markdown]
# checking results:

# %%
data_recon_norm = utils.data_table(autoencoder.predict(data.norm(**norm_args).df.values), headers=train_norm.headers)
data_recon = data.inorm(data_recon_norm, **norm_args)
data_recon.name = "all jet data (pred)"

# train_reconstructed_norm = data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
# test_reconstructed_norm = data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)

# train_reconstructed = data.inorm(train_reconstructed_norm)
# # test_reconstructed = data.inorm(test_reconstructed_norm)


# train_reconstructed.name = "train reconstructed"
# test_reconstructed.name = "test reconstructed"

# train.plot([train_reconstructed], bins = 30, alpha=1.0)
# test.plot([test_reconstructed], bins=30, alpha=1.0)
data.plot(
#     [train_reconstructed, test_reconstructed],
    data_recon,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
)

data.norm(**norm_args).plot(
    data_recon_norm,
    normed=0, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'all jet data (pred)']
# data_table :: plotting distrubution(s) for table(s) ["'all jet data' normed to 'all jet data'", 'untitled 130']

# %%
encoder, decoder = autoencoder.layers[1:]
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), name="test_reps")
)

# %%
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=1, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']
