# %%
import autoencodeSVJ.utils as utils

version = 'v1'
hlf = True
eflow = True
eflow_base = 3
signal_path = "data/signal/base_{}/*.h5".format(eflow_base)
qcd_path = "data/background/base_{}/*.h5".format(eflow_base)

(signal,
 signal_jets,
 signal_event,
 signal_flavor) = utils.load_all_data(
    signal_path,
    "signal", include_hlf=hlf, include_eflow=eflow
)

(qcd,
 qcd_jets,
 qcd_event,
 qcd_flavor) = utils.load_all_data(
    qcd_path, 
    "qcd background", include_hlf=hlf, include_eflow=eflow
)

# %% [markdown]
# ### data checking, etc.
# uncomment the following lines to see training and signal data comparisons. commented out for simplicity here

# %%
# utils.jet_flavor_check(qcd_flavor)
# utils.jet_flavor_check(signal_flavor)

# signal.plot(utils.jet_flavor_split(qcd, qcd_flavor), normed='n', figname='signal vs. different jet signals', bins=50, figsize=20)

# %%
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import os

seed = 40

import numpy as np
import tensorflow as tf

np.random.seed(seed)
tf.set_random_seed(seed)

target_dim = 10
input_dim = len(signal.columns)
test_split = 0.15
val_split = 0.15

filename = "{}{}{}_{}".format('hlf_' if hlf else '', 'eflow{}_'.format(eflow_base) if eflow else '', target_dim, version)

norm_args = {
    "norm_type": "StandardScaler"
}

data_args = {
    'target_dim': target_dim,
    'input_dim': input_dim,
    'test_split': test_split,
    'val_split': val_split,
    'hlf': hlf, 
    'eflow': eflow,
    'eflow_base': eflow_base,
    'seed': seed,
    'filename': filename,
    'filepath': os.path.abspath(filename),
    'signal_path': signal_path,
    'qcd_path': qcd_path,
}

custom_objects = {
    
}

all_train, test = qcd.train_test_split(test_split, seed)
train, val = all_train.train_test_split(val_split, seed)

train_norm = train.norm(out_name="qcd train norm", **norm_args)
val_norm = train.norm(val, out_name="qcd val norm", **norm_args)
 
test_norm = test.norm(out_name="qcd test norm", **norm_args)
signal_norm = signal.norm(out_name="signal norm", **norm_args)

train.name = "qcd training data"
test.name = "qcd test data"
val.name = "qcd validation data"

instance = trainer.trainer(filename)

aes = models.base_autoencoder()
aes.add(input_dim)
aes.add(30, activation='relu')
aes.add(30, activation='relu')
aes.add(target_dim, activation='relu')
aes.add(30, activation='relu')
aes.add(30, activation='relu')
aes.add(input_dim, activation='linear')

ae = aes.build()
ae.summary()
# Out:
# h5_elt 'metric_names' :: creating group 'data' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'training' :: creating group 'params' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'hlf_eflow3_10_v1.h5'
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 19)                0
# _________________________________________________________________
# encoder (Model)              (None, 10)                1840
# _________________________________________________________________
# decoder (Model)              (None, 19)                1849
# =================================================================
# Total params: 3,689
# Trainable params: 3,689
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# commented plot; this shows training, testing, and validation dataset comparisons

# %%
# train.plot([val,test], normed=1, figname='training, testing, and evaluation qcd data', bins=60)

# %%
train_args = {
    'batch_size': 64, 
    'loss': 'mse', 
    'optimizer': 'adam',
    'epochs': 100,
    'learning_rate': 0.0005,
}

do_train = True
if do_train:
    ae = instance.train(
        x_train=train_norm.data,
        x_test=val_norm.data,
        y_train=train_norm.data,
        y_test=val_norm.data,
        model=ae,
        force=True,
        use_callbacks=True,
        custom_objects=custom_objects, 
        **train_args
    )
else:
    ae = instance.load_model(custom_objects=custom_objects)
# Out:
# Train on 74717 samples, validate on 13186 samples
# Epoch 1/100
# 74717/74717 [==============================] - 3s 40us/step - loss: 0.1638 - val_loss: 0.0255
# Epoch 2/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 0.0154 - val_loss: 0.0099
# Epoch 3/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 4/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 0.0045 - val_loss: 0.0035
# Epoch 5/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 6/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 7/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 8/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 9/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 0.0010 - val_loss: 8.0423e-04
# Epoch 10/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 9.1668e-04 - val_loss: 9.2987e-04
# Epoch 11/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 8.1870e-04 - val_loss: 6.8924e-04
# Epoch 12/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 7.4324e-04 - val_loss: 0.0013
# Epoch 13/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 6.8613e-04 - val_loss: 0.0010
# Epoch 14/100
# 74717/74717 [==============================] - 3s 34us/step - loss: 6.6325e-04 - val_loss: 5.8784e-04
# Epoch 15/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 6.1657e-04 - val_loss: 5.0965e-04
# Epoch 16/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 6.0081e-04 - val_loss: 5.8349e-04
# Epoch 17/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 5.5883e-04 - val_loss: 5.3871e-04
# Epoch 18/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 6.0773e-04 - val_loss: 4.3264e-04
# Epoch 19/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 4.8719e-04 - val_loss: 5.1733e-04
# Epoch 20/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 4.9801e-04 - val_loss: 5.5646e-04
# Epoch 21/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 4.8498e-04 - val_loss: 4.2027e-04
# Epoch 22/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 4.9482e-04 - val_loss: 0.0013
# Epoch 23/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 4.6879e-04 - val_loss: 7.1466e-04
# Epoch 24/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 4.4224e-04 - val_loss: 3.8205e-04
# Epoch 25/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 3.0253e-04 - val_loss: 2.9767e-04
# Epoch 26/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 3.0188e-04 - val_loss: 2.9891e-04
# Epoch 27/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 3.0053e-04 - val_loss: 2.9312e-04
# Epoch 28/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.9856e-04 - val_loss: 3.1503e-04
# Epoch 29/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.9421e-04 - val_loss: 2.8676e-04
# Epoch 30/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.9097e-04 - val_loss: 2.8432e-04
# Epoch 31/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 2.8799e-04 - val_loss: 2.7888e-04
# Epoch 32/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7409e-04 - val_loss: 2.7169e-04
# Epoch 33/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7388e-04 - val_loss: 2.7149e-04
# Epoch 34/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7342e-04 - val_loss: 2.7119e-04
# Epoch 35/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 2.7291e-04 - val_loss: 2.7073e-04
# Epoch 36/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7216e-04 - val_loss: 2.7006e-04
# Epoch 37/100
# 74717/74717 [==============================] - 3s 34us/step - loss: 2.7078e-04 - val_loss: 2.6957e-04
# Epoch 38/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7065e-04 - val_loss: 2.6908e-04
# Epoch 39/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7059e-04 - val_loss: 2.6915e-04
# Epoch 40/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7050e-04 - val_loss: 2.6900e-04
# Epoch 41/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 2.7044e-04 - val_loss: 2.6901e-04
# Epoch 42/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7030e-04 - val_loss: 2.6885e-04
# Epoch 43/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7025e-04 - val_loss: 2.6883e-04
# Epoch 44/100
# 74717/74717 [==============================] - 3s 35us/step - loss: 2.7024e-04 - val_loss: 2.6882e-04
# Epoch 45/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 2.7023e-04 - val_loss: 2.6882e-04
# Epoch 46/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7022e-04 - val_loss: 2.6883e-04
# Epoch 47/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 48/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 49/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 50/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 51/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 52/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 53/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# Epoch 54/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 2.7020e-04 - val_loss: 2.6883e-04
# EPOCH N: 100 100
# train_shell ::
# train_shell :: trained 54 epochs!
# train_shell ::
# h5_elt 'loss' :: creating group 'metric_names' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'loss' :: creating dataset 'metric_names/loss' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'lr' :: creating dataset 'metric_names/lr' in file 'hlf_eflow3_10_v1.h5'
# h5_elt 'val_loss' :: creating dataset 'metric_names/val_loss' in file 'hlf_eflow3_10_v1.h5'
# finished epoch N 54
# prev [54]
# train_shell :: model saved

# %%
instance.plot_metrics(figsize=(8,5), figname="metrics", yscale='linear', figloc='upper right')

# %% [markdown]
# ### get reconstructions, errors, and node representatives

# %%
[data_err, signal_err], [data_recon, signal_recon] = utils.get_recon_errors([test_norm, signal_norm], ae)

data_reps = utils.data_table(ae.layers[1].predict(test_norm.data), name='background reps')
signal_reps = utils.data_table(ae.layers[1].predict(signal_norm.data), name='signal reps')

# %%
data_recon.plot(test_norm, figname='qcd reconstructions', cols=5)
signal_recon.plot(signal_norm, figname='signal reconstructions', cols=5)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['qcd test norm pred', 'qcd test norm']
# data_table :: plotting distrubution(s) for table(s) ['signal norm pred', 'signal norm']

# %%
data_reps.plot(signal_reps, alpha=1, normed=1, figname='node reps', figsize=10, figloc='upper right', cols=4)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['background reps', 'signal reps']

# %%
data_err.plot(
    signal_err, figsize=15, normed='n', 
    figname='error for eflow variables', 
    yscale='linear', rng=((0, 0.08), (0, 0.3)), 
    figloc="upper right", bins=80,
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['qcd test norm error', 'signal norm error']

# %%
utils.roc_auc_plot(data_err, signal_err, metrics=['mae', 'mse'], figsize=8, figname='ROC (hlf & eflow with $d\leq4$)', figloc=(0.3, 0.2))
roc_dict = utils.roc_auc_dict(data_err, signal_err, metrics=['mae', 'mse']).values()[0]
result_args = dict([(r + '_auc', roc_dict[r]['auc']) for r in roc_dict])

# %%
utils.dump_summary_json(result_args, train_args, norm_args, data_args)
# Out:
# mse_auc : 0.981749996317
# mae_auc : 0.982155088238
# epochs : 100
# loss : mse
# learning_rate : 0.0005
# optimizer : adam
# batch_size : 64
# norm_type : StandardScaler
# seed : 40
# target_dim : 10
# eflow_base : 3
# hlf : True
# qcd_path : data/background/base_3/*.h5
# test_split : 0.15
# val_split : 0.15
# filepath : /afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/autoencode/notebooks/ae/eflow/hlf_eflow3_10_v1
# eflow : True
# filename : hlf_eflow3_10_v1
# signal_path : data/signal/base_3/*.h5
# input_dim : 19
#
# successfully dumped size-21 summary dict to file '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/autoencode/data/summary/hlf_eflow3_10_v1.summary'
