# %%
import autoencodeSVJ.utils as utils

version = 'v1'
hlf = False
eflow = True
eflow_base = 3
signal_path = "data/signal/base_{}/*.h5".format(eflow_base)
qcd_path = "data/background/base_{}/*.h5".format(eflow_base)

(signal,
 signal_jets,
 signal_event,
 signal_flavor) = utils.load_all_data(
    signal_path,
    "signal", include_hlf=hlf, include_eflow=eflow
)

(qcd,
 qcd_jets,
 qcd_event,
 qcd_flavor) = utils.load_all_data(
    qcd_path, 
    "qcd background", include_hlf=hlf, include_eflow=eflow
)

# %% [markdown]
# ### data checking, etc.
# uncomment the following lines to see training and signal data comparisons. commented out for simplicity here

# %%
# utils.jet_flavor_check(qcd_flavor)
# utils.jet_flavor_check(signal_flavor)

# signal.plot(utils.jet_flavor_split(qcd, qcd_flavor), normed='n', figname='signal vs. different jet signals', bins=50, figsize=20)

# %%
import autoencodeSVJ.models as models
import autoencodeSVJ.trainer as trainer
import os

seed = 40

import numpy as np
import tensorflow as tf

np.random.seed(seed)
tf.set_random_seed(seed)

target_dim = 8
input_dim = len(signal.columns)
test_split = 0.15
val_split = 0.15

filename = "{}{}{}_{}".format('hlf_' if hlf else '', 'eflow{}_'.format(eflow_base) if eflow else '', target_dim, version)

norm_args = {
    "norm_type": "StandardScaler"
}

data_args = {
    'target_dim': target_dim,
    'input_dim': input_dim,
    'test_split': test_split,
    'val_split': val_split,
    'hlf': hlf, 
    'eflow': eflow,
    'eflow_base': eflow_base,
    'seed': seed,
    'filename': filename,
    'filepath': os.path.abspath(filename),
    'signal_path': signal_path,
    'qcd_path': qcd_path,
}
custom_objects = {
    
}

all_train, test = qcd.train_test_split(test_split, seed)
train, val = all_train.train_test_split(val_split, seed)

train_norm = train.norm(out_name="qcd train norm", **norm_args)
val_norm = train.norm(val, out_name="qcd val norm", **norm_args)
 
test_norm = test.norm(out_name="qcd test norm", **norm_args)
signal_norm = signal.norm(out_name="signal norm", **norm_args)

train.name = "qcd training data"
test.name = "qcd test data"
val.name = "qcd validation data"

instance = trainer.trainer(filename)

aes = models.base_autoencoder()
aes.add(input_dim)
aes.add(30, activation='relu')
aes.add(30, activation='relu')
aes.add(target_dim, activation='relu')
aes.add(30, activation='relu')
aes.add(30, activation='relu')
aes.add(input_dim, activation='linear')

ae = aes.build()
ae.summary()
# Out:
# Using TensorFlow backend.
# h5_elt 'metric_names' :: creating group 'data' in file 'eflow3_8_v1.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'eflow3_8_v1.h5'
# h5_elt 'training' :: creating group 'params' in file 'eflow3_8_v1.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'eflow3_8_v1.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'eflow3_8_v1.h5'
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 12)                0
# _________________________________________________________________
# encoder (Model)              (None, 8)                 1568
# _________________________________________________________________
# decoder (Model)              (None, 12)                1572
# =================================================================
# Total params: 3,140
# Trainable params: 3,140
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# commented plot; this shows training, testing, and validation dataset comparisons

# %%
# train.plot([val,test], normed=1, figname='training, testing, and evaluation qcd data', bins=60)

# %%
train_args = {
    'batch_size': 64, 
    'loss': 'mse', 
    'optimizer': 'adam',
    'epochs': 100,
    'learning_rate': 0.0005,
}

do_train = False
if do_train:
    ae = instance.train(
        x_train=train_norm.data,
        x_test=val_norm.data,
        y_train=train_norm.data,
        y_test=val_norm.data,
        model=ae,
        force=True,
        use_callbacks=True,
        custom_objects=custom_objects, 
        **train_args
    )
else:
    ae = instance.load_model(custom_objects=custom_objects)
# Out:
# Train on 74717 samples, validate on 13186 samples
# Epoch 1/100
# 74717/74717 [==============================] - 3s 35us/step - loss: 0.0905 - val_loss: 0.0040
# Epoch 2/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 0.0016 - val_loss: 6.8030e-04
# Epoch 3/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 5.0850e-04 - val_loss: 3.9567e-04
# Epoch 4/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 3.3960e-04 - val_loss: 2.5315e-04
# Epoch 5/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 2.4066e-04 - val_loss: 1.9189e-04
# Epoch 6/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 2.3261e-04 - val_loss: 1.9636e-04
# Epoch 7/100
# 74717/74717 [==============================] - 2s 28us/step - loss: 2.0538e-04 - val_loss: 1.6303e-04
# Epoch 8/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 2.0508e-04 - val_loss: 1.6776e-04
# Epoch 9/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.7239e-04 - val_loss: 1.5982e-04
# Epoch 10/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.7785e-04 - val_loss: 1.8791e-04
# Epoch 11/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 1.2016e-04 - val_loss: 1.1785e-04
# Epoch 12/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.1835e-04 - val_loss: 1.2320e-04
# Epoch 13/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.1626e-04 - val_loss: 1.1584e-04
# Epoch 14/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 1.1472e-04 - val_loss: 1.1221e-04
# Epoch 15/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.1214e-04 - val_loss: 1.0890e-04
# Epoch 16/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.1018e-04 - val_loss: 1.0858e-04
# Epoch 17/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0807e-04 - val_loss: 1.0708e-04
# Epoch 18/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 1.0278e-04 - val_loss: 1.0238e-04
# Epoch 19/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 1.0241e-04 - val_loss: 1.0277e-04
# Epoch 20/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 1.0214e-04 - val_loss: 1.0193e-04
# Epoch 21/100
# 74717/74717 [==============================] - 3s 34us/step - loss: 1.0186e-04 - val_loss: 1.0178e-04
# Epoch 22/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0154e-04 - val_loss: 1.0163e-04
# Epoch 23/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.0106e-04 - val_loss: 1.0128e-04
# Epoch 24/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.0096e-04 - val_loss: 1.0110e-04
# Epoch 25/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0092e-04 - val_loss: 1.0107e-04
# Epoch 26/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0088e-04 - val_loss: 1.0107e-04
# Epoch 27/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 1.0086e-04 - val_loss: 1.0106e-04
# Epoch 28/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.0080e-04 - val_loss: 1.0101e-04
# Epoch 29/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0079e-04 - val_loss: 1.0101e-04
# Epoch 30/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0078e-04 - val_loss: 1.0100e-04
# Epoch 31/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0078e-04 - val_loss: 1.0099e-04
# Epoch 32/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0078e-04 - val_loss: 1.0099e-04
# Epoch 33/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 34/100
# 74717/74717 [==============================] - 2s 33us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 35/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 36/100
# 74717/74717 [==============================] - 2s 31us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 37/100
# 74717/74717 [==============================] - 2s 32us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 38/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 39/100
# 74717/74717 [==============================] - 2s 29us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 40/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# Epoch 41/100
# 74717/74717 [==============================] - 2s 30us/step - loss: 1.0077e-04 - val_loss: 1.0099e-04
# EPOCH N: 100 100
# train_shell ::
# train_shell :: trained 41 epochs!
# train_shell ::
# h5_elt 'loss' :: creating group 'metric_names' in file 'eflow3_8_v1.h5'
# h5_elt 'loss' :: creating dataset 'metric_names/loss' in file 'eflow3_8_v1.h5'
# h5_elt 'lr' :: creating dataset 'metric_names/lr' in file 'eflow3_8_v1.h5'
# h5_elt 'val_loss' :: creating dataset 'metric_names/val_loss' in file 'eflow3_8_v1.h5'
# finished epoch N 41
# prev [41]
# train_shell :: model saved

# %%
instance.plot_metrics(figsize=(8,5), figname="metrics", yscale='log', figloc='upper right')

# %% [markdown]
# ### get reconstructions, errors, and node representatives

# %%
[data_err, signal_err], [data_recon, signal_recon] = utils.get_recon_errors([test_norm, signal_norm], ae)

data_reps = utils.data_table(ae.layers[1].predict(test_norm.data), name='background reps')
signal_reps = utils.data_table(ae.layers[1].predict(signal_norm.data), name='signal reps')

# %%
data_recon.plot(test_norm, figname='qcd reconstructions', cols=5)
signal_recon.plot(signal_norm, figname='signal reconstructions', cols=5)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['qcd test norm pred', 'qcd test norm']
# data_table :: plotting distrubution(s) for table(s) ['signal norm pred', 'signal norm']

# %%
data_reps.plot(signal_reps, alpha=1, normed=1, figname='node reps', figsize=10, figloc='upper right', cols=4)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['background reps', 'signal reps']

# %%
data_err.plot(
    signal_err, figsize=15, normed='n', 
    figname='error for eflow variables', 
    yscale='linear', rng=((0, 0.08), (0, 0.3)), 
    figloc="upper right"
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['qcd test norm error', 'signal norm error']

# %%
utils.roc_auc_plot(data_err, signal_err, metrics=['mae', 'mse'], figsize=8, figname='ROC (hlf & eflow with $d\leq4$)', figloc=(0.3, 0.2))
roc_dict = utils.roc_auc_dict(data_err, signal_err, metrics=['mae', 'mse']).values()[0]
result_args = dict([(r + '_auc', roc_dict[r]['auc']) for r in roc_dict])

# %%
utils.dump_summary_json(result_args, train_args, norm_args, data_args)
# Out:
# mse_auc : 0.995133771593
# mae_auc : 0.995048491756
# epochs : 100
# loss : mse
# learning_rate : 0.0005
# optimizer : adam
# batch_size : 64
# norm_type : StandardScaler
# seed : 40
# input_dim : 12
# target_dim : 8
# test_split : 0.15
# hlf : False
# val_split : 0.15
# filepath : /afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/autoencode/notebooks/ae/eflow/eflow3_8_v1
# eflow : True
# eflow_base : 3
# filename : eflow3_8_v1
#
# successfully dumped size-19 summary dict to file '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/autoencode/data/summary/eflow3_8_v1.summary'
