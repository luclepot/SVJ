# %%
from autoencodeSVJ import utils, models, trainer
import glob
import os
import numpy as np
import keras
import keras.backend as K
import matplotlib.pyplot as plt

version_id = 'v5'
SEED = 42
# Out:
# Using TensorFlow backend.

# %%
# get h5 datasets
data_path = "data/background/*_data.h5"
signal_path = "data/signal/*_data.h5"

data, data_tags, data_jets = utils.load_all_data(data_path, "background")
signal, signal_tags, signal_jets = utils.load_all_data(signal_path, "signal")

split = 0.25

train, test = data.train_test_split(split, SEED)
utils.compare_tags([train, test, data, signal])

data_raw = data.cdrop("*Flavor")
signal_raw = signal.cdrop("*Flavor")
train_raw = train.cdrop("*Flavor")
test_raw = test.cdrop("*Flavor")

norm_args = {"norm_type": "StandardScaler"}
train_norm, test_norm = train_raw.norm(**norm_args), train_raw.norm(test_raw, **norm_args)
data_norm, signal_norm = train_raw.norm(data_raw, **norm_args), train_raw.norm(signal_raw, **norm_args)
# Out:
# background tags:
#
# down jet: 18999, 18.4%
# up jet: 38841, 37.6%
# strange jet: 25377, 24.5%
# charm jet: 9577, 9.3%
# bottom jet: 3341, 3.2%
# gluon jet: 7281, 7.0%
#
# signal tags:
#
# down jet: 1220, 2.5%
# up jet: 1866, 3.8%
# strange jet: 1550, 3.1%
# charm jet: 3344, 6.8%
# bottom jet: 38995, 78.8%
# gluon jet: 2541, 5.1%
#
# bottom:
# 	3.2% (2504) train
# 	3.2% (837) test
# 	3.2% (3341) background
# 	78.8% (38995) signal
# up:
# 	37.4% (29023) train
# 	38.0% (9818) test
# 	37.6% (38841) background
# 	3.8% (1866) signal
# down:
# 	18.4% (14251) train
# 	18.4% (4748) test
# 	18.4% (18999) background
# 	2.5% (1220) signal
# strange:
# 	24.7% (19123) train
# 	24.2% (6254) test
# 	24.5% (25377) background
# 	3.1% (1550) signal
# charm:
# 	9.2% (7151) train
# 	9.4% (2426) test
# 	9.3% (9577) background
# 	6.8% (3344) signal
# gluon:
# 	7.1% (5510) train
# 	6.9% (1771) test
# 	7.0% (7281) background
# 	5.1% (2541) signal

# %%
bn = 2
name = "bn_{0}_{1}".format(bn, version_id)
repo_head = utils.get_repo_info()['head']
model_path = repo_head + "/autoencode/data/training_runs/"

ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(100)
ae_skeleton.add(100)
ae_skeleton.add(bn, 'relu')
ae_skeleton.add(100)
ae_skeleton.add(100)
ae_skeleton.add(7, "linear")

autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
instance = trainer.trainer(os.path.join(model_path, name))
autoencoder.summary()
# Out:
# h5_elt 'metric_names' :: creating group 'data' in file 'bn_2_v5.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'bn_2_v5.h5'
# h5_elt 'training' :: creating group 'params' in file 'bn_2_v5.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'bn_2_v5.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'bn_2_v5.h5'
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 2)                 11102
# _________________________________________________________________
# decoder (Model)              (None, 7)                 11107
# =================================================================
# Total params: 22,209
# Trainable params: 22,209
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_np(true, pred):
    SS_res = np.sum(np.square(true - pred), axis=1)
    SS_tot = np.sum(np.square(true - np.mean(true, axis=0)), axis=1)
    return 1. - SS_res/SS_tot

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss='mae',
    epochs=50,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=True,
    batch_size=64,
    use_callbacks=True,
    learning_rate=0.001
)
# Out:
# train_shell :: using model passed as function argument
# Train on 77562 samples, validate on 25854 samples
# Epoch 105/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1764 - r_square: 0.9213 - mean_absolute_error: 0.1764 - mean_squared_error: 0.0787 - val_loss: 0.1780 - val_r_square: 0.9182 - val_mean_absolute_error: 0.1780 - val_mean_squared_error: 0.0817
# Epoch 106/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1752 - r_square: 0.9220 - mean_absolute_error: 0.1752 - mean_squared_error: 0.0780 - val_loss: 0.1781 - val_r_square: 0.9195 - val_mean_absolute_error: 0.1781 - val_mean_squared_error: 0.0804
# Epoch 107/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1751 - r_square: 0.9216 - mean_absolute_error: 0.1751 - mean_squared_error: 0.0784 - val_loss: 0.1776 - val_r_square: 0.9180 - val_mean_absolute_error: 0.1776 - val_mean_squared_error: 0.0818
# Epoch 108/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1748 - r_square: 0.9217 - mean_absolute_error: 0.1748 - mean_squared_error: 0.0783 - val_loss: 0.1779 - val_r_square: 0.9162 - val_mean_absolute_error: 0.1779 - val_mean_squared_error: 0.0836
# Epoch 109/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1750 - r_square: 0.9219 - mean_absolute_error: 0.1750 - mean_squared_error: 0.0781 - val_loss: 0.1784 - val_r_square: 0.9176 - val_mean_absolute_error: 0.1784 - val_mean_squared_error: 0.0823
# Epoch 110/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1749 - r_square: 0.9227 - mean_absolute_error: 0.1749 - mean_squared_error: 0.0773 - val_loss: 0.1788 - val_r_square: 0.9168 - val_mean_absolute_error: 0.1788 - val_mean_squared_error: 0.0831
# Epoch 111/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1747 - r_square: 0.9225 - mean_absolute_error: 0.1747 - mean_squared_error: 0.0775 - val_loss: 0.1771 - val_r_square: 0.9173 - val_mean_absolute_error: 0.1771 - val_mean_squared_error: 0.0826
# Epoch 112/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1736 - r_square: 0.9230 - mean_absolute_error: 0.1736 - mean_squared_error: 0.0770 - val_loss: 0.1770 - val_r_square: 0.9170 - val_mean_absolute_error: 0.1770 - val_mean_squared_error: 0.0828
# Epoch 113/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1732 - r_square: 0.9230 - mean_absolute_error: 0.1732 - mean_squared_error: 0.0770 - val_loss: 0.1758 - val_r_square: 0.9186 - val_mean_absolute_error: 0.1758 - val_mean_squared_error: 0.0813
# Epoch 114/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1729 - r_square: 0.9230 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0770 - val_loss: 0.1761 - val_r_square: 0.9186 - val_mean_absolute_error: 0.1761 - val_mean_squared_error: 0.0813
# Epoch 115/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1729 - r_square: 0.9225 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0775 - val_loss: 0.1758 - val_r_square: 0.9174 - val_mean_absolute_error: 0.1758 - val_mean_squared_error: 0.0825
# Epoch 116/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1729 - r_square: 0.9223 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0777 - val_loss: 0.1753 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1753 - val_mean_squared_error: 0.0808
# Epoch 117/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1732 - r_square: 0.9229 - mean_absolute_error: 0.1732 - mean_squared_error: 0.0771 - val_loss: 0.1765 - val_r_square: 0.9187 - val_mean_absolute_error: 0.1765 - val_mean_squared_error: 0.0812
# Epoch 118/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1729 - r_square: 0.9233 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0767 - val_loss: 0.1744 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1744 - val_mean_squared_error: 0.0807
# Epoch 119/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1716 - r_square: 0.9232 - mean_absolute_error: 0.1716 - mean_squared_error: 0.0768 - val_loss: 0.1738 - val_r_square: 0.9196 - val_mean_absolute_error: 0.1738 - val_mean_squared_error: 0.0802
# Epoch 120/154
# 1211/1211 [==============================] - 139s 115ms/step - loss: 0.1726 - r_square: 0.9233 - mean_absolute_error: 0.1726 - mean_squared_error: 0.0767 - val_loss: 0.1756 - val_r_square: 0.9190 - val_mean_absolute_error: 0.1756 - val_mean_squared_error: 0.0808
# Epoch 121/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1730 - r_square: 0.9234 - mean_absolute_error: 0.1730 - mean_squared_error: 0.0766 - val_loss: 0.1755 - val_r_square: 0.9208 - val_mean_absolute_error: 0.1755 - val_mean_squared_error: 0.0790
# Epoch 122/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1726 - r_square: 0.9240 - mean_absolute_error: 0.1726 - mean_squared_error: 0.0760 - val_loss: 0.1756 - val_r_square: 0.9196 - val_mean_absolute_error: 0.1756 - val_mean_squared_error: 0.0803
# Epoch 123/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1729 - r_square: 0.9233 - mean_absolute_error: 0.1729 - mean_squared_error: 0.0767 - val_loss: 0.1747 - val_r_square: 0.9216 - val_mean_absolute_error: 0.1747 - val_mean_squared_error: 0.0782
# Epoch 124/154
# 1211/1211 [==============================] - 139s 115ms/step - loss: 0.1724 - r_square: 0.9241 - mean_absolute_error: 0.1724 - mean_squared_error: 0.0759 - val_loss: 0.1749 - val_r_square: 0.9190 - val_mean_absolute_error: 0.1749 - val_mean_squared_error: 0.0808
# Epoch 125/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1722 - r_square: 0.9237 - mean_absolute_error: 0.1722 - mean_squared_error: 0.0763 - val_loss: 0.1760 - val_r_square: 0.9183 - val_mean_absolute_error: 0.1760 - val_mean_squared_error: 0.0815
# Epoch 126/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1693 - r_square: 0.9254 - mean_absolute_error: 0.1693 - mean_squared_error: 0.0746 - val_loss: 0.1725 - val_r_square: 0.9194 - val_mean_absolute_error: 0.1725 - val_mean_squared_error: 0.0804
# Epoch 127/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1691 - r_square: 0.9256 - mean_absolute_error: 0.1691 - mean_squared_error: 0.0744 - val_loss: 0.1724 - val_r_square: 0.9195 - val_mean_absolute_error: 0.1724 - val_mean_squared_error: 0.0804
# Epoch 128/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1691 - r_square: 0.9257 - mean_absolute_error: 0.1691 - mean_squared_error: 0.0743 - val_loss: 0.1725 - val_r_square: 0.9193 - val_mean_absolute_error: 0.1725 - val_mean_squared_error: 0.0806
# Epoch 129/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1690 - r_square: 0.9257 - mean_absolute_error: 0.1690 - mean_squared_error: 0.0743 - val_loss: 0.1725 - val_r_square: 0.9190 - val_mean_absolute_error: 0.1725 - val_mean_squared_error: 0.0808
# Epoch 130/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1689 - r_square: 0.9258 - mean_absolute_error: 0.1689 - mean_squared_error: 0.0742 - val_loss: 0.1724 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1724 - val_mean_squared_error: 0.0808
# Epoch 131/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1688 - r_square: 0.9259 - mean_absolute_error: 0.1688 - mean_squared_error: 0.0741 - val_loss: 0.1724 - val_r_square: 0.9189 - val_mean_absolute_error: 0.1724 - val_mean_squared_error: 0.0810
# Epoch 132/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1687 - r_square: 0.9259 - mean_absolute_error: 0.1687 - mean_squared_error: 0.0741 - val_loss: 0.1723 - val_r_square: 0.9195 - val_mean_absolute_error: 0.1723 - val_mean_squared_error: 0.0803
# Epoch 133/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1686 - r_square: 0.9260 - mean_absolute_error: 0.1686 - mean_squared_error: 0.0740 - val_loss: 0.1723 - val_r_square: 0.9189 - val_mean_absolute_error: 0.1723 - val_mean_squared_error: 0.0809
# Epoch 134/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1686 - r_square: 0.9260 - mean_absolute_error: 0.1686 - mean_squared_error: 0.0740 - val_loss: 0.1722 - val_r_square: 0.9193 - val_mean_absolute_error: 0.1722 - val_mean_squared_error: 0.0805
# Epoch 135/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1685 - r_square: 0.9260 - mean_absolute_error: 0.1685 - mean_squared_error: 0.0740 - val_loss: 0.1721 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1721 - val_mean_squared_error: 0.0806
# Epoch 136/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1685 - r_square: 0.9261 - mean_absolute_error: 0.1685 - mean_squared_error: 0.0739 - val_loss: 0.1721 - val_r_square: 0.9193 - val_mean_absolute_error: 0.1721 - val_mean_squared_error: 0.0806
# Epoch 137/154
# 1211/1211 [==============================] - 141s 117ms/step - loss: 0.1684 - r_square: 0.9261 - mean_absolute_error: 0.1684 - mean_squared_error: 0.0739 - val_loss: 0.1720 - val_r_square: 0.9194 - val_mean_absolute_error: 0.1720 - val_mean_squared_error: 0.0804
# Epoch 138/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1684 - r_square: 0.9261 - mean_absolute_error: 0.1684 - mean_squared_error: 0.0739 - val_loss: 0.1721 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1721 - val_mean_squared_error: 0.0808
# Epoch 139/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1684 - r_square: 0.9262 - mean_absolute_error: 0.1684 - mean_squared_error: 0.0738 - val_loss: 0.1720 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1720 - val_mean_squared_error: 0.0807
# Epoch 140/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1683 - r_square: 0.9262 - mean_absolute_error: 0.1683 - mean_squared_error: 0.0738 - val_loss: 0.1720 - val_r_square: 0.9189 - val_mean_absolute_error: 0.1720 - val_mean_squared_error: 0.0809
# Epoch 141/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1683 - r_square: 0.9262 - mean_absolute_error: 0.1683 - mean_squared_error: 0.0738 - val_loss: 0.1720 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1720 - val_mean_squared_error: 0.0807
# Epoch 142/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1682 - r_square: 0.9263 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0737 - val_loss: 0.1720 - val_r_square: 0.9190 - val_mean_absolute_error: 0.1720 - val_mean_squared_error: 0.0809
# Epoch 143/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1682 - r_square: 0.9263 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0737 - val_loss: 0.1719 - val_r_square: 0.9195 - val_mean_absolute_error: 0.1719 - val_mean_squared_error: 0.0804
# Epoch 144/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1682 - r_square: 0.9263 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0737 - val_loss: 0.1719 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1719 - val_mean_squared_error: 0.0806
# Epoch 145/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1681 - r_square: 0.9263 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0737 - val_loss: 0.1719 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1719 - val_mean_squared_error: 0.0806
# Epoch 146/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1681 - r_square: 0.9263 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0737 - val_loss: 0.1718 - val_r_square: 0.9194 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0805
# Epoch 147/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1681 - r_square: 0.9264 - mean_absolute_error: 0.1681 - mean_squared_error: 0.0736 - val_loss: 0.1718 - val_r_square: 0.9193 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0805
# Epoch 148/154
# 1211/1211 [==============================] - 140s 115ms/step - loss: 0.1680 - r_square: 0.9264 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0736 - val_loss: 0.1718 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0806
# Epoch 149/154
# 1211/1211 [==============================] - 140s 116ms/step - loss: 0.1680 - r_square: 0.9264 - mean_absolute_error: 0.1680 - mean_squared_error: 0.0736 - val_loss: 0.1718 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0808
# Epoch 150/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1679 - r_square: 0.9264 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0736 - val_loss: 0.1718 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0808
# Epoch 151/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1679 - r_square: 0.9264 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0736 - val_loss: 0.1718 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0807
# Epoch 152/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1679 - r_square: 0.9264 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0736 - val_loss: 0.1718 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0807
# Epoch 153/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1679 - r_square: 0.9265 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0735 - val_loss: 0.1718 - val_r_square: 0.9191 - val_mean_absolute_error: 0.1718 - val_mean_squared_error: 0.0807
# Epoch 154/154
# 1211/1211 [==============================] - 141s 116ms/step - loss: 0.1679 - r_square: 0.9265 - mean_absolute_error: 0.1679 - mean_squared_error: 0.0735 - val_loss: 0.1717 - val_r_square: 0.9192 - val_mean_absolute_error: 0.1717 - val_mean_squared_error: 0.0807
# EPOCH N: 154 50
# train_shell ::
# train_shell :: trained 50 epochs!
# train_shell ::
# finished epoch N 154
# prev [100, 2, 2, 50]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
# instance.plot_metrics(fnmatch_criteria="*loss*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*squared*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*r_square*", yscale="log")

# %% [markdown]
# checking results:

# %%
errors, recon = utils.get_recon_errors([train_norm, test_norm, data_norm, signal_norm], autoencoder, functions=['mse', 'mae', r_square_np], names=[None, None, "r-square"])
(train_err, test_err, data_err, signal_err) = errors
(train_recon, test_recon, data_recon, signal_recon) = recon

# %%
data_norm.plot(data_recon, normed=0)
signal_norm.plot(signal_recon, normed=0)
# Out:
# data_table :: plotting distrubution(s) for table(s) ["'background' normed to 'train'", "'background' normed to 'train' pred"]
# data_table :: plotting distrubution(s) for table(s) ["'signal' normed to 'train'", "'signal' normed to 'train' pred"]

# %%
data_err.plot(signal_err, figloc="upper left", bins=100, rng=((0,.5), (0, 0.9), (0.5, 1.)), normed=1)

def roc_auc_plot(data_err, signal_err, metric='mae'):
    from sklearn.metrics import roc_curve, roc_auc_score
    pred = np.hstack([signal_err[metric].values, data_err[metric].values])
    true = np.hstack([np.ones(signal_err.shape[0]), np.zeros(data_err.shape[0])])

    roc = roc_curve(true, pred)
    auc = roc_auc_score(true, pred)
    print "auc value:", auc
    plt.figure(figsize=(10,10))
    # ax = fig.axes() 
    plt.plot(roc[0], roc[1])
    plt.plot((0,1), (0,1))
    roc_dict = {"roc": roc, "auc": auc}
    
    fpr, tpr, _ = roc_dict['roc']
    argmin = np.argsort(np.sqrt(fpr**2. + (1. - tpr)**2.))[0]
#     print fpr[argmin], tpr[argmin]
    plt.scatter(fpr[argmin], tpr[argmin], c='r')
    
    plt.show()
    
    return roc_dict

roc_dict = roc_auc_plot(data_err, signal_err, 'mae')
# Out:
# data_table :: plotting distrubution(s) for table(s) ["'background' normed to 'train' error", "'signal' normed to 'train' error"]
# auc value: 0.604649174232

# %%
plt.figure(figsize=(5,5))
plt.plot(x,y)
deriv = np.diff(y)/np.diff(x)

plt.plot(x[1:], deriv, c='r')
plt.show()
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-centos7-gcc7-opt/lib/python2.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
np.isclose(np.diff(x), 0).shape
# Out:
# (63867,)

# %%
y/x
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-centos7-gcc7-opt/lib/python2.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in divide
#   """Entry point for launching an IPython kernel.
# array([        nan,  0.        ,  2.08853704, ...,  0.99997895,
#         1.00001934,  1.        ])

# %%
# errors.plot(
#     errors_tagged,
#     figsize=(20,8), 
#     bins=40,
#     rng=((0,0.1), (0, 0.25), (.85,1)),
#     fontsize=20, cols=3, 
#     figloc="upper center",
#     normed=True,
#     yscale="linear",
#     histtype="step",
#     alpha=1
# )
# errors.plot(
#     errors_tagged,
#     figsize=(20,8), 
#     bins=40,
#     rng=((0,0.3), (0, 0.5), (.5,1)),
#     fontsize=20, cols=3, 
#     figloc="upper center",
#     normed=True,
#     yscale="log",
#     histtype="step",
#     alpha=1
# )
# errors.plot(
#     errors_tagged,
#     figsize=(20,8), 
#     bins=20,
#     rng=((.1,0.3), (.12, 0.5), (.5,.9)),
#     fontsize=20, cols=3, 
#     figloc="upper center",
#     normed=True,
#     yscale="linear",
#     histtype="step",
#     alpha=1
# )
