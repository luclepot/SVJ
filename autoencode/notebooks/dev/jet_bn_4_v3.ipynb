# %%
from autoencodeSVJ import utils, models, trainer
import glob
import os
import numpy as np
import keras
import keras.backend as K
import matplotlib.pyplot as plt

version_id = 'v3'
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
repo_head = utils.get_repo_info()['head']
assert len(repo_head) > 0, "not running jupyter notebook from within a repo!! Prolly won't work :-)"
data_path = os.path.join(repo_head, "data/tightSVJ/10h5/*_data.h5")

# replace above code for 'data_path' if you want something else
data, jet_tables = utils.get_training_data_jets(data_path)

data.cdrop(["jetM", "*MET*", "*Delta*"], inplace=True)
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_10_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_12_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_11_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_23_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_15_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_17_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_14_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_13_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_18_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_16_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_19_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_21_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_22_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_28_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_20_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_26_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_24_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_30_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_25_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_27_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_31_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_29_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_33_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_32_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_34_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/datafixed_0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#           jetEta    jetPhi        jetPt  jetChargedFraction    jetPTD  \
# 0       0.292314 -1.215342   811.505066            0.617647  0.292997
# 1      -1.108254  0.154565   792.122620            0.600000  0.234078
# 2       0.131421 -2.197223   665.996277            0.526316  0.198135
# 3      -1.134106  1.502835   942.049133            0.619048  0.277420
# 4      -0.058697  2.968807   753.037720            0.500000  0.407907
# 5      -0.116076 -1.582877  1224.752563            0.575758  0.193657
# 6      -0.522428 -1.064521  1240.000854            0.672414  0.214055
# 7       0.479513  2.142449  1163.479126            0.550000  0.283502
# 8       0.785336  1.244235   713.023560            0.421053  0.222477
# 9      -0.561334 -1.531905   962.493652            0.378378  0.392954
# 10     -0.522298 -1.966336   620.625366            0.500000  0.372961
# 11     -0.349148 -0.184005   962.956848            0.611111  0.468053
# 12     -0.186097 -0.634149   876.603455            0.666667  0.570375
# 13      0.646903  0.328228  1282.709961            0.558824  0.397234
# 14     -0.731659 -2.069067  1149.119141            0.631579  0.441191
# 15      0.251663 -2.037174   753.708252            0.395349  0.283164
# 16     -0.525851 -0.712804  1071.257935            0.428571  0.333651
# 17      0.251762  0.245324   840.363708            0.500000  0.312958
# 18      0.046264 -1.697923   994.453674            0.485294  0.261338
# 19      0.168608 -0.640267   815.322510            0.593220  0.221745
# 20      0.556715  2.216664   894.205688            0.627907  0.312438
# 21     -0.389482 -1.157212  1311.519409            0.575758  0.529720
# 22      1.138927  2.488871   861.502258            0.571429  0.643854
# 23     -0.965012 -1.945139   882.775696            0.603448  0.248044
# 24     -0.028729  1.793943  1194.469727            0.479167  0.548132
# 25     -0.283393 -0.533182   642.556946            0.750000  0.437456
# 26      0.337100  0.543027   818.530090            0.513889  0.253783
# 27     -0.849820 -1.163341  1714.166870            0.321429  0.455497
# 28      0.551213 -2.948952  1280.083618            0.507246  0.238844
# 29     -0.139992 -3.015406   778.579773            0.625000  0.297276
# ...          ...       ...          ...                 ...       ...
# 103386 -0.777233  1.076672   537.510498            0.541667  0.313189
# 103387  0.093429  1.750992   567.386536            0.780488  0.195785
# 103388 -0.140647 -0.287098   438.255615            0.722222  0.387304
# 103389 -0.625187 -0.518215   539.317261            0.732143  0.186291
# 103390  0.501899  2.260820   327.454163            0.884615  0.155193
# 103391 -0.671737 -1.935592   488.134399            0.562500  0.339051
# 103392 -0.248868  2.237542   512.103577            0.517857  0.263996
# 103393 -0.556577 -1.741644   304.653137            0.680000  0.353932
# 103394  0.735330  0.182954   496.935669            0.627119  0.194807
# 103395 -0.848740 -0.665390   292.582123            0.500000  0.349048
# 103396  0.930291 -2.301146   364.734833            0.800000  0.502970
# 103397  1.388285  2.722309   446.535095            0.636364  0.447891
# 103398  0.321274  2.262723   324.318115            0.807692  0.240159
# 103399  1.722634 -1.917789   385.018402            0.315789  0.211032
# 103400 -1.411962  2.157040   426.891296            0.631579  0.342927
# 103401  0.385944  1.637310   445.687683            0.666667  0.414504
# 103402  0.071750 -0.016674   486.405243            0.514286  0.371825
# 103403 -0.274274 -2.026819   423.579742            0.655172  0.419825
# 103404 -0.034476 -2.993685   360.139099            0.500000  0.378675
# 103405 -0.090806  0.697530   436.733917            0.625000  0.258427
# 103406 -1.196746  0.567630   279.266632            0.448276  0.274682
# 103407  0.487608  0.025602   208.672699            0.500000  0.378830
# 103408  0.584099  0.932500   586.188782            0.470588  0.548982
# 103409 -0.182965 -1.939916   570.412842            0.476190  0.407647
# 103410  0.547675 -2.880787   291.602722            0.750000  0.177748
# 103411  1.139636  1.404210   421.269684            0.714286  0.319042
# 103412 -0.380799  0.993952   428.067627            0.777778  0.337833
# 103413  0.083928  2.417642   607.483276            0.533333  0.432423
# 103414  0.069787  0.725840   470.475006            0.642857  0.609724
# 103415  0.543851 -0.418095   329.591095            0.724138  0.194798
#
#         jetAxis2  jetFlavor    jetEnergy
# 0       0.015287        1.0   847.437136
# 1       0.025373        3.0  1331.724071
# 2       0.021002        3.0   674.659860
# 3       0.018531        2.0  1616.606413
# 4       0.027717        2.0   756.594176
# 5       0.020776        4.0  1240.268663
# 6       0.022217        1.0  1415.601506
# 7       0.020701        3.0  1313.717833
# 8       0.100818        2.0   946.259955
# 9       0.022140        1.0  1119.513002
# 10      0.018785        3.0   707.847508
# 11      0.006561        2.0  1022.451136
# 12      0.005961        2.0   892.310396
# 13      0.009808        1.0  1562.785168
# 14      0.006322        2.0  1470.845332
# 15      0.036941        3.0   780.293723
# 16      0.008910        2.0  1223.627348
# 17      0.021573        2.0   868.710598
# 18      0.038473        4.0  1008.743118
# 19      0.034709        1.0   833.242187
# 20      0.017430        3.0  1038.669196
# 21      0.010735        3.0  1413.514999
# 22      0.004517        3.0  1483.531703
# 23      0.019557        4.0  1328.341260
# 24      0.014543        3.0  1197.454310
# 25      0.010260        4.0   668.810909
# 26      0.036376        4.0   871.829995
# 27      0.010684        2.0  2372.503739
# 28      0.032092        5.0  1484.629500
# 29      0.020089        3.0   787.074072
# ...          ...        ...          ...
# 103386  0.017270        4.0   708.363454
# 103387  0.057422        3.0   581.441837
# 103388  0.016090        1.0   442.878099
# 103389  0.040452        1.0   655.988591
# 103390  0.042345        2.0   370.276746
# 103391  0.022722       21.0   603.181690
# 103392  0.046526        3.0   531.101860
# 103393  0.030684        3.0   353.736628
# 103394  0.031222        4.0   638.256417
# 103395  0.034171        3.0   404.785405
# 103396  0.011691        2.0   534.496402
# 103397  0.010900        3.0   950.795024
# 103398  0.025647        2.0   341.780570
# 103399  0.094948        2.0  1115.146208
# 103400  0.013452        2.0   928.268144
# 103401  0.017875        1.0   480.126553
# 103402  0.020780        3.0   488.758627
# 103403  0.017165        3.0   440.403674
# 103404  0.017596        1.0   360.688050
# 103405  0.060339       21.0   440.743713
# 103406  0.037106        2.0   504.866810
# 103407  0.027390        1.0   234.123772
# 103408  0.009190        1.0   689.268892
# 103409  0.012631        3.0   580.483251
# 103410  0.039075        1.0   336.657709
# 103411  0.019636       21.0   726.260814
# 103412  0.016043        2.0   460.304188
# 103413  0.009017        1.0   610.087231
# 103414  0.007267        4.0   472.207252
# 103415  0.030352        3.0   380.959989
#
# [103416 rows x 8 columns]

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
tagged, tag_index = utils.split_table_by_column(
    "jetFlavor",
    data,
    utils.delphes_jet_tags_dict,
    False
)
sizes = map(lambda x: x.shape[0], tagged)
for t,s in zip(tagged, sizes):
    print  "{} jet: {}, {}%".format(t.name, s, round(100.*s/sum(sizes), 1))
# Out:
# down jet: 18999, 18.4%
# up jet: 38841, 37.6%
# strange jet: 25377, 24.5%
# charm jet: 9577, 9.3%
# bottom jet: 3341, 3.2%
# gluon jet: 7281, 7.0%

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
split = 0.25

train, test = data.train_test_split(split)

train_tags, test_tags = map(
    lambda x: utils.split_table_by_column(
        "jetFlavor", x,
        utils.delphes_jet_tags_dict, False
    )[0],
    [train, test]
)

for trt, tet in zip(train_tags, test_tags):
    print "{}:".format(trt.name)
    print "\t{:.1f}% ({}) train".format(100.*trt.shape[0]/train.shape[0], trt.shape[0])
    print "\t{:.1f}% ({}) test".format(100.*tet.shape[0]/test.shape[0], tet.shape[0])
    print "\t{:.1f}% ({}) original".format(100.*(tet.shape[0] + trt.shape[0])/data.shape[0], trt.shape[0] + tet.shape[0])

for full, trt, tet in zip(tagged, train_tags, test_tags):
    trt.name = "train_" + trt.name
    tet.name = "test_" + tet.name
    trt.plot([tet, full], normed=1)

# data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# down:
# 	18.4% (14271) train
# 	18.3% (4728) test
# 	18.4% (18999) original
# up:
# 	37.6% (29146) train
# 	37.5% (9695) test
# 	37.6% (38841) original
# strange:
# 	24.6% (19052) train
# 	24.5% (6325) test
# 	24.5% (25377) original
# charm:
# 	9.2% (7144) train
# 	9.4% (2433) test
# 	9.3% (9577) original
# bottom:
# 	3.2% (2518) train
# 	3.2% (823) test
# 	3.2% (3341) original
# gluon:
# 	7.0% (5431) train
# 	7.2% (1850) test
# 	7.0% (7281) original
# data_table :: plotting distrubution(s) for table(s) ['train_down', 'test_down', 'down']
# data_table :: plotting distrubution(s) for table(s) ['train_up', 'test_up', 'up']
# data_table :: plotting distrubution(s) for table(s) ['train_strange', 'test_strange', 'strange']
# data_table :: plotting distrubution(s) for table(s) ['train_charm', 'test_charm', 'charm']
# data_table :: plotting distrubution(s) for table(s) ['train_bottom', 'test_bottom', 'bottom']
# data_table :: plotting distrubution(s) for table(s) ['train_gluon', 'test_gluon', 'gluon']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
tagged[0].plot(tagged[1:], normed=0, bins=50, cols=2, figsize=(10,20), rng=(
        (0,2), (-3.2, 3.2), (0,2500), (0,1), (0, 0.8),(0,.1), (0,3000)))
# Out:
# data_table :: plotting distrubution(s) for table(s) ['down', 'up', 'strange', 'charm', 'bottom', 'gluon']

# %%
raw = data.cdrop("*Flavor")

norm_args = {
    "norm_type": "StandardScaler",
#     "feature_range": (0.01, 0.99)
}

train_raw = train.cdrop("*Flavor")
test_raw = test.cdrop("*Flavor")
train_norm, test_norm = train_raw.norm(**norm_args), train_raw.norm(test_raw, **norm_args)

norm = train_raw.norm(raw, **norm_args)
features = [utils.data_table(norm[c].values.reshape(norm[c].shape[0],1), name=c, headers=["normed features"]) for c in norm]
features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, figloc="upper right")

# rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # norm_data = data.norm(norm_type=0, rng=rng)
# norm_data = custom_norm(data)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetChargedFraction', 'jetPTD', 'jetAxis2', 'jetEnergy']

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
bn = 4
name = "bn_{1}_{0}".format(version_id, bn)
path = "autoencode/data/training_runs/7jf/custom"

ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(40)
ae_skeleton.add(bn, 'relu')
ae_skeleton.add(40)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
instance = trainer.trainer(os.path.join(os.path.join(repo_head, path), name))
# Out:
# h5_elt 'metric_names' :: loading dataset 'data/metric_names' from file 'bn_4_v3.h5'
# h5_elt 'training' :: loading dataset 'params/training' from file 'bn_4_v3.h5'
# h5_elt 'config' :: loading dataset 'params/config' from file 'bn_4_v3.h5'

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 40)                320
# _________________________________________________________________
# layer_3 (Dense)              (None, 4)                 164
# =================================================================
# Total params: 484
# Trainable params: 484
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_3 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# layer_4 (Dense)              (None, 40)                200
# _________________________________________________________________
# layer_5 (Dense)              (None, 7)                 287
# =================================================================
# Total params: 487
# Trainable params: 487
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 4)                 484
# _________________________________________________________________
# decoder (Model)              (None, 7)                 487
# =================================================================
# Total params: 971
# Trainable params: 971
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss='mse',
    epochs=50,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=True,
    batch_size=128,
    use_callbacks=True,
    learning_rate=0.001
)
# Out:
# Train on 77562 samples, validate on 25854 samples
# Epoch 1/50
# 605/605 [==============================] - 38s 63ms/step - loss: 0.2826 - r_square: 0.7174 - mean_absolute_error: 0.3432 - mean_squared_error: 0.2826 - val_loss: 0.1384 - val_r_square: 0.8620 - val_mean_absolute_error: 0.2403 - val_mean_squared_error: 0.1384
# Epoch 2/50
# 605/605 [==============================] - 36s 60ms/step - loss: 0.1149 - r_square: 0.8851 - mean_absolute_error: 0.2188 - mean_squared_error: 0.1149 - val_loss: 0.1046 - val_r_square: 0.8957 - val_mean_absolute_error: 0.2065 - val_mean_squared_error: 0.1046
# Epoch 3/50
# 605/605 [==============================] - 39s 65ms/step - loss: 0.0944 - r_square: 0.9056 - mean_absolute_error: 0.1956 - mean_squared_error: 0.0944 - val_loss: 0.0861 - val_r_square: 0.9142 - val_mean_absolute_error: 0.1877 - val_mean_squared_error: 0.0861
# Epoch 4/50
# 605/605 [==============================] - 38s 63ms/step - loss: 0.0806 - r_square: 0.9194 - mean_absolute_error: 0.1818 - mean_squared_error: 0.0806 - val_loss: 0.0770 - val_r_square: 0.9233 - val_mean_absolute_error: 0.1773 - val_mean_squared_error: 0.0770
# Epoch 5/50
# 605/605 [==============================] - 39s 65ms/step - loss: 0.0745 - r_square: 0.9255 - mean_absolute_error: 0.1737 - mean_squared_error: 0.0745 - val_loss: 0.0730 - val_r_square: 0.9272 - val_mean_absolute_error: 0.1713 - val_mean_squared_error: 0.0730
# Epoch 6/50
# 605/605 [==============================] - 37s 61ms/step - loss: 0.0709 - r_square: 0.9291 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0709 - val_loss: 0.0697 - val_r_square: 0.9306 - val_mean_absolute_error: 0.1656 - val_mean_squared_error: 0.0697
# Epoch 7/50
# 605/605 [==============================] - 38s 62ms/step - loss: 0.0684 - r_square: 0.9316 - mean_absolute_error: 0.1640 - mean_squared_error: 0.0684 - val_loss: 0.0677 - val_r_square: 0.9325 - val_mean_absolute_error: 0.1630 - val_mean_squared_error: 0.0677
# Epoch 8/50
# 605/605 [==============================] - 35s 58ms/step - loss: 0.0668 - r_square: 0.9332 - mean_absolute_error: 0.1617 - mean_squared_error: 0.0668 - val_loss: 0.0665 - val_r_square: 0.9337 - val_mean_absolute_error: 0.1609 - val_mean_squared_error: 0.0665
# Epoch 9/50
# 605/605 [==============================] - 36s 60ms/step - loss: 0.0656 - r_square: 0.9344 - mean_absolute_error: 0.1599 - mean_squared_error: 0.0656 - val_loss: 0.0655 - val_r_square: 0.9347 - val_mean_absolute_error: 0.1592 - val_mean_squared_error: 0.0655
# Epoch 10/50
# 605/605 [==============================] - 36s 59ms/step - loss: 0.0646 - r_square: 0.9354 - mean_absolute_error: 0.1584 - mean_squared_error: 0.0646 - val_loss: 0.0646 - val_r_square: 0.9356 - val_mean_absolute_error: 0.1580 - val_mean_squared_error: 0.0646
# Epoch 11/50
# 605/605 [==============================] - 42s 69ms/step - loss: 0.0637 - r_square: 0.9363 - mean_absolute_error: 0.1572 - mean_squared_error: 0.0637 - val_loss: 0.0640 - val_r_square: 0.9362 - val_mean_absolute_error: 0.1573 - val_mean_squared_error: 0.0640
# Epoch 12/50
# 605/605 [==============================] - 50s 83ms/step - loss: 0.0630 - r_square: 0.9370 - mean_absolute_error: 0.1562 - mean_squared_error: 0.0630 - val_loss: 0.0632 - val_r_square: 0.9370 - val_mean_absolute_error: 0.1558 - val_mean_squared_error: 0.0632
# Epoch 13/50
# 605/605 [==============================] - 50s 83ms/step - loss: 0.0624 - r_square: 0.9376 - mean_absolute_error: 0.1554 - mean_squared_error: 0.0624 - val_loss: 0.0626 - val_r_square: 0.9376 - val_mean_absolute_error: 0.1553 - val_mean_squared_error: 0.0626
# Epoch 14/50
# 605/605 [==============================] - 53s 87ms/step - loss: 0.0619 - r_square: 0.9381 - mean_absolute_error: 0.1548 - mean_squared_error: 0.0619 - val_loss: 0.0620 - val_r_square: 0.9382 - val_mean_absolute_error: 0.1544 - val_mean_squared_error: 0.0620
# Epoch 15/50
# 605/605 [==============================] - 65s 107ms/step - loss: 0.0614 - r_square: 0.9386 - mean_absolute_error: 0.1542 - mean_squared_error: 0.0614 - val_loss: 0.0615 - val_r_square: 0.9387 - val_mean_absolute_error: 0.1538 - val_mean_squared_error: 0.0615
# Epoch 16/50
# 605/605 [==============================] - 88s 145ms/step - loss: 0.0609 - r_square: 0.9391 - mean_absolute_error: 0.1536 - mean_squared_error: 0.0609 - val_loss: 0.0613 - val_r_square: 0.9389 - val_mean_absolute_error: 0.1544 - val_mean_squared_error: 0.0613
# Epoch 17/50
# 605/605 [==============================] - 91s 151ms/step - loss: 0.0605 - r_square: 0.9395 - mean_absolute_error: 0.1531 - mean_squared_error: 0.0605 - val_loss: 0.0608 - val_r_square: 0.9394 - val_mean_absolute_error: 0.1534 - val_mean_squared_error: 0.0608
# Epoch 18/50
# 605/605 [==============================] - 86s 141ms/step - loss: 0.0602 - r_square: 0.9398 - mean_absolute_error: 0.1526 - mean_squared_error: 0.0602 - val_loss: 0.0603 - val_r_square: 0.9399 - val_mean_absolute_error: 0.1523 - val_mean_squared_error: 0.0603
# Epoch 19/50
# 605/605 [==============================] - 94s 155ms/step - loss: 0.0598 - r_square: 0.9402 - mean_absolute_error: 0.1522 - mean_squared_error: 0.0598 - val_loss: 0.0600 - val_r_square: 0.9402 - val_mean_absolute_error: 0.1519 - val_mean_squared_error: 0.0600
# Epoch 20/50
# 605/605 [==============================] - 108s 178ms/step - loss: 0.0595 - r_square: 0.9405 - mean_absolute_error: 0.1518 - mean_squared_error: 0.0595 - val_loss: 0.0597 - val_r_square: 0.9405 - val_mean_absolute_error: 0.1517 - val_mean_squared_error: 0.0597
# Epoch 21/50
# 605/605 [==============================] - 116s 192ms/step - loss: 0.0592 - r_square: 0.9408 - mean_absolute_error: 0.1515 - mean_squared_error: 0.0592 - val_loss: 0.0595 - val_r_square: 0.9407 - val_mean_absolute_error: 0.1513 - val_mean_squared_error: 0.0595
# Epoch 22/50
# 605/605 [==============================] - 114s 188ms/step - loss: 0.0590 - r_square: 0.9410 - mean_absolute_error: 0.1513 - mean_squared_error: 0.0590 - val_loss: 0.0592 - val_r_square: 0.9410 - val_mean_absolute_error: 0.1512 - val_mean_squared_error: 0.0592
# Epoch 23/50
# 605/605 [==============================] - 104s 172ms/step - loss: 0.0588 - r_square: 0.9412 - mean_absolute_error: 0.1510 - mean_squared_error: 0.0588 - val_loss: 0.0591 - val_r_square: 0.9411 - val_mean_absolute_error: 0.1511 - val_mean_squared_error: 0.0591
# Epoch 24/50
# 605/605 [==============================] - 59s 97ms/step - loss: 0.0585 - r_square: 0.9415 - mean_absolute_error: 0.1507 - mean_squared_error: 0.0585 - val_loss: 0.0588 - val_r_square: 0.9414 - val_mean_absolute_error: 0.1508 - val_mean_squared_error: 0.0588
# Epoch 25/50
# 605/605 [==============================] - 58s 96ms/step - loss: 0.0583 - r_square: 0.9417 - mean_absolute_error: 0.1505 - mean_squared_error: 0.0583 - val_loss: 0.0585 - val_r_square: 0.9417 - val_mean_absolute_error: 0.1503 - val_mean_squared_error: 0.0585
# Epoch 26/50
# 605/605 [==============================] - 61s 101ms/step - loss: 0.0580 - r_square: 0.9420 - mean_absolute_error: 0.1502 - mean_squared_error: 0.0580 - val_loss: 0.0583 - val_r_square: 0.9419 - val_mean_absolute_error: 0.1500 - val_mean_squared_error: 0.0583
# Epoch 27/50
# 605/605 [==============================] - 63s 104ms/step - loss: 0.0578 - r_square: 0.9422 - mean_absolute_error: 0.1499 - mean_squared_error: 0.0578 - val_loss: 0.0583 - val_r_square: 0.9419 - val_mean_absolute_error: 0.1507 - val_mean_squared_error: 0.0583
# Epoch 28/50
# 605/605 [==============================] - 75s 125ms/step - loss: 0.0576 - r_square: 0.9424 - mean_absolute_error: 0.1497 - mean_squared_error: 0.0576 - val_loss: 0.0579 - val_r_square: 0.9423 - val_mean_absolute_error: 0.1495 - val_mean_squared_error: 0.0579
# Epoch 29/50
# 605/605 [==============================] - 130s 215ms/step - loss: 0.0574 - r_square: 0.9426 - mean_absolute_error: 0.1495 - mean_squared_error: 0.0574 - val_loss: 0.0576 - val_r_square: 0.9425 - val_mean_absolute_error: 0.1492 - val_mean_squared_error: 0.0576
# Epoch 30/50
# 605/605 [==============================] - 166s 274ms/step - loss: 0.0572 - r_square: 0.9428 - mean_absolute_error: 0.1492 - mean_squared_error: 0.0572 - val_loss: 0.0575 - val_r_square: 0.9427 - val_mean_absolute_error: 0.1491 - val_mean_squared_error: 0.0575
# Epoch 31/50
# 605/605 [==============================] - 165s 273ms/step - loss: 0.0570 - r_square: 0.9430 - mean_absolute_error: 0.1491 - mean_squared_error: 0.0570 - val_loss: 0.0573 - val_r_square: 0.9429 - val_mean_absolute_error: 0.1490 - val_mean_squared_error: 0.0573
# Epoch 32/50
# 605/605 [==============================] - 160s 264ms/step - loss: 0.0568 - r_square: 0.9432 - mean_absolute_error: 0.1489 - mean_squared_error: 0.0568 - val_loss: 0.0571 - val_r_square: 0.9431 - val_mean_absolute_error: 0.1486 - val_mean_squared_error: 0.0571
# Epoch 33/50
# 605/605 [==============================] - 165s 273ms/step - loss: 0.0566 - r_square: 0.9434 - mean_absolute_error: 0.1488 - mean_squared_error: 0.0566 - val_loss: 0.0569 - val_r_square: 0.9433 - val_mean_absolute_error: 0.1486 - val_mean_squared_error: 0.0569
# Epoch 34/50
# 605/605 [==============================] - 204s 337ms/step - loss: 0.0565 - r_square: 0.9435 - mean_absolute_error: 0.1486 - mean_squared_error: 0.0565 - val_loss: 0.0568 - val_r_square: 0.9434 - val_mean_absolute_error: 0.1487 - val_mean_squared_error: 0.0568
# Epoch 35/50
# 605/605 [==============================] - 186s 307ms/step - loss: 0.0563 - r_square: 0.9437 - mean_absolute_error: 0.1485 - mean_squared_error: 0.0563 - val_loss: 0.0566 - val_r_square: 0.9435 - val_mean_absolute_error: 0.1486 - val_mean_squared_error: 0.0566
# Epoch 36/50
# 605/605 [==============================] - 170s 280ms/step - loss: 0.0562 - r_square: 0.9438 - mean_absolute_error: 0.1484 - mean_squared_error: 0.0562 - val_loss: 0.0566 - val_r_square: 0.9436 - val_mean_absolute_error: 0.1492 - val_mean_squared_error: 0.0566
# Epoch 37/50
# 605/605 [==============================] - 178s 294ms/step - loss: 0.0560 - r_square: 0.9440 - mean_absolute_error: 0.1484 - mean_squared_error: 0.0560 - val_loss: 0.0566 - val_r_square: 0.9436 - val_mean_absolute_error: 0.1497 - val_mean_squared_error: 0.0566
# Epoch 38/50
# 605/605 [==============================] - 166s 274ms/step - loss: 0.0559 - r_square: 0.9441 - mean_absolute_error: 0.1482 - mean_squared_error: 0.0559 - val_loss: 0.0562 - val_r_square: 0.9440 - val_mean_absolute_error: 0.1482 - val_mean_squared_error: 0.0562
# Epoch 39/50
# 605/605 [==============================] - 172s 284ms/step - loss: 0.0558 - r_square: 0.9442 - mean_absolute_error: 0.1481 - mean_squared_error: 0.0558 - val_loss: 0.0562 - val_r_square: 0.9439 - val_mean_absolute_error: 0.1491 - val_mean_squared_error: 0.0562
# Epoch 40/50
# 605/605 [==============================] - 176s 291ms/step - loss: 0.0556 - r_square: 0.9444 - mean_absolute_error: 0.1481 - mean_squared_error: 0.0556 - val_loss: 0.0559 - val_r_square: 0.9443 - val_mean_absolute_error: 0.1479 - val_mean_squared_error: 0.0559
# Epoch 41/50
# 605/605 [==============================] - 158s 261ms/step - loss: 0.0555 - r_square: 0.9445 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0555 - val_loss: 0.0557 - val_r_square: 0.9445 - val_mean_absolute_error: 0.1476 - val_mean_squared_error: 0.0557
# Epoch 42/50
# 605/605 [==============================] - 166s 274ms/step - loss: 0.0554 - r_square: 0.9446 - mean_absolute_error: 0.1479 - mean_squared_error: 0.0554 - val_loss: 0.0557 - val_r_square: 0.9445 - val_mean_absolute_error: 0.1479 - val_mean_squared_error: 0.0557
# Epoch 43/50
# 605/605 [==============================] - 158s 260ms/step - loss: 0.0553 - r_square: 0.9447 - mean_absolute_error: 0.1478 - mean_squared_error: 0.0553 - val_loss: 0.0555 - val_r_square: 0.9447 - val_mean_absolute_error: 0.1475 - val_mean_squared_error: 0.0555
# Epoch 44/50
# 605/605 [==============================] - 174s 288ms/step - loss: 0.0552 - r_square: 0.9448 - mean_absolute_error: 0.1477 - mean_squared_error: 0.0552 - val_loss: 0.0554 - val_r_square: 0.9448 - val_mean_absolute_error: 0.1474 - val_mean_squared_error: 0.0554
# Epoch 45/50
# 605/605 [==============================] - 153s 253ms/step - loss: 0.0551 - r_square: 0.9449 - mean_absolute_error: 0.1477 - mean_squared_error: 0.0551 - val_loss: 0.0554 - val_r_square: 0.9448 - val_mean_absolute_error: 0.1483 - val_mean_squared_error: 0.0554
# Epoch 46/50
# 605/605 [==============================] - 140s 232ms/step - loss: 0.0550 - r_square: 0.9450 - mean_absolute_error: 0.1476 - mean_squared_error: 0.0550 - val_loss: 0.0553 - val_r_square: 0.9449 - val_mean_absolute_error: 0.1476 - val_mean_squared_error: 0.0553
# Epoch 47/50
# 605/605 [==============================] - 54s 89ms/step - loss: 0.0549 - r_square: 0.9451 - mean_absolute_error: 0.1476 - mean_squared_error: 0.0549 - val_loss: 0.0551 - val_r_square: 0.9451 - val_mean_absolute_error: 0.1473 - val_mean_squared_error: 0.0551
# Epoch 48/50
# 605/605 [==============================] - 51s 84ms/step - loss: 0.0548 - r_square: 0.9452 - mean_absolute_error: 0.1474 - mean_squared_error: 0.0548 - val_loss: 0.0549 - val_r_square: 0.9453 - val_mean_absolute_error: 0.1471 - val_mean_squared_error: 0.0549
# Epoch 49/50
# 605/605 [==============================] - 51s 84ms/step - loss: 0.0547 - r_square: 0.9453 - mean_absolute_error: 0.1474 - mean_squared_error: 0.0547 - val_loss: 0.0548 - val_r_square: 0.9453 - val_mean_absolute_error: 0.1469 - val_mean_squared_error: 0.0548
# Epoch 50/50
# 605/605 [==============================] - 49s 81ms/step - loss: 0.0546 - r_square: 0.9454 - mean_absolute_error: 0.1472 - mean_squared_error: 0.0546 - val_loss: 0.0548 - val_r_square: 0.9454 - val_mean_absolute_error: 0.1468 - val_mean_squared_error: 0.0548
# EPOCH N: 50 50
# train_shell ::
# train_shell :: trained 50 epochs!
# train_shell ::
# h5_elt 'val_r_square' :: creating group 'metric_names' in file 'bn_4_v3.h5'
# h5_elt 'val_r_square' :: creating dataset 'metric_names/val_r_square' in file 'bn_4_v3.h5'
# h5_elt 'loss' :: creating dataset 'metric_names/loss' in file 'bn_4_v3.h5'
# h5_elt 'mean_absolute_error' :: creating dataset 'metric_names/mean_absolute_error' in file 'bn_4_v3.h5'
# h5_elt 'val_mean_squared_error' :: creating dataset 'metric_names/val_mean_squared_error' in file 'bn_4_v3.h5'
# h5_elt 'val_mean_absolute_error' :: creating dataset 'metric_names/val_mean_absolute_error' in file 'bn_4_v3.h5'
# h5_elt 'r_square' :: creating dataset 'metric_names/r_square' in file 'bn_4_v3.h5'
# h5_elt 'mean_squared_error' :: creating dataset 'metric_names/mean_squared_error' in file 'bn_4_v3.h5'
# h5_elt 'lr' :: creating dataset 'metric_names/lr' in file 'bn_4_v3.h5'
# h5_elt 'val_loss' :: creating dataset 'metric_names/val_loss' in file 'bn_4_v3.h5'
# finished epoch N 50
# prev [50]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*mean_s*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="log")
instance.plot_metrics(fnmatch_criteria="*r_s*", yscale="log")

# %% [markdown]
# checking results:

# %%
# data_recon_norm = utils.data_table(autoencoder.predict(.norm(**norm_args).df.values), headers=train_norm.headers)
# data_recon = data.inorm(data_recon_norm, **norm_args)
# data_recon.name = "all jet data (pred)"

train_reconstructed_norm = utils.data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
test_reconstructed_norm = utils.data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)
data_reconstructed_norm = utils.data_table(autoencoder.predict(norm.data), headers=norm.headers)

train_reconstructed = train_raw.inorm(train_reconstructed_norm, **norm_args)
test_reconstructed = train_raw.inorm(test_reconstructed_norm, **norm_args)
data_reconstructed = train_raw.inorm(data_reconstructed_norm, **norm_args)

train_reconstructed.name = "train reconstructed"
test_reconstructed.name = "test reconstructed"
data_reconstructed.name = "data reconstructed"

# train_reconstructed_norm.plot([train_norm], values='jetAxis2', bins=70, rng=(0,0.5))
rngs = [
    (-2.2,2.2),
    (-3.14,3.14),
    (0,2000.),
    (0,1.),
    (0,1.),
    (0,.12),
    (0,2500),
]

raw.plot([train_reconstructed, test_reconstructed], normed=1, bins=60, rng=rngs)
for c,rng in zip(raw.headers, rngs):
    raw.plot([train_reconstructed, test_reconstructed], normed=1, values=c, rng=rng, bins=60, figloc='upper right')
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'train reconstructed', 'test reconstructed']

# %%
encoder, decoder = autoencoder.layers[1:]
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), name="test_reps")
)
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=1, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']

# %%
def r_square_np(true, pred):
    SS_res = np.sum(np.square(true - pred), axis=1)
    SS_tot = np.sum(np.square(true - np.mean(true, axis=0)), axis=1)
    return 1. - SS_res/SS_tot

def get_errors(true, pred, out_name="errors", functions=["mse", "mae", r_square_np], names=[None, None, "r_square"]):
    import tensorflow as tf
    if names is None:
        names = ['err {}'.format(i) for i in range(len(functions))]
    
    functions_keep = []
    for i,f in enumerate(functions):
        if isinstance(f, str):
            fuse = getattr(keras.losses, f)
            functions_keep.append(fuse)
            names[i] = f
        else:
            functions_keep.append(f)
    
    raw = [func(true, pred) for func in functions_keep]
    raw = np.asarray(map(lambda x: K.eval(x) if isinstance(x, tf.Tensor) else x, raw)).T
    return utils.data_table(
        raw,
        headers=[str(f) for f in names],
        name=out_name
    )

errors = get_errors(norm.data, data_reconstructed_norm.data, "all errors")
tagged_norm = [train_raw.norm(t, **norm_args) for t in tagged]
# tagged_recon_norm = [utils.data_table(autoencoder.predict(t.data), name=t.name + "_norm", headers=t.headers) for t in tagged]
errors_tagged = [get_errors(t.data, autoencoder.predict(t.data), "error " + t.name.split("normed")[0].strip().strip("'")) for t in tagged_norm]

# %%
import matplotlib.pyplot as plt

metric = 'mse'
rng = (0,1)
bins= 20
ecounts, ebins = np.histogram(errors[metric], range=rng, bins=bins, normed=1)
for e in errors_tagged:
    counts, bins = np.histogram(e[metric], range=rng, bins=bins, normed=1)
    ratio = counts.astype(float)/ecounts
    plt.plot(bins[:-1], ratio, label=e.name)
    print e.shape, e.name
plt.legend()
plt.show()
#     errors.plot([e], values=metric, rng=rng, normed=1, yscale="log")
# Out:
# (18999, 3) error down
# (38841, 3) error up
# (25377, 3) error strange
# (9577, 3) error charm
# (3341, 3) error bottom
# (7281, 3) error gluon

# %%
errors.plot(
    errors_tagged,
    figsize=(20,8), 
    bins=40,
    rng=((0,0.4), (0, 0.4), (.5,1)),
    fontsize=20, cols=3, 
    figloc="upper center",
    normed=True,
    yscale="linear",
    histtype="step",
    alpha=1
)
errors.plot(
    errors_tagged,
    figsize=(20,8), 
    bins=40,
    rng=((0,0.4), (0, 0.4), (.5,1)),
    fontsize=20, cols=3, 
    figloc="upper center",
    normed=True,
    yscale="log",
    histtype="step",
    alpha=1
)
errors.plot(
    errors_tagged,
    figsize=(20,8), 
    bins=20,
    rng=((.4,1.), (.35,1.2), (.5,.75)),
    fontsize=20, cols=3, 
    figloc="upper center",
    normed=True,
    yscale="linear",
    histtype="step",
    alpha=1
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all errors', 'error down', 'error up', 'error strange', 'error charm', 'error bottom', 'error gluon']
# data_table :: plotting distrubution(s) for table(s) ['all errors', 'error down', 'error up', 'error strange', 'error charm', 'error bottom', 'error gluon']
# data_table :: plotting distrubution(s) for table(s) ['all errors', 'error down', 'error up', 'error strange', 'error charm', 'error bottom', 'error gluon']

# %%
import keras
errors = utils.data_table(np.asarray(map(
        lambda x: keras.backend.eval(getattr(keras.losses, x)(data.norm(**norm_args).data, data_recon_norm.data)),
        ["mse", "mae"]
    )).T,                      
    headers=["mse", "mae"],
    name="errors"
)
outlier_fraction = 0.02
index = np.argsort(errors.mse)
out_index = index[-int(outlier_fraction*len(errors)):]
reg_index = index[:-int(outlier_fraction*len(errors))]
# print out_index.size + reg_index.size,len(errors)
# print out_index.size, reg_index.size
out,reg = (
    utils.data_table(data.data[out_index], headers=data.headers, name="outliers (top {})".format(outlier_fraction)), 
    utils.data_table(data.data[reg_index], headers=data.headers, name="normal")
)
out_reps, reg_reps = (
    utils.data_table(all_reps.data[out_index], headers=all_reps.headers, name="outlier reps"), 
    utils.data_table(all_reps.data[reg_index], headers=all_reps.headers, name="normal reps")
)
out_reps.plot(reg_reps, normed=1, bins=50, figsize=(20,4))
# reg.plot(out, normed=1, bins=50, figsize=(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f00f61ae4dbe> in <module>()
#       2 errors = utils.data_table(np.asarray(map(
#       3         lambda x: keras.backend.eval(getattr(keras.losses, x)(data.norm(**norm_args).data, data_recon_norm.data)),
# ----> 4         ["mse", "mae"]
#       5     )).T,
#       6     headers=["mse", "mae"],
#
# <ipython-input-21-f00f61ae4dbe> in <lambda>(x)
#       1 import keras
#       2 errors = utils.data_table(np.asarray(map(
# ----> 3         lambda x: keras.backend.eval(getattr(keras.losses, x)(data.norm(**norm_args).data, data_recon_norm.data)),
#       4         ["mse", "mae"]
#       5     )).T,
#
# NameError: global name 'data_recon_norm' is not defined
