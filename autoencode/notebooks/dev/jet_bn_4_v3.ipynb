# %%
from autoencodeSVJ import utils, models, trainer
import glob
import os
import numpy as np
import keras
import keras.backend as K
import matplotlib.pyplot as plt

version_id = 'v3'

# %% [markdown]
# ### 1: load and normalize input data
# we can use the data_loader for this.
# add an h5 sample, grab the table which represents it, and then split the table into training and testing datasets:

# %%
# get h5 datasets
repo_head = utils.get_repo_info()['head']
assert len(repo_head) > 0, "not running jupyter notebook from within a repo!! Prolly won't work :-)"
data_path = os.path.join(repo_head, "data/tightSVJ/10h5/*_data.h5")

# replace above code for 'data_path' if you want something else
data, jet_tables = utils.get_training_data_jets(data_path)

data.cdrop(["jetM", "*MET*", "*Delta*"], inplace=True)
# Out:
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_5_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_4_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_3_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_2_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_1_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_6_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_9_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_10_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_7_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_12_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_8_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_11_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_23_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_15_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_17_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_14_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_13_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_18_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_16_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_19_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_21_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_22_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_28_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_20_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_26_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_24_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_30_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_25_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_27_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_31_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_29_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_33_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_32_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/data_34_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Adding sample at path '/afs/cern.ch/work/l/llepotti/private/CMS/CMSSW_8_0_20/src/autoencodeSVJ/data/tightSVJ/10h5/datafixed_0_data.h5'
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
# data_loader :: Grabbing dataset with keys [u'event_feature_data']
#           jetEta    jetPhi        jetPt  jetChargedFraction    jetPTD  \
# 0       0.292314 -1.215342   811.505066            0.617647  0.292997
# 1      -1.108254  0.154565   792.122620            0.600000  0.234078
# 2       0.131421 -2.197223   665.996277            0.526316  0.198135
# 3      -1.134106  1.502835   942.049133            0.619048  0.277420
# 4      -0.058697  2.968807   753.037720            0.500000  0.407907
# 5      -0.116076 -1.582877  1224.752563            0.575758  0.193657
# 6      -0.522428 -1.064521  1240.000854            0.672414  0.214055
# 7       0.479513  2.142449  1163.479126            0.550000  0.283502
# 8       0.785336  1.244235   713.023560            0.421053  0.222477
# 9      -0.561334 -1.531905   962.493652            0.378378  0.392954
# 10     -0.522298 -1.966336   620.625366            0.500000  0.372961
# 11     -0.349148 -0.184005   962.956848            0.611111  0.468053
# 12     -0.186097 -0.634149   876.603455            0.666667  0.570375
# 13      0.646903  0.328228  1282.709961            0.558824  0.397234
# 14     -0.731659 -2.069067  1149.119141            0.631579  0.441191
# 15      0.251663 -2.037174   753.708252            0.395349  0.283164
# 16     -0.525851 -0.712804  1071.257935            0.428571  0.333651
# 17      0.251762  0.245324   840.363708            0.500000  0.312958
# 18      0.046264 -1.697923   994.453674            0.485294  0.261338
# 19      0.168608 -0.640267   815.322510            0.593220  0.221745
# 20      0.556715  2.216664   894.205688            0.627907  0.312438
# 21     -0.389482 -1.157212  1311.519409            0.575758  0.529720
# 22      1.138927  2.488871   861.502258            0.571429  0.643854
# 23     -0.965012 -1.945139   882.775696            0.603448  0.248044
# 24     -0.028729  1.793943  1194.469727            0.479167  0.548132
# 25     -0.283393 -0.533182   642.556946            0.750000  0.437456
# 26      0.337100  0.543027   818.530090            0.513889  0.253783
# 27     -0.849820 -1.163341  1714.166870            0.321429  0.455497
# 28      0.551213 -2.948952  1280.083618            0.507246  0.238844
# 29     -0.139992 -3.015406   778.579773            0.625000  0.297276
# ...          ...       ...          ...                 ...       ...
# 103386 -0.777233  1.076672   537.510498            0.541667  0.313189
# 103387  0.093429  1.750992   567.386536            0.780488  0.195785
# 103388 -0.140647 -0.287098   438.255615            0.722222  0.387304
# 103389 -0.625187 -0.518215   539.317261            0.732143  0.186291
# 103390  0.501899  2.260820   327.454163            0.884615  0.155193
# 103391 -0.671737 -1.935592   488.134399            0.562500  0.339051
# 103392 -0.248868  2.237542   512.103577            0.517857  0.263996
# 103393 -0.556577 -1.741644   304.653137            0.680000  0.353932
# 103399  0.094948        2.0  1115.146208
# 103400  0.013452        2.0   928.268144
# 103401  0.017875        1.0   480.126553
# 103402  0.020780        3.0   488.758627
# 103403  0.017165        3.0   440.403674
# 103404  0.017596        1.0   360.688050
# 103405  0.060339       21.0   440.743713
# 103406  0.037106        2.0   504.866810
# 103407  0.027390        1.0   234.123772
# 103408  0.009190        1.0   689.268892
# 103409  0.012631        3.0   580.483251
# 103410  0.039075        1.0   336.657709
# 103411  0.019636       21.0   726.260814
# 103412  0.016043        2.0   460.304188
# 103413  0.009017        1.0   610.087231
# 103414  0.007267        4.0   472.207252
# 103415  0.030352        3.0   380.959989
#
# [103416 rows x 8 columns]

# %% [markdown]
# #### plotting
# we'll also plot the input histograms here, to make sure there are no screaming discrepancies in the training and testing sets

# %%
tagged, tag_index = utils.split_table_by_column(
    "jetFlavor",
    data,
    utils.delphes_jet_tags_dict,
    False
)
sizes = map(lambda x: x.shape[0], tagged)
for t,s in zip(tagged, sizes):
    print  "{} jet: {}, {}%".format(t.name, s, round(100.*s/sum(sizes), 1))
# Out:
# down jet: 18999, 18.4%
# up jet: 38841, 37.6%
# strange jet: 25377, 24.5%
# charm jet: 9577, 9.3%
# bottom jet: 3341, 3.2%
# gluon jet: 7281, 7.0%

# %% [markdown]
# We then get training/testing datasets, and normalize them to the main data set. We can check how the normalized features look compared with one another, to make sure that they are useful. This way we can decide what type of normalization to use.

# %%
split = 0.25

train, test = data.train_test_split(split)

train_tags, test_tags = map(
    lambda x: utils.split_table_by_column(
        "jetFlavor", x,
        utils.delphes_jet_tags_dict, False
    )[0],
    [train, test]
)

for trt, tet in zip(train_tags, test_tags):
    print "{}:".format(trt.name)
    print "\t{:.1f}% ({}) train".format(100.*trt.shape[0]/train.shape[0], trt.shape[0])
    print "\t{:.1f}% ({}) test".format(100.*tet.shape[0]/test.shape[0], tet.shape[0])
    print "\t{:.1f}% ({}) original".format(100.*(tet.shape[0] + trt.shape[0])/data.shape[0], trt.shape[0] + tet.shape[0])

for full, trt, tet in zip(tagged, train_tags, test_tags):
    trt.name = "train_" + trt.name
    tet.name = "test_" + tet.name
    trt.plot([tet, full], normed=1)

# data.plot([train, test], normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# data.plot(jet_tables, normed=1, bins=32, figsize=(30,15), fontsize=25, cols=4, alpha=1)
# Out:
# down:
# 	18.3% (14206) train
# 	18.5% (4793) test
# 	18.4% (18999) original
# up:
# 	37.6% (29179) train
# 	37.4% (9662) test
# 	37.6% (38841) original
# strange:
# 	24.5% (19003) train
# 	24.7% (6374) test
# 	24.5% (25377) original
# charm:
# 	9.4% (7253) train
# 	9.0% (2324) test
# 	9.3% (9577) original
# bottom:
# 	3.2% (2480) train
# 	3.3% (861) test
# 	3.2% (3341) original
# gluon:
# 	7.0% (5441) train
# 	7.1% (1840) test
# 	7.0% (7281) original
# data_table :: plotting distrubution(s) for table(s) ['train_down', 'test_down', 'down']

# %% [markdown]
# we will use `RobustScaler`, because the results look the best (and train the best ;-))

# %%
tagged[0].plot(tagged[1:], normed=0, bins=50, cols=2, figsize=(10,20), rng=(
        (0,2), (-3.2, 3.2), (0,2500), (0,1), (0, 0.8),(0,.1), (0,3000)))
# Out:
# data_table :: plotting distrubution(s) for table(s) ['down', 'up', 'strange', 'charm', 'bottom', 'gluon']

# %%
raw = data.cdrop("*Flavor")

norm_args = {
    "norm_type": "StandardScaler",
#     "feature_range": (0.01, 0.99)
}

train_raw = train.cdrop("*Flavor")
test_raw = test.cdrop("*Flavor")
train_norm, test_norm = train_raw.norm(**norm_args), train_raw.norm(test_raw, **norm_args)

norm = train_raw.norm(raw, **norm_args)
features = [utils.data_table(norm[c].values.reshape(norm[c].shape[0],1), name=c, headers=["normed features"]) for c in norm]
features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10, figloc="upper right")

# rmin, rmax = np.asarray([(data.median() - 2.*data.std()).values, (data.median() + 2.*data.std()).values])
# custom_norm = lambda x: (x - rmin) / (rmax - rmin)
# # norm_data = data.norm(norm_type=0, rng=rng)
# norm_data = custom_norm(data)
# features = [utils.data_table(norm_data[c].values.reshape(norm_data[c].shape[0],1), name=c, headers=["normed features"]) for c in norm_data]
# features[0].plot(features[1:], bins=50, figsize=(8,8), fontsize=10)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jetEta', 'jetPhi', 'jetPt', 'jetChargedFraction', 'jetPTD', 'jetAxis2', 'jetEnergy']

# %% [markdown]
# ### 2. build model
# To make our model, we'll use the simple "shallow" architecture defined in models.py. This gives us a decidedly shallow autoencoder with a bottleneck of our liking.

# %%
bn = 4
name = "bn_{1}_{0}".format(version_id, bn)
path = "autoencode/data/training_runs/7jf/custom"

ae_skeleton = models.base_autoencoder()
ae_skeleton.add(7)
ae_skeleton.add(40)
ae_skeleton.add(bn, 'relu')
ae_skeleton.add(40)
ae_skeleton.add(7, "linear")
autoencoder = ae_skeleton.build()
encoder, decoder = autoencoder.layers[1:]
instance = trainer.trainer(os.path.join(os.path.join(repo_head, path), name))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-11-dee1de4b001f> in <module>()
#      11 autoencoder = ae_skeleton.build()
#      12 encoder, decoder = autoencoder.layers[1:]
# ---> 13 instance = trainer.trainer(os.path.join(os.path.join(repo_head, path), name))
#
# /afs/cern.ch/user/l/llepotti/.local/lib/python2.7/site-packages/autoencodeSVJ/trainer.pyc in __init__(self, name, verbose, overwrite)
#     128             self._throw("filename '{}' is already being edited in another instance!!".format(self.config_file))
#     129
# --> 130         self.file = h5py.File(self.config_file)
#     131
#     132         # self._lock_file(self.config_file)
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-centos7-gcc7-opt/lib/python2.7/site-packages/h5py/_hl/files.pyc in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     270
#     271                 fapl = make_fapl(driver, libver, **kwds)
# --> 272                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     273
#     274                 if swmr_support:
#
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-centos7-gcc7-opt/lib/python2.7/site-packages/h5py/_hl/files.pyc in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     115                 fid = h5f.open(name, h5f.ACC_RDONLY, fapl=fapl)
#     116             except IOError:
# --> 117                 fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     118     else:
#     119         raise ValueError("Invalid mode; must be one of r, r+, w, w-, x, a")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# IOError: Unable to create file (Unable to open file: name = '/afs/cern.ch/work/l/llepotti/private/cms/cmssw_8_0_20/src/autoencodesvj/autoencode/data/training_runs/7jf/custom/bn_4_v2.h5', errno = 17, error message = 'file exists', flags = 15, o_flags = c2)

# %% [markdown]
# ... and the model summaries:

# %%
print('encoder summary:')
encoder.summary()
print('\n')
print('decoder summary:')
decoder.summary()
print('\n')
print('autoencoder summary:')
autoencoder.summary()
# Out:
# encoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# layer_2 (Dense)              (None, 30)                240
# _________________________________________________________________
# layer_3 (Dense)              (None, 30)                930
# _________________________________________________________________
# layer_4 (Dense)              (None, 4)                 124
# =================================================================
# Total params: 1,294
# Trainable params: 1,294
# Non-trainable params: 0
# _________________________________________________________________
#
#
# decoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_4 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# layer_5 (Dense)              (None, 40)                200
# _________________________________________________________________
# layer_6 (Dense)              (None, 7)                 287
# =================================================================
# Total params: 487
# Trainable params: 487
# Non-trainable params: 0
# _________________________________________________________________
#
#
# autoencoder summary:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1 (InputLayer)         (None, 7)                 0
# _________________________________________________________________
# encoder (Model)              (None, 4)                 1294
# _________________________________________________________________
# decoder (Model)              (None, 7)                 487
# =================================================================
# Total params: 1,781
# Trainable params: 1,781
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3. train model
# this can be most easily done using the `training_skeleton`, defined in `skeletons.py`. This helps with dynamic training and allows for stopping midway without losing history information, retraining models, etc.

# %%
# name = "medium_4_test"
# instance = trainer.trainer(os.path.join("../data/training_runs/7jf/mean_std_norm/", name))

# %% [markdown]
# training is easy:

# %%
from keras import backend as K

def r_square(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return SS_res/(SS_tot + K.epsilon())

# train, test = data.train_test_split(0.25)
# ntype="RobustScaler"
# train_norm, test_norm = data.norm(train, norm_type=ntype), data.norm(test, norm_type=ntype)

autoencoder = instance.train(
    x_train=train_norm.data,
    x_test=test_norm.data,
    y_train=train_norm.data,
    y_test=test_norm.data,
    optimizer="adam",
    loss=r_square_loss,
    epochs=10,
    model=autoencoder,
    metrics=[r_square, "mae", "mse"],
    force=True,
    batch_size=128,
    use_callbacks=True,
    learning_rate=0.001
)
# Out:
# train_shell :: using model passed as function argument
# Train on 7865 samples, validate on 3371 samples
# Epoch 91/100
# 245/245 [==============================] - 4s 17ms/step - loss: 0.0629 - r_square: 0.9371 - mean_absolute_error: 0.1974 - mean_squared_error: 0.0831 - val_loss: 0.0651 - val_r_square: 0.9349 - val_mean_absolute_error: 0.1991 - val_mean_squared_error: 0.0857
# Epoch 92/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0625 - r_square: 0.9375 - mean_absolute_error: 0.1967 - mean_squared_error: 0.0826 - val_loss: 0.0651 - val_r_square: 0.9349 - val_mean_absolute_error: 0.1990 - val_mean_squared_error: 0.0857
# Epoch 93/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0623 - r_square: 0.9377 - mean_absolute_error: 0.1963 - mean_squared_error: 0.0823 - val_loss: 0.0650 - val_r_square: 0.9350 - val_mean_absolute_error: 0.1988 - val_mean_squared_error: 0.0856
# Epoch 94/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0621 - r_square: 0.9379 - mean_absolute_error: 0.1959 - mean_squared_error: 0.0820 - val_loss: 0.0649 - val_r_square: 0.9351 - val_mean_absolute_error: 0.1985 - val_mean_squared_error: 0.0854
# Epoch 95/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0619 - r_square: 0.9381 - mean_absolute_error: 0.1955 - mean_squared_error: 0.0817 - val_loss: 0.0647 - val_r_square: 0.9353 - val_mean_absolute_error: 0.1983 - val_mean_squared_error: 0.0852
# Epoch 96/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0617 - r_square: 0.9383 - mean_absolute_error: 0.1951 - mean_squared_error: 0.0815 - val_loss: 0.0646 - val_r_square: 0.9354 - val_mean_absolute_error: 0.1978 - val_mean_squared_error: 0.0850
# Epoch 97/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0615 - r_square: 0.9385 - mean_absolute_error: 0.1948 - mean_squared_error: 0.0812 - val_loss: 0.0645 - val_r_square: 0.9355 - val_mean_absolute_error: 0.1977 - val_mean_squared_error: 0.0850
# Epoch 98/100
# 245/245 [==============================] - 3s 10ms/step - loss: 0.0613 - r_square: 0.9387 - mean_absolute_error: 0.1944 - mean_squared_error: 0.0810 - val_loss: 0.0645 - val_r_square: 0.9355 - val_mean_absolute_error: 0.1976 - val_mean_squared_error: 0.0849
# Epoch 99/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0612 - r_square: 0.9388 - mean_absolute_error: 0.1941 - mean_squared_error: 0.0808 - val_loss: 0.0644 - val_r_square: 0.9356 - val_mean_absolute_error: 0.1972 - val_mean_squared_error: 0.0847
# Epoch 100/100
# 245/245 [==============================] - 3s 11ms/step - loss: 0.0610 - r_square: 0.9390 - mean_absolute_error: 0.1938 - mean_squared_error: 0.0806 - val_loss: 0.0643 - val_r_square: 0.9357 - val_mean_absolute_error: 0.1968 - val_mean_squared_error: 0.0847
# EPOCH N: 100 10
# train_shell ::
# train_shell :: trained 10 epochs!
# train_shell ::
# finished epoch N 100
# prev [40, 10, 10, 10, 10, 10, 10]
# train_shell :: model saved

# %% [markdown]
# ### 4. check results
# it is easy to check things like loss, accuracy, etc. later on with this method - all data is saved to an h5 file unique to that training name.

# %%
instance.plot_metrics(fnmatch_criteria="*mean_s*", yscale="linear")
instance.plot_metrics(fnmatch_criteria="*absolute*", yscale="linear")
instance.plot_metrics(fnmatch_criteria="*r_s*", yscale="linear")

# %% [markdown]
# checking results:

# %%
data_recon_norm = utils.data_table(autoencoder.predict(data.norm(**norm_args).df.values), headers=train_norm.headers)
data_recon = data.inorm(data_recon_norm, **norm_args)
data_recon.name = "all jet data (pred)"

train_reconstructed_norm = utils.data_table(autoencoder.predict(train_norm.data), headers=train_norm.headers)
test_reconstructed_norm = utils.data_table(autoencoder.predict(test_norm.data), headers=test_norm.headers)

train_reconstructed = data.inorm(train_reconstructed_norm, **norm_args)
test_reconstructed = data.inorm(test_reconstructed_norm, **norm_args)


train_reconstructed.name = "train reconstructed"
test_reconstructed.name = "test reconstructed"

# train.plot([train_reconstructed],
#     normed=0, bins=50, alpha=1.0, figloc="upper right",
#     figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
# )
# test.plot([test_reconstructed], 
#       normed=0, bins=50, alpha=1.0, figloc="upper right",
#     figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
# )
data.plot(
#     [train_reconstructed, test_reconstructed],
    data_recon,
    normed=1, bins=50, alpha=1.0, figloc="upper right",
    figsize=(25,15), fontsize=22, rng=[(-2,2), (-4,4), (0,2000), (0,210), (0,1), (0,0.8), (0, .10)]
)

# data.norm(**norm_args).plot(
#     data_recon_norm,
#     normed=0, bins=50, alpha=1.0, figloc="upper right",
#     figsize=(25,15), fontsize=22
# )
# Out:
# data_table :: plotting distrubution(s) for table(s) ['all jet data', 'all jet data (pred)']

# %%
encoder, decoder = autoencoder.layers[1:]
all_reps = utils.data_table(encoder.predict(data.norm(**norm_args).data), headers=["rep {}".format(i + 1) for i in range(4)], name="all_reps")
train_reps, test_reps = (
    utils.data_table(encoder.predict(train_norm.data), headers=["rep {}".format(i + 1) for i in range(4)], name="train_reps"),
    utils.data_table(encoder.predict(test_norm.data), headers=["rep {}".format(i + 1) for i in range(4)], name="test_reps")
)

# %%
train_reps.plot([test_reps], cols=5, figsize=(25,5), fontsize=22, normed=1, bins=40)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['train_reps', 'test_reps']

# %%
import keras
errors = utils.data_table(np.asarray(map(
        lambda x: keras.backend.eval(getattr(keras.losses, x)(data.norm(**norm_args).data, data_recon_norm.data)),
        ["mse", "mae"]
    )).T,                      
    headers=["mse", "mae"],
    name="errors"
)
outlier_fraction = 0.02
index = np.argsort(errors.mse)
out_index = index[-int(outlier_fraction*len(errors)):]
reg_index = index[:-int(outlier_fraction*len(errors))]
# print out_index.size + reg_index.size,len(errors)
# print out_index.size, reg_index.size
out,reg = (
    utils.data_table(data.data[out_index], headers=data.headers, name="outliers (top {})".format(outlier_fraction)), 
    utils.data_table(data.data[reg_index], headers=data.headers, name="normal")
)
out_reps, reg_reps = (
    utils.data_table(all_reps.data[out_index], headers=all_reps.headers, name="outlier reps"), 
    utils.data_table(all_reps.data[reg_index], headers=all_reps.headers, name="normal reps")
)
out_reps.plot(reg_reps, normed=1, bins=50, figsize=(20,4))
# reg.plot(out, normed=1, bins=50, figsize=(20,10))
# Out:
# data_table :: plotting distrubution(s) for table(s) ['outlier reps', 'normal reps']
