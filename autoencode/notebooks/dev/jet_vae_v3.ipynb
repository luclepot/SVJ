# %%
from autoencodeSVJ import utils, models, trainer
import glob
import os
import numpy as np
import keras
import keras.backend as K
import matplotlib.pyplot as plt
import root_numpy as rtnp

version_id = 'v3'
SEED = 42
# Out:
# Using TensorFlow backend.
# Welcome to JupyROOT 6.12/06

# %%
# get h5 datasets
data_path = "data/background/*_data.h5"
signal_path = "data/signal/*_data.h5"

data, data_tags, data_jets = utils.load_all_data(data_path, "background")
signal, signal_tags, signal_jets = utils.load_all_data(signal_path, "signal")

split = 0.2

train, test = data.train_test_split(split, SEED)
utils.compare_tags([train, test, data, signal])

data_raw = data.cdrop("*Flavor")
signal_raw = signal.cdrop("*Flavor")
train_raw = train.cdrop("*Flavor")
test_raw = test.cdrop("*Flavor")

norm_args = {"norm_type": "StandardScaler"}
train_norm, test_norm = train_raw.norm(**norm_args), train_raw.norm(test_raw, **norm_args)
data_norm, signal_norm = train_raw.norm(data_raw, **norm_args), train_raw.norm(signal_raw, **norm_args)
# Out:
# background tags:
#
# down jet: 18999, 18.4%
# up jet: 38841, 37.6%
# strange jet: 25377, 24.5%
# charm jet: 9577, 9.3%
# bottom jet: 3341, 3.2%
# gluon jet: 7281, 7.0%
#
# signal tags:
#
# down jet: 1220, 2.5%
# up jet: 1866, 3.8%
# strange jet: 1550, 3.1%
# charm jet: 3344, 6.8%
# bottom jet: 38995, 78.8%
# gluon jet: 2541, 5.1%
#
# bottom:
# 	3.2% (2664) train
# 	3.3% (677) test
# 	3.2% (3341) background
# 	78.8% (38995) signal
# up:
# 	37.5% (30997) train
# 	37.9% (7844) test
# 	37.6% (38841) background
# 	3.8% (1866) signal
# down:
# 	18.4% (15192) train
# 	18.4% (3807) test
# 	18.4% (18999) background
# 	2.5% (1220) signal
# strange:
# 	24.6% (20367) train
# 	24.2% (5010) test
# 	24.5% (25377) background
# 	3.1% (1550) signal
# charm:
# 	9.3% (7667) train
# 	9.2% (1910) test
# 	9.3% (9577) background
# 	6.8% (3344) signal
# gluon:
# 	7.1% (5845) train
# 	6.9% (1436) test
# 	7.0% (7281) background
# 	5.1% (2541) signal

# %% [markdown]
# ### Make autoencoder
# Here we have some characterizing parameters for the VAE which can be messed with to try and acheive better results.

# %%
l1_amount = None          # l1 regularization amount
KL_loss_weight = 1.8    # according to olmo's paper
input_dim = 7              # num. HLF
interm_dim = 20            # num. interm nodes
neck_dim = 2              # num. latent variables
kernel_max_norm = None     # kernel max norm amount

name = "bn_{0}_{1}".format(neck_dim, version_id)
repo_head = utils.get_repo_info()['head']
model_path = repo_head + "/autoencode/data/training_runs/"

# %% [markdown]
# Loss functions and helpers

# %%
import keras.backend as K
import keras

def isrlu(args, min_value = 5e-3):
    """ranges from (0, +inf), with relu behavior at x > 0 and exponential decay at x < 0"""
    return 1. + min_value + K.tf.where(K.tf.greater(args, 0), args, K.tf.divide(args, K.sqrt(1+K.square(args))))

def sample_from_gauss(args):
    """reparam trick for VAE"""
    z_mean, z_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], K.shape(z_mean)[1]), mean=0., stddev=1.)
    return z_mean + z_sigma * epsilon

def make_zero(x):
    """lambda zero function, for forward pass of priors from x variable"""
    return 0.*x

def KL_loss(mu, sigma, mu_prior, sigma_prior):
    """KL loss from mu, sigma, and their priors"""
    kl_loss = K.tf.multiply(K.square(sigma), K.square(sigma_prior))
    kl_loss += K.square(K.tf.divide(mu_prior - mu, sigma_prior))
    kl_loss += K.log(K.tf.divide(sigma_prior, sigma)) -1
    return 0.5 * K.sum(kl_loss, axis=-1)

def reconstruction_probability(x, mu, sigma):
    """calculate gaussian -log likelihood across all variables and sum"""
    z_score = K.tf.divide(x - mu, sigma)
    single = - K.log(1./(sigma*np.sqrt(2.*np.pi)))/np.log(np.e) + 0.5*K.square(z_score)
    return K.sum(single, axis=-1)

class recon_prob_wrapper_layer(keras.layers.Layer):
    """Wrapper for recon. prob. function. 
    Outputs reconstruction probability of gaussians for vae
    """
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(recon_prob_wrapper_layer, self).__init__(**kwargs)
    
    def call(self, inputs):
        x, mu, sigma = inputs
        return reconstruction_probability(x, mu, sigma)
    
class KL_loss_wrapper_layer(keras.layers.Layer):
    """Wrapper for KL_loss function. 
    Layer which outputs KL loss according the the function defined above
    """
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(KL_loss_wrapper_layer, self).__init__(**kwargs)
    
    def call(self, inputs):
        mu, sigma, mu_prior, sigma_prior = inputs
        return KL_loss(mu, sigma, mu_prior, sigma_prior)
    
def Identity(y_train, vae_output):
    """identity loss, takes into account ONLY the VAE output (vae output should actually be the 
    calculated loss functions!)"""
    return K.mean(vae_output)

custom_objects = {
    "isrlu": isrlu,
    "sample_from_gauss": sample_from_gauss,
    "make_zero": make_zero,
    "KL_loss": KL_loss,
    "reconstruction_probability": reconstruction_probability,
    "recon_prob_wrapper_layer": recon_prob_wrapper_layer,
    "KL_loss_wrapper_layer": KL_loss_wrapper_layer,
    "Identity": Identity,
}

# %% [markdown]
# ### Define layers
# Define layers to setup layer architecture for later

# %%
import keras.backend as K
import keras
from keras.constraints import max_norm

# define layers
input_layer = keras.layers.Input(shape=(input_dim,), name="input")

intermediate_layer_enc1 = keras.layers.Dense(interm_dim, name="hidden_enc1")
intermediate_layer_enc2 = keras.layers.Dense(interm_dim, activation='relu', kernel_constraint=max_norm(kernel_max_norm), name='hidden_enc2')

z_mu_layer = keras.layers.Dense(neck_dim, name='z_mu')
z_sigma_pre_layer = keras.layers.Dense(neck_dim, name="z_sigma_pre")
z_sigma_layer = keras.layers.Lambda(isrlu, name="z_sigma")

z_latent_layer = keras.layers.Lambda(sample_from_gauss, name="latent_sampling")
z_input_layer = keras.layers.Input(shape=(neck_dim,), name="z_input_layer")

intermediate_layer_dec1 = keras.layers.Dense(interm_dim, name="hidden_dec1", kernel_constraint=max_norm(kernel_max_norm))
intermediate_layer_dec2 = keras.layers.Dense(interm_dim, name="hidden_dec2")

output_sigma_pre_layer = keras.layers.Dense(input_dim, name="output_sigma_pre", activation="linear")
output_sigma_layer = keras.layers.Lambda(isrlu, name="output_sigma")
output_mu_layer = keras.layers.Dense(input_dim, name="output_mu", activation="linear")

# prior layers for KL divergence
fixed_input_layer = keras.layers.Lambda(make_zero, name="fixed_input")
prior_layer = keras.layers.Dense(1, kernel_initializer='zeros', bias_initializer='ones', trainable=False, name='prior')
prior_mu_layer = keras.layers.Dense(neck_dim, kernel_initializer='zeros', bias_initializer='zeros', trainable=True, name='prior_mu')
prior_sigma_pre_layer = keras.layers.Dense(neck_dim, kernel_initializer='zeros', bias_initializer='ones', trainable=True, name='prior_sigma_pre')
prior_sigma_layer = keras.layers.Lambda(isrlu, name='prior_sigma')

# %%
## INPUT to encoder
aux = intermediate_layer_enc1(input_layer)   # first intermediate layer
aux = intermediate_layer_enc2(aux)

z_mu = z_mu_layer(aux)                    # z mu layer
z_sigma = z_sigma_layer(z_sigma_pre_layer(aux)) # z sigma layer (with correction)
z_latent = z_latent_layer([z_mu, z_sigma])      # z latent layer (draw from latent distribution, zmu/zsigma)

## INPUT to decoder
aux = intermediate_layer_dec1(z_latent) # z_input_layer if you want a decoder
aux = intermediate_layer_dec2(aux)
out_mu = output_mu_layer(aux)
out_sigma = output_sigma_layer(output_sigma_pre_layer(aux))
## OUTPUT to decoder

# reparameterization trick!
fixed_input = fixed_input_layer(input_layer)        # fixed input layer (no training)
prior = prior_layer(fixed_input)                    # prior layer (one node, all constant)
prior_mu = prior_mu_layer(prior)                    # mu layer (all ones, trainable)
prior_sigma = prior_sigma_layer(prior_sigma_pre_layer(prior)) # sigma layer (all geq zero, trainable)


# # make encoder/decoder models
# encoder = keras.models.Model(inputs=input_layer, outputs=z_latent, name="encoder")
# decoder = keras.models.Model(inputs=z_input_layer, outputs=[out_mu, out_sigma], name="decoder")

# reconstruction probability: create from input layer, as well as outputs of decoder (mu/sigma out)
reco_prob_out = recon_prob_wrapper_layer(name="reconstructed_probability")([input_layer, out_mu, out_sigma])
# KL loss: create from zed mu/sigma, as well as prior variables
KL_loss_out = KL_loss_wrapper_layer(name="KL_loss_layer")([z_mu, z_sigma, prior_mu, prior_sigma])

# autoencoder made from x-input to loss outputs
vae = keras.models.Model(inputs=input_layer, outputs=[KL_loss_out, reco_prob_out])

vae.compile(optimizer="adam", loss=[Identity, Identity], loss_weights=[KL_loss_weight, 1.])
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 7)            0
# __________________________________________________________________________________________________
# hidden_enc1 (Dense)             (None, 20)           160         input[0][0]
# __________________________________________________________________________________________________
# hidden_enc2 (Dense)             (None, 20)           420         hidden_enc1[0][0]
# __________________________________________________________________________________________________
# z_sigma_pre (Dense)             (None, 2)            42          hidden_enc2[0][0]
# __________________________________________________________________________________________________
# z_mu (Dense)                    (None, 2)            42          hidden_enc2[0][0]
# __________________________________________________________________________________________________
# z_sigma (Lambda)                (None, 2)            0           z_sigma_pre[0][0]
# __________________________________________________________________________________________________
# latent_sampling (Lambda)        (None, 2)            0           z_mu[0][0]
#                                                                  z_sigma[0][0]
# __________________________________________________________________________________________________
# fixed_input (Lambda)            (None, 7)            0           input[0][0]
# __________________________________________________________________________________________________
# hidden_dec1 (Dense)             (None, 20)           60          latent_sampling[0][0]
# __________________________________________________________________________________________________
# prior (Dense)                   (None, 1)            8           fixed_input[0][0]
# __________________________________________________________________________________________________
# hidden_dec2 (Dense)             (None, 20)           420         hidden_dec1[0][0]
# __________________________________________________________________________________________________
# prior_sigma_pre (Dense)         (None, 2)            4           prior[0][0]
# __________________________________________________________________________________________________
# output_sigma_pre (Dense)        (None, 7)            147         hidden_dec2[0][0]
# __________________________________________________________________________________________________
# prior_mu (Dense)                (None, 2)            4           prior[0][0]
# __________________________________________________________________________________________________
# prior_sigma (Lambda)            (None, 2)            0           prior_sigma_pre[0][0]
# __________________________________________________________________________________________________
# output_mu (Dense)               (None, 7)            147         hidden_dec2[0][0]
# __________________________________________________________________________________________________
# output_sigma (Lambda)           (None, 7)            0           output_sigma_pre[0][0]
# __________________________________________________________________________________________________
# KL_loss_layer (KL_loss_wrapper_ [(None, 2), (None, 2 0           z_mu[0][0]
#                                                                  z_sigma[0][0]
#                                                                  prior_mu[0][0]
#                                                                  prior_sigma[0][0]
# __________________________________________________________________________________________________
# reconstructed_probability (reco [(None, 7), (None, 7 0           input[0][0]
#                                                                  output_mu[0][0]
#                                                                  output_sigma[0][0]
# ==================================================================================================
# Total params: 1,454
# Trainable params: 1,446
# Non-trainable params: 8
# __________________________________________________________________________________________________

# %%
instance = trainer.trainer(os.path.join(model_path, name))
# Out:
# h5_elt 'metric_names' :: creating group 'data' in file 'bn_2_v3.h5'
# h5_elt 'metric_names' :: creating dataset 'data/metric_names' in file 'bn_2_v3.h5'
# h5_elt 'training' :: creating group 'params' in file 'bn_2_v3.h5'
# h5_elt 'training' :: creating dataset 'params/training' in file 'bn_2_v3.h5'
# h5_elt 'config' :: creating dataset 'params/config' in file 'bn_2_v3.h5'

# %%
vae = instance.load_model(custom_objects=custom_objects)
# Out:
# train_shell :: ERROR: no model passed and no saved model found!!
# AttributeErrorTraceback (most recent call last)
# <ipython-input-77-998bc2535cb9> in <module>()
# ----> 1 vae = instance.load_model(custom_objects=custom_objects)
#
# /t3home/llepotti/.local/lib/python2.7/site-packages/autoencodeSVJ/trainer.pyc in load_model(self, model, force, custom_objects)
#     271
#     272         if model is None:
# --> 273             self._throw("no model passed and no saved model found!!")
#     274
#     275         return model
#
# /t3home/llepotti/.local/lib/python2.7/site-packages/autoencodeSVJ/trainer.pyc in _throw(self, msg, exc, unlock)
#     186             self.close()
#     187         self.error(msg)
# --> 188         raise exc, msg
#     189
#     190     def close(
#
# AttributeError: no model passed and no saved model found!!

# %%
train = True
if train:
    vae = instance.train(
        x_train=train_norm.data,
        x_test=test_norm.data,
        y_train=[np.empty((train_norm.shape[0], neck_dim)), np.empty_like(train_norm.data)],
        y_test=[np.empty((test_norm.shape[0], neck_dim)), np.empty_like(test_norm.data)],
        optimizer="adam",
        loss=[Identity, Identity],
        loss_weights=[0., 1.0],
        epochs=20,
        model=vae,
        use_callbacks=True,
        learning_rate=0.0005,
        custom_objects=custom_objects,
        batch_size=500
    )
    vae = instance.train(
        x_train=train_norm.data,
        x_test=test_norm.data,
        y_train=[np.empty((train_norm.shape[0], neck_dim)), np.empty_like(train_norm.data)],
        y_test=[np.empty((test_norm.shape[0], neck_dim)), np.empty_like(test_norm.data)],
        optimizer="adam",
        loss=[Identity, Identity],
        loss_weights=[1.8, 1.0],
        epochs=100,
        model=vae,
        use_callbacks=True,
        learning_rate=0.0005,
        custom_objects=custom_objects,
        batch_size=500
    )
# Out:
# Train on 82732 samples, validate on 20684 samples
# Epoch 1/20
# 82732/82732 [==============================] - 3s 31us/step - loss: 12.6548 - KL_loss_layer_loss: 2.3359 - reconstructed_probability_loss: 12.6548 - val_loss: 10.1800 - val_KL_loss_layer_loss: 2.1012 - val_reconstructed_probability_loss: 10.1800
# Epoch 2/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 9.8447 - KL_loss_layer_loss: 1.9817 - reconstructed_probability_loss: 9.8447 - val_loss: 9.4901 - val_KL_loss_layer_loss: 1.9076 - val_reconstructed_probability_loss: 9.4901
# Epoch 3/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 9.1236 - KL_loss_layer_loss: 1.8638 - reconstructed_probability_loss: 9.1236 - val_loss: 8.7389 - val_KL_loss_layer_loss: 1.8438 - val_reconstructed_probability_loss: 8.7389
# Epoch 4/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.3734 - KL_loss_layer_loss: 1.8427 - reconstructed_probability_loss: 8.3734 - val_loss: 7.9393 - val_KL_loss_layer_loss: 1.8850 - val_reconstructed_probability_loss: 7.9393
# Epoch 5/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.4315 - KL_loss_layer_loss: 1.9838 - reconstructed_probability_loss: 7.4315 - val_loss: 6.8938 - val_KL_loss_layer_loss: 2.1280 - val_reconstructed_probability_loss: 6.8938
# Epoch 6/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 6.4560 - KL_loss_layer_loss: 2.3416 - reconstructed_probability_loss: 6.4560 - val_loss: 6.0723 - val_KL_loss_layer_loss: 2.6157 - val_reconstructed_probability_loss: 6.0723
# Epoch 7/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 5.8710 - KL_loss_layer_loss: 2.8665 - reconstructed_probability_loss: 5.8710 - val_loss: 5.6989 - val_KL_loss_layer_loss: 3.1183 - val_reconstructed_probability_loss: 5.6989
# Epoch 8/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 5.5846 - KL_loss_layer_loss: 3.3029 - reconstructed_probability_loss: 5.5846 - val_loss: 5.4515 - val_KL_loss_layer_loss: 3.4927 - val_reconstructed_probability_loss: 5.4515
# Epoch 9/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 5.3207 - KL_loss_layer_loss: 3.6130 - reconstructed_probability_loss: 5.3207 - val_loss: 5.1420 - val_KL_loss_layer_loss: 3.7538 - val_reconstructed_probability_loss: 5.1420
# Epoch 10/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 4.8807 - KL_loss_layer_loss: 3.8432 - reconstructed_probability_loss: 4.8807 - val_loss: 4.4905 - val_KL_loss_layer_loss: 3.9714 - val_reconstructed_probability_loss: 4.4905
# Epoch 11/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 3.8480 - KL_loss_layer_loss: 4.1786 - reconstructed_probability_loss: 3.8480 - val_loss: 3.1839 - val_KL_loss_layer_loss: 4.4888 - val_reconstructed_probability_loss: 3.1839
# Epoch 12/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 2.7663 - KL_loss_layer_loss: 4.7559 - reconstructed_probability_loss: 2.7663 - val_loss: 2.3569 - val_KL_loss_layer_loss: 5.0040 - val_reconstructed_probability_loss: 2.3569
# Epoch 13/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 2.0908 - KL_loss_layer_loss: 5.1741 - reconstructed_probability_loss: 2.0908 - val_loss: 1.9079 - val_KL_loss_layer_loss: 5.3699 - val_reconstructed_probability_loss: 1.9079
# Epoch 14/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 1.6009 - KL_loss_layer_loss: 5.5100 - reconstructed_probability_loss: 1.6009 - val_loss: 1.3749 - val_KL_loss_layer_loss: 5.6709 - val_reconstructed_probability_loss: 1.3749
# Epoch 15/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 1.1020 - KL_loss_layer_loss: 5.7873 - reconstructed_probability_loss: 1.1020 - val_loss: 0.8015 - val_KL_loss_layer_loss: 5.9426 - val_reconstructed_probability_loss: 0.8015
# Epoch 16/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 0.7857 - KL_loss_layer_loss: 6.0295 - reconstructed_probability_loss: 0.7857 - val_loss: 0.6611 - val_KL_loss_layer_loss: 6.1510 - val_reconstructed_probability_loss: 0.6611
# Epoch 17/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 0.4385 - KL_loss_layer_loss: 6.2292 - reconstructed_probability_loss: 0.4385 - val_loss: 0.7968 - val_KL_loss_layer_loss: 6.3416 - val_reconstructed_probability_loss: 0.7968
# Epoch 18/20
# 82732/82732 [==============================] - 1s 13us/step - loss: 0.1774 - KL_loss_layer_loss: 6.3982 - reconstructed_probability_loss: 0.1774 - val_loss: 0.0747 - val_KL_loss_layer_loss: 6.5005 - val_reconstructed_probability_loss: 0.0747
# Epoch 19/20
# 82732/82732 [==============================] - 1s 14us/step - loss: -0.0874 - KL_loss_layer_loss: 6.5524 - reconstructed_probability_loss: -0.0874 - val_loss: -0.2338 - val_KL_loss_layer_loss: 6.6489 - val_reconstructed_probability_loss: -0.2338
# Epoch 20/20
# 82732/82732 [==============================] - 1s 13us/step - loss: -0.1778 - KL_loss_layer_loss: 6.6822 - reconstructed_probability_loss: -0.1778 - val_loss: -0.5112 - val_KL_loss_layer_loss: 6.7627 - val_reconstructed_probability_loss: -0.5112
# EPOCH N: 20 20
# train_shell ::
# train_shell :: trained 20 epochs!
# train_shell ::
# h5_elt 'loss' :: creating group 'metric_names' in file 'bn_2_v3.h5'
# h5_elt 'loss' :: creating dataset 'metric_names/loss' in file 'bn_2_v3.h5'
# h5_elt 'KL_loss_layer_loss' :: creating dataset 'metric_names/KL_loss_layer_loss' in file 'bn_2_v3.h5'
# h5_elt 'lr' :: creating dataset 'metric_names/lr' in file 'bn_2_v3.h5'
# h5_elt 'val_KL_loss_layer_loss' :: creating dataset 'metric_names/val_KL_loss_layer_loss' in file 'bn_2_v3.h5'
# h5_elt 'val_reconstructed_probability_loss' :: creating dataset 'metric_names/val_reconstructed_probability_loss' in file 'bn_2_v3.h5'
# h5_elt 'reconstructed_probability_loss' :: creating dataset 'metric_names/reconstructed_probability_loss' in file 'bn_2_v3.h5'
# h5_elt 'val_loss' :: creating dataset 'metric_names/val_loss' in file 'bn_2_v3.h5'
# finished epoch N 20
# prev [20]
# train_shell :: model saved
# train_shell :: ERROR: IGNORING PASSED PARAMETER 'model'
# train_shell :: using saved model
# Train on 82732 samples, validate on 20684 samples
# Epoch 21/120
# 82732/82732 [==============================] - 3s 32us/step - loss: 12.1672 - KL_loss_layer_loss: 6.3122 - reconstructed_probability_loss: 0.8053 - val_loss: 10.3206 - val_KL_loss_layer_loss: 5.9357 - val_reconstructed_probability_loss: -0.3636
# Epoch 22/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 9.8708 - KL_loss_layer_loss: 5.6121 - reconstructed_probability_loss: -0.2310 - val_loss: 9.5462 - val_KL_loss_layer_loss: 5.3735 - val_reconstructed_probability_loss: -0.1261
# Epoch 23/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 9.2648 - KL_loss_layer_loss: 5.1913 - reconstructed_probability_loss: -0.0796 - val_loss: 9.0501 - val_KL_loss_layer_loss: 5.0654 - val_reconstructed_probability_loss: -0.0676
# Epoch 24/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.8610 - KL_loss_layer_loss: 4.9473 - reconstructed_probability_loss: -0.0441 - val_loss: 8.6838 - val_KL_loss_layer_loss: 4.8654 - val_reconstructed_probability_loss: -0.0740
# Epoch 25/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.5832 - KL_loss_layer_loss: 4.7843 - reconstructed_probability_loss: -0.0285 - val_loss: 8.4768 - val_KL_loss_layer_loss: 4.7339 - val_reconstructed_probability_loss: -0.0442
# Epoch 26/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.3613 - KL_loss_layer_loss: 4.6706 - reconstructed_probability_loss: -0.0458 - val_loss: 8.2791 - val_KL_loss_layer_loss: 4.6365 - val_reconstructed_probability_loss: -0.0667
# Epoch 27/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.2346 - KL_loss_layer_loss: 4.5901 - reconstructed_probability_loss: -0.0275 - val_loss: 8.1366 - val_KL_loss_layer_loss: 4.5680 - val_reconstructed_probability_loss: -0.0858
# Epoch 28/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.0962 - KL_loss_layer_loss: 4.5319 - reconstructed_probability_loss: -0.0613 - val_loss: 8.0719 - val_KL_loss_layer_loss: 4.5135 - val_reconstructed_probability_loss: -0.0525
# Epoch 29/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 8.0259 - KL_loss_layer_loss: 4.4881 - reconstructed_probability_loss: -0.0527 - val_loss: 7.9675 - val_KL_loss_layer_loss: 4.4785 - val_reconstructed_probability_loss: -0.0937
# Epoch 30/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.9772 - KL_loss_layer_loss: 4.4581 - reconstructed_probability_loss: -0.0475 - val_loss: 7.8922 - val_KL_loss_layer_loss: 4.4547 - val_reconstructed_probability_loss: -0.1262
# Epoch 31/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.8984 - KL_loss_layer_loss: 4.4321 - reconstructed_probability_loss: -0.0793 - val_loss: 7.8584 - val_KL_loss_layer_loss: 4.4306 - val_reconstructed_probability_loss: -0.1167
# Epoch 32/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.9154 - KL_loss_layer_loss: 4.4148 - reconstructed_probability_loss: -0.0312 - val_loss: 7.8652 - val_KL_loss_layer_loss: 4.4113 - val_reconstructed_probability_loss: -0.0751
# Epoch 33/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.8351 - KL_loss_layer_loss: 4.4014 - reconstructed_probability_loss: -0.0874 - val_loss: 7.7438 - val_KL_loss_layer_loss: 4.4012 - val_reconstructed_probability_loss: -0.1783
# Epoch 34/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.8357 - KL_loss_layer_loss: 4.3968 - reconstructed_probability_loss: -0.0786 - val_loss: 7.7818 - val_KL_loss_layer_loss: 4.3946 - val_reconstructed_probability_loss: -0.1284
# Epoch 35/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.8525 - KL_loss_layer_loss: 4.3873 - reconstructed_probability_loss: -0.0447 - val_loss: 7.8858 - val_KL_loss_layer_loss: 4.3819 - val_reconstructed_probability_loss: -0.0016
# Epoch 36/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.8114 - KL_loss_layer_loss: 4.3741 - reconstructed_probability_loss: -0.0619 - val_loss: 7.8588 - val_KL_loss_layer_loss: 4.3746 - val_reconstructed_probability_loss: -0.0155
# Epoch 37/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.7697 - KL_loss_layer_loss: 4.3702 - reconstructed_probability_loss: -0.0967 - val_loss: 7.7562 - val_KL_loss_layer_loss: 4.3752 - val_reconstructed_probability_loss: -0.1190
# Epoch 38/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.7530 - KL_loss_layer_loss: 4.3781 - reconstructed_probability_loss: -0.1277 - val_loss: 7.7937 - val_KL_loss_layer_loss: 4.3882 - val_reconstructed_probability_loss: -0.1050
# Epoch 39/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.7858 - KL_loss_layer_loss: 4.3799 - reconstructed_probability_loss: -0.0980 - val_loss: 7.6815 - val_KL_loss_layer_loss: 4.3847 - val_reconstructed_probability_loss: -0.2109
# Epoch 40/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.7528 - KL_loss_layer_loss: 4.3805 - reconstructed_probability_loss: -0.1320 - val_loss: 7.7026 - val_KL_loss_layer_loss: 4.3904 - val_reconstructed_probability_loss: -0.2001
# Epoch 41/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.7288 - KL_loss_layer_loss: 4.3873 - reconstructed_probability_loss: -0.1683 - val_loss: 7.6863 - val_KL_loss_layer_loss: 4.3932 - val_reconstructed_probability_loss: -0.2214
# Epoch 42/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.7597 - KL_loss_layer_loss: 4.3949 - reconstructed_probability_loss: -0.1512 - val_loss: 7.8697 - val_KL_loss_layer_loss: 4.4006 - val_reconstructed_probability_loss: -0.0514
# Epoch 43/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.7593 - KL_loss_layer_loss: 4.3913 - reconstructed_probability_loss: -0.1451 - val_loss: 7.7873 - val_KL_loss_layer_loss: 4.3988 - val_reconstructed_probability_loss: -0.1305
# Epoch 44/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.7194 - KL_loss_layer_loss: 4.4000 - reconstructed_probability_loss: -0.2005 - val_loss: 7.8019 - val_KL_loss_layer_loss: 4.4104 - val_reconstructed_probability_loss: -0.1369
# Epoch 45/120
# 82732/82732 [==============================] - 2s 20us/step - loss: 7.7455 - KL_loss_layer_loss: 4.4062 - reconstructed_probability_loss: -0.1857 - val_loss: 7.7622 - val_KL_loss_layer_loss: 4.4178 - val_reconstructed_probability_loss: -0.1899
# Epoch 46/120
# 82732/82732 [==============================] - 1s 12us/step - loss: 7.6415 - KL_loss_layer_loss: 4.4129 - reconstructed_probability_loss: -0.3018 - val_loss: 7.6276 - val_KL_loss_layer_loss: 4.4167 - val_reconstructed_probability_loss: -0.3224
# Epoch 47/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6332 - KL_loss_layer_loss: 4.4137 - reconstructed_probability_loss: -0.3115 - val_loss: 7.6315 - val_KL_loss_layer_loss: 4.4188 - val_reconstructed_probability_loss: -0.3223
# Epoch 48/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6329 - KL_loss_layer_loss: 4.4163 - reconstructed_probability_loss: -0.3165 - val_loss: 7.6178 - val_KL_loss_layer_loss: 4.4225 - val_reconstructed_probability_loss: -0.3426
# Epoch 49/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6357 - KL_loss_layer_loss: 4.4209 - reconstructed_probability_loss: -0.3219 - val_loss: 7.6226 - val_KL_loss_layer_loss: 4.4274 - val_reconstructed_probability_loss: -0.3467
# Epoch 50/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6265 - KL_loss_layer_loss: 4.4243 - reconstructed_probability_loss: -0.3373 - val_loss: 7.6283 - val_KL_loss_layer_loss: 4.4295 - val_reconstructed_probability_loss: -0.3447
# Epoch 51/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6253 - KL_loss_layer_loss: 4.4271 - reconstructed_probability_loss: -0.3435 - val_loss: 7.6320 - val_KL_loss_layer_loss: 4.4331 - val_reconstructed_probability_loss: -0.3476
# Epoch 52/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6304 - KL_loss_layer_loss: 4.4314 - reconstructed_probability_loss: -0.3462 - val_loss: 7.6417 - val_KL_loss_layer_loss: 4.4379 - val_reconstructed_probability_loss: -0.3465
# Epoch 53/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6244 - KL_loss_layer_loss: 4.4363 - reconstructed_probability_loss: -0.3610 - val_loss: 7.6280 - val_KL_loss_layer_loss: 4.4413 - val_reconstructed_probability_loss: -0.3664
# Epoch 54/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6221 - KL_loss_layer_loss: 4.4393 - reconstructed_probability_loss: -0.3686 - val_loss: 7.6261 - val_KL_loss_layer_loss: 4.4459 - val_reconstructed_probability_loss: -0.3765
# Epoch 55/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6157 - KL_loss_layer_loss: 4.4422 - reconstructed_probability_loss: -0.3804 - val_loss: 7.6164 - val_KL_loss_layer_loss: 4.4464 - val_reconstructed_probability_loss: -0.3871
# Epoch 56/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6190 - KL_loss_layer_loss: 4.4428 - reconstructed_probability_loss: -0.3780 - val_loss: 7.6043 - val_KL_loss_layer_loss: 4.4470 - val_reconstructed_probability_loss: -0.4003
# Epoch 57/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6152 - KL_loss_layer_loss: 4.4435 - reconstructed_probability_loss: -0.3831 - val_loss: 7.6210 - val_KL_loss_layer_loss: 4.4477 - val_reconstructed_probability_loss: -0.3848
# Epoch 58/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6169 - KL_loss_layer_loss: 4.4440 - reconstructed_probability_loss: -0.3824 - val_loss: 7.6139 - val_KL_loss_layer_loss: 4.4482 - val_reconstructed_probability_loss: -0.3929
# Epoch 59/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6149 - KL_loss_layer_loss: 4.4445 - reconstructed_probability_loss: -0.3851 - val_loss: 7.6041 - val_KL_loss_layer_loss: 4.4486 - val_reconstructed_probability_loss: -0.4035
# Epoch 60/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6162 - KL_loss_layer_loss: 4.4451 - reconstructed_probability_loss: -0.3850 - val_loss: 7.6161 - val_KL_loss_layer_loss: 4.4493 - val_reconstructed_probability_loss: -0.3927
# Epoch 61/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6167 - KL_loss_layer_loss: 4.4457 - reconstructed_probability_loss: -0.3856 - val_loss: 7.6125 - val_KL_loss_layer_loss: 4.4499 - val_reconstructed_probability_loss: -0.3974
# Epoch 62/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6182 - KL_loss_layer_loss: 4.4464 - reconstructed_probability_loss: -0.3852 - val_loss: 7.6167 - val_KL_loss_layer_loss: 4.4507 - val_reconstructed_probability_loss: -0.3945
# Epoch 63/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6122 - KL_loss_layer_loss: 4.4469 - reconstructed_probability_loss: -0.3923 - val_loss: 7.6085 - val_KL_loss_layer_loss: 4.4511 - val_reconstructed_probability_loss: -0.4034
# Epoch 64/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6150 - KL_loss_layer_loss: 4.4475 - reconstructed_probability_loss: -0.3905 - val_loss: 7.6030 - val_KL_loss_layer_loss: 4.4517 - val_reconstructed_probability_loss: -0.4100
# Epoch 65/120
# 82732/82732 [==============================] - 1s 13us/step - loss: 7.6101 - KL_loss_layer_loss: 4.4479 - reconstructed_probability_loss: -0.3961 - val_loss: 7.5996 - val_KL_loss_layer_loss: 4.4520 - val_reconstructed_probability_loss: -0.4140
# Epoch 66/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6172 - KL_loss_layer_loss: 4.4485 - reconstructed_probability_loss: -0.3900 - val_loss: 7.6095 - val_KL_loss_layer_loss: 4.4528 - val_reconstructed_probability_loss: -0.4055
# Epoch 67/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6197 - KL_loss_layer_loss: 4.4494 - reconstructed_probability_loss: -0.3892 - val_loss: 7.6180 - val_KL_loss_layer_loss: 4.4537 - val_reconstructed_probability_loss: -0.3987
# Epoch 68/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6199 - KL_loss_layer_loss: 4.4502 - reconstructed_probability_loss: -0.3904 - val_loss: 7.5953 - val_KL_loss_layer_loss: 4.4544 - val_reconstructed_probability_loss: -0.4227
# Epoch 69/120
# 82732/82732 [==============================] - 1s 15us/step - loss: 7.6182 - KL_loss_layer_loss: 4.4508 - reconstructed_probability_loss: -0.3933 - val_loss: 7.6169 - val_KL_loss_layer_loss: 4.4550 - val_reconstructed_probability_loss: -0.4022
# Epoch 70/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6126 - KL_loss_layer_loss: 4.4514 - reconstructed_probability_loss: -0.4000 - val_loss: 7.6021 - val_KL_loss_layer_loss: 4.4557 - val_reconstructed_probability_loss: -0.4181
# Epoch 71/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6120 - KL_loss_layer_loss: 4.4520 - reconstructed_probability_loss: -0.4017 - val_loss: 7.6134 - val_KL_loss_layer_loss: 4.4561 - val_reconstructed_probability_loss: -0.4075
# Epoch 72/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6140 - KL_loss_layer_loss: 4.4525 - reconstructed_probability_loss: -0.4004 - val_loss: 7.6177 - val_KL_loss_layer_loss: 4.4567 - val_reconstructed_probability_loss: -0.4043
# Epoch 73/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6210 - KL_loss_layer_loss: 4.4532 - reconstructed_probability_loss: -0.3948 - val_loss: 7.6154 - val_KL_loss_layer_loss: 4.4576 - val_reconstructed_probability_loss: -0.4083
# Epoch 74/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6119 - KL_loss_layer_loss: 4.4540 - reconstructed_probability_loss: -0.4052 - val_loss: 7.6070 - val_KL_loss_layer_loss: 4.4582 - val_reconstructed_probability_loss: -0.4178
# Epoch 75/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6179 - KL_loss_layer_loss: 4.4543 - reconstructed_probability_loss: -0.3999 - val_loss: 7.6126 - val_KL_loss_layer_loss: 4.4582 - val_reconstructed_probability_loss: -0.4123
# Epoch 76/120
# 82732/82732 [==============================] - 1s 15us/step - loss: 7.6109 - KL_loss_layer_loss: 4.4544 - reconstructed_probability_loss: -0.4069 - val_loss: 7.6022 - val_KL_loss_layer_loss: 4.4583 - val_reconstructed_probability_loss: -0.4227
# Epoch 77/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6063 - KL_loss_layer_loss: 4.4544 - reconstructed_probability_loss: -0.4117 - val_loss: 7.6076 - val_KL_loss_layer_loss: 4.4583 - val_reconstructed_probability_loss: -0.4174
# Epoch 78/120
# 82732/82732 [==============================] - 1s 14us/step - loss: 7.6154 - KL_loss_layer_loss: 4.4545 - reconstructed_probability_loss: -0.4026 - val_loss: 7.6003 - val_KL_loss_layer_loss: 4.4584 - val_reconstructed_probability_loss: -0.4248
# EPOCH N: 120 100
# train_shell ::
# train_shell :: trained 58 epochs!
# train_shell ::
# finished epoch N 78
# prev [20, 58]
# train_shell :: model saved

# %% [markdown]
# ### Training progress
# Obviously, KL loss was not weighted properly in this attempt. We won't mind that now, though.

# %%
instance.plot_metrics(fnmatch_criteria="*?????loss", figloc=(.52,.565), figsize=(12,8), figname='Training Loss')

# %%
z_mu, z_sigma = vae.get_layer("z_mu").output, vae.get_layer("z_sigma").output
input_layer = vae.get_layer("input").output

z_out = vae.get_layer("latent_sampling").output
out_mu, out_sigma = vae.get_layer("output_mu").output, vae.get_layer("output_sigma").output

encoder = keras.models.Model(inputs=input_layer, outputs=[z_mu, z_sigma])
autoencoder = keras.models.Model(inputs=input_layer, outputs=[out_mu, out_sigma])
zencoder = keras.models.Model(inputs=input_layer, outputs=z_out)

# aux = encoder.predict(np.zeros((1,input_dim)))
# mu_prior = aux[0][0]
# sigma_prior = aux[1][0]

# mu_prior, sigma_prior

inputs_out = [data_norm, signal_norm]
outputs_out = [autoencoder.predict(data_norm.data), autoencoder.predict(signal_norm.data)]

# %%
utils.plot_spdfs(inputs_out, outputs_out, figname="output distributions")

# %%
signal_jets_norm, data_jets_norm = [
    [train_raw.norm(j.cfilter(signal_norm.headers), **norm_args) for j in jet_table] for jet_table in [signal_jets, data_jets]
]

nodenames = ['node {}'.format(i) for i in range(neck_dim)]

data_reps, signal_reps = (
    utils.data_table(zencoder.predict(data_norm.data), headers=nodenames, name="background_reps"),
    utils.data_table(zencoder.predict(signal_norm.data), headers=nodenames, name="signal_reps")
)

data_jet_reps, signal_jet_reps = (
    [utils.data_table(zencoder.predict(d.data), headers=nodenames, name="jet {} background reps".format(i)) for i,d in enumerate(data_jets_norm)],
    [utils.data_table(zencoder.predict(d.data), headers=nodenames, name="jet {} signal reps".format(i)) for i,d in enumerate(signal_jets_norm)],
)

# %%
# node_outputs[0].plot(node_outputs[1], normed=1, figname='node outputs', figloc='upper right', figsize=15, fontsize=20, cols=2)
signal_jet_reps[0].plot(
    signal_jet_reps[1:] + data_jet_reps, 
    normed=1, figname='node outputs', figloc='upper right', 
    figsize=20, fontsize=20, cols=3, bins=60)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jet 0 signal reps', 'jet 1 signal reps', 'jet 0 background reps', 'jet 1 background reps']

# %%
err_data = utils.data_table(vae.predict(data_norm.data)[1], headers=['loss'], name='combined data error')
err_signal = utils.data_table(vae.predict(signal_norm.data)[1], headers=['loss'], name='combined signal error')
err_data_jets = [
    utils.data_table(
        vae.predict(d.data)[1],
        headers=['loss'],
        name='jet {} background error'.format(i + 1)
    ) for i,d in enumerate(data_jets_norm)
]

err_signal_jets = [
    utils.data_table(
        vae.predict(d.data)[1],
        headers=['loss'],
        name='jet {} signal error'.format(i + 1)
    ) for i,d in enumerate(signal_jets_norm)
]

# %%
err_signal_jets[0].plot(
    err_signal_jets[1:] + err_data_jets, bins=100, normed=1, yscale='linear',
    figsize=(10,10), alpha=1.5, rng=(-6, 20), figloc="upper right",
    figname="error"
)
# Out:
# data_table :: plotting distrubution(s) for table(s) ['jet 1 signal error', 'jet 2 signal error', 'jet 1 background error', 'jet 2 background error']

# %%
utils.roc_auc_plot([err_data], err_signal_jets + [err_signal], ticksize=10, yscale='linear', figsize=10, figloc=(.4, .10), figname="ROC by jet #, compared against all background jets")
utils.roc_auc_plot(err_data_jets + [err_data], err_signal_jets + [err_signal], ticksize=10, yscale='linear', figsize=10, figloc=(.4, .10), figname="ROC by jet #, compared against respective background jet")

# %%
# def plot_vae_necknodes(encoder, x_ins, bins=50, *args, **kwargs):
    
#     input_dim = encoder.layers[0].get_input_shape_at(0)[1]
#     aux = encoder.predict(np.zeros((1, input_dim)))
#     mu_prior = aux[0][0]
#     sigma_prior = aux[1][0]
    
#     to_calculate = [encoder.predict(d.data) for d in x_ins] 
    
#     assert len(mu_prior) == len(sigma_prior)
#     neck_dim = len(mu_prior)
    
#     fig, ax_on, ax_off, plt_end, colors = get_plot_params(neck_dim, *args, **kwargs)
    
#     for i in range(neck_dim):
#         ax = ax_on(i)
#         lower = mu_prior[i] - 6*sigma_prior[i]
#         upper = mu_prior[i] + 6*sigma_prior[i]

#         width = (upper - lower) / bins
#         z = np.arange(lower, upper, width)
        
#         for j,calc in enumerate(to_calculate):
            
#             mus, sigmas = calc
#             content = sum_of_gaussians(z, mus[i], sigmas[i])*width
#             ax.errorbar(z + width/2., content, xerr=width/2, c=colors[j], label=x_ins[j].name)
        
#         ax_off("node {}".format(i))
#     plt_end()
        
# plot_vae_necknodes(encoder, inputs)
